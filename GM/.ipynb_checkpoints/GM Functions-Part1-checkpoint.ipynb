# %% [markdown]
# # Problems

# %% [markdown]
# ## # Anchor Check Problem

# %% [markdown]
# # Capstone Project

# %% [markdown]
# # Libraries

# %%
# Import Library 

import re
import requests
from re import search

import unicodedata
from bs4 import BeautifulSoup
from bs4 import Tag

from bs4 import NavigableString
from bs4 import SoupStrainer
from pprint import pprint

import numpy as np
from numpy import array
import pandas as pd 

import csv
import pickle

from collections import Counter
import datetime

from IPython.display import display_html
from IPython.display import display
from IPython.core import display as ICD
pd.set_option('display.max_columns', 100)

# %% [markdown]
# # Define Text Normalization Function

# %%
def restore_windows_1252_characters(restore_string):
    """
    Replace C1 control characters in the Unicode string s by the
    characters at the corresponding code points in Windows-1252,
    where possible.
    """

def to_windows_1252(match):
    try:
        return bytes([ord(match.group(0))]).decode('windows-1252')
    except UnicodeDecodeError:
        # No character at the corresponding code point: remove it.
        return ''

    return re.sub(r'[\u0080-\u0099]', to_windows_1252, restore_string)

# %% [markdown]
# # Grab the Document Content

# %%
def grab_doc_content( brand, CIK ):
    
    company = {}
    
    company['auto'] = {}
    auto = {brand : CIK
           }
    company['auto'] = auto

    value = list(auto.copy().values())
    
    return value

# %%
GDC = grab_doc_content('General_Motors' , '0001467858')

# %%
master_filings_dict = {}
    
file_code = {}
    
file_text = {}

Accession_Number_URL = {}

# %%
# URL Directory For CIK    
dir_url = r'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-&dateb=&owner=include&count=100'
dir_url_list = [dir_url.format(x) for x in GDC]

#print('Directory URL: {}'.format(dir_url_list))
doc_url_list = [] 

# FOR-loop yielding Accession Numbers from CIK/URL Directory.
for CIK_num in GDC:

    doc_url = r'https://www.sec.gov/Archives/edgar/data/{CIKx}/{xx}/{yy}.txt'
    doc_url_new = doc_url.format(CIKx = CIK_num, xx='{xx}', yy ='{yy}')
    doc_url_list.append(doc_url_new)

# %%
def url_maker(dir_url):
    dir_url_list = [dir_url.format(x) for x in GDC]

    #print('Directory URL: {}'.format(dir_url_list))
    doc_url_list = [] 

    # FOR-loop yielding Accession Numbers from CIK/URL Directory.
    for CIK_num in GDC:

        doc_url = r'https://www.sec.gov/Archives/edgar/data/{CIKx}/{xx}/{yy}.txt'
        doc_url_new = doc_url.format(CIKx = CIK_num, xx='{xx}', yy ='{yy}')
        
        doc_url_list.append(doc_url_new)
        
        url_lists = zip( dir_url_list , doc_url_list )
        
    return url_lists

# %%
url = r'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-&dateb=&owner=include&count=100'
for dir_url, doc_url in url_maker(url): 
    print(1, dir_url)
    print(2, doc_url)
# Out:
# 1 https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=0001467858&type=10-&dateb=&owner=include&count=100
# 2 https://www.sec.gov/Archives/edgar/data/0001467858/{xx}/{yy}.txt

# %%
Accession_Number_URL = {}
url = r'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-&dateb=&owner=include&count=100'

for dir_url, doc_url in url_maker(url):
    
    response = requests.get(dir_url)
    soup = BeautifulSoup(response.content, 'lxml')
    text = soup.get_text(strip=True)

    cleaned_text = re.findall('Acc-no: \d+-\d+-\d+' , text)

    accession_number = [n.replace('Acc-no: ', '') for n in cleaned_text]
    accessionnumber = [num.replace('-', '') for num in accession_number]

    accession_numbers = zip(accessionnumber, accession_number)
    
    cikk = [ cikk_.replace('CIK=', '') for cikk_ in re.findall('CIK=\d+', dir_url) ][0]
    CIKK = {cikk : accessionnumber}
    
    for (a,b) in accession_numbers: 
        master_filings_dict[b] = {}
        master_filings_dict[b]['sec_header_content'] = {}
        master_filings_dict[b]['filing_documents'] = None

        doc_url_single = doc_url.format(xx = a, yy = b)

        file_url_list = []

        

        file_url_list.append( doc_url_single )
        
        Accession_Number_URL.update({ b : file_url_list})

# %%
A_N = []
for AN, url in Accession_Number_URL.items():
    
    if AN == '0000037996-12-000049':
        break
    else:
        A_N.append(AN)
        print(url)
        
print(A_N, '\n')
print(len(A_N))
# Out:
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785820000069/0001467858-20-000069.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785820000028/0001467858-20-000028.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785819000121/0001467858-19-000121.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785819000107/0001467858-19-000107.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785819000084/0001467858-19-000084.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785819000033/0001467858-19-000033.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785818000104/0001467858-18-000104.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785818000089/0001467858-18-000089.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785818000068/0001467858-18-000068.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785818000022/0001467858-18-000022.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785817000133/0001467858-17-000133.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785817000103/0001467858-17-000103.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785817000070/0001467858-17-000070.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785817000028/0001467858-17-000028.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785816000363/0001467858-16-000363.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785816000341/0001467858-16-000341.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785816000317/0001467858-16-000317.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785816000255/0001467858-16-000255.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785815000217/0001467858-15-000217.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785815000175/0001467858-15-000175.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785815000122/0001467858-15-000122.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785815000036/0001467858-15-000036.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785814000247/0001467858-14-000247.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785814000213/0001467858-14-000213.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785814000125/0001467858-14-000125.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785814000043/0001467858-14-000043.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785813000135/0001467858-13-000135.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785813000106/0001467858-13-000106.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785813000083/0001467858-13-000083.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785813000075/0001467858-13-000075.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785813000025/0001467858-13-000025.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785812000070/0001467858-12-000070.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785812000060/0001467858-12-000060.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785812000047/0001467858-12-000047.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785812000029/0001467858-12-000029.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000146785812000014/0001467858-12-000014.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312511303419/0001193125-11-303419.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312511211642/0001193125-11-211642.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312511130473/0001193125-11-130473.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312511051462/0001193125-11-051462.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312510255233/0001193125-10-255233.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312510189968/0001193125-10-189968.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312510121894/0001193125-10-121894.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312510121463/0001193125-10-121463.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312510078147/0001193125-10-078147.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312510078123/0001193125-10-078123.txt']
# ['https://www.sec.gov/Archives/edgar/data/0001467858/000119312510078119/0001193125-10-078119.txt']
# ['0001467858-20-000069', '0001467858-20-000028', '0001467858-19-000121', '0001467858-19-000107', '0001467858-19-000084', '0001467858-19-000033', '0001467858-18-000104', '0001467858-18-000089', '0001467858-18-000068', '0001467858-18-000022', '0001467858-17-000133', '0001467858-17-000103', '0001467858-17-000070', '0001467858-17-000028', '0001467858-16-000363', '0001467858-16-000341', '0001467858-16-000317', '0001467858-16-000255', '0001467858-15-000217', '0001467858-15-000175', '0001467858-15-000122', '0001467858-15-000036', '0001467858-14-000247', '0001467858-14-000213', '0001467858-14-000125', '0001467858-14-000043', '0001467858-13-000135', '0001467858-13-000106', '0001467858-13-000083', '0001467858-13-000075', '0001467858-13-000025', '0001467858-12-000070', '0001467858-12-000060', '0001467858-12-000047', '0001467858-12-000029', '0001467858-12-000014', '0001193125-11-303419', '0001193125-11-211642', '0001193125-11-130473', '0001193125-11-051462', '0001193125-10-255233', '0001193125-10-189968', '0001193125-10-121894', '0001193125-10-121463', '0001193125-10-078147', '0001193125-10-078123', '0001193125-10-078119']
#
# 47

# %%
QorK = {'10-Q' : [],
        '10-K' : []
       }

for acc_num, url in Accession_Number_URL.items():
    
    master_document_dict = {}
    
    # create a stop point
    if acc_num == '0000037996-12-000049':
        break

    else:
        
        # grab the response
        response = requests.get(url[0])

    # Soupify
        # pass it through the parser, in this case let's just use lxml because the tags seem to follow xml.
        soup = BeautifulSoup(response.content, 'lxml')
        filing_document = soup.find('document')
        document_description = filing_document.description.find(text=True, recursive=False).strip()
        print(document_description)
        break
# Out:
# 10-Q

# %% [markdown]
# ## Save each Filing.

# %%
QorK = {'10-Q' : [],
        '10-K' : []
       }

for acc_num, url in Accession_Number_URL.items():
    
    master_document_dict = {}
    
    # create a stop point
    if acc_num == '0000037996-12-000049':
        break

    else:
        
        # grab the response
        response = requests.get(url[0])

    # Soupify
        # pass it through the parser, in this case let's just use lxml because the tags seem to follow xml.
        soup = BeautifulSoup(response.content, 'lxml')
        filing_document = soup.find('document')
        
    # Parsing
        # Document type ->> document_id
        document_id = filing_document.type.find(text=True, recursive=False).strip()
        # Document sequence ->> document_sequence
        document_sequence = filing_document.sequence.find(text=True, recursive=False).strip()
        # Document filename ->> document_filename
        document_filename = filing_document.filename.find(text=True, recursive=False).strip()
        
    # Storage    
        # initalize our document dictionary
        master_document_dict[document_id] = {}

        # add the different parts, we parsed up above.
        master_document_dict[document_id]['document_sequence'] = document_sequence
        master_document_dict[document_id]['document_filename'] = document_filename
        
# Scraping
        # grab the text portion of the document, this will be used to split the document into pages.
        filing_doc_text = filing_document.find('text').extract()

        # find all the thematic breaks, these help define page numbers and page breaks.
        all_thematic_breaks = filing_doc_text.find_all('hr')
        
        # Locate and store page number via list comprehension.
        all_page_numbers = [thematic_break.previous_sibling.get_text(strip=True) for thematic_break in all_thematic_breaks if len(str(thematic_break))>6]
            
        # convert all thematic breaks to a string so it can be used for parsing
        all_thematic_breaks = [str(thematic_break) for thematic_break in all_thematic_breaks]

        # prep the document text for splitting, this means converting it to a string.
        filing_doc_string = str(filing_doc_text)
    
        # handle the case where there are thematic breaks.
        if len(all_thematic_breaks) > 0: 

            # define the regex delimiter pattern, this would just be all of our thematic breaks.
            regex_delimiter_pattern = '|'.join(map(re.escape, all_thematic_breaks))

            # split the document along each thematic break.
            split_filing_string = re.split(regex_delimiter_pattern, filing_doc_string)

            # store the document itself
            master_document_dict[document_id]['pages_code'] = split_filing_string

        # handle the case where there are no thematic breaks.
        elif len(all_thematic_breaks) == 0:

            # handles so it will display correctly.
            split_filing_string = all_thematic_breaks

            # store the document as is, since there are no thematic breaks. In other words, no splitting.
            master_document_dict[document_id]['pages_code'] = [filing_doc_string]
            
        # display some information to the user.
        print('-'*80)
        print('The document {} was parsed.'.format(document_id))
        print('There was {} page(s) found.'.format(len(all_page_numbers)))
        print('There was {} thematic breaks(s) found.'.format(len(all_thematic_breaks)))

        # store the documents in the master_filing_dictionary.
        master_filings_dict[acc_num]['filing_documents'] = master_document_dict
        
        # if document is 10-Q
        if document_id == '10-Q':
            QorK['10-Q'].append(acc_num) # add acc_num to QorK in 10-Q as key
        
        # if document is 10-K
        if document_id == '10-K':
            QorK['10-K'].append(acc_num) # add acc_num to QorK in 10-K as key
        
        del master_document_dict
        
        print('-'*80)
        print('All the documents for filing {} were parsed and stored.'.format(acc_num))
# Out:
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 50 page(s) found.
# There was 52 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-20-000069 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 103 page(s) found.
# There was 103 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-20-000028 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 50 page(s) found.
# There was 52 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-19-000121 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 48 page(s) found.
# There was 50 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-19-000107 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 43 page(s) found.
# There was 45 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-19-000084 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 108 page(s) found.
# There was 108 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-19-000033 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 52 page(s) found.
# There was 54 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-18-000104 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 53 page(s) found.
# There was 55 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-18-000089 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 46 page(s) found.
# There was 48 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-18-000068 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 95 page(s) found.
# There was 95 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-18-000022 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 51 page(s) found.
# There was 53 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-17-000133 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 50 page(s) found.
# There was 52 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-17-000103 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 43 page(s) found.
# There was 45 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-17-000070 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 96 page(s) found.
# There was 96 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-17-000028 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 46 page(s) found.
# There was 48 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-16-000363 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 45 page(s) found.
# There was 47 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-16-000341 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 40 page(s) found.
# There was 42 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-16-000317 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 113 page(s) found.
# There was 113 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-16-000255 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 50 page(s) found.
# There was 52 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-15-000217 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 49 page(s) found.
# There was 51 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-15-000175 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 45 page(s) found.
# There was 47 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-15-000122 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 124 page(s) found.
# There was 124 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-15-000036 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 57 page(s) found.
# There was 59 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-14-000247 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 57 page(s) found.
# There was 59 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-14-000213 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 49 page(s) found.
# There was 51 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-14-000125 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 142 page(s) found.
# There was 142 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-14-000043 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 60 page(s) found.
# There was 62 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-13-000135 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 59 page(s) found.
# There was 61 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-13-000106 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q/A was parsed.
# There was 70 page(s) found.
# There was 72 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-13-000083 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 69 page(s) found.
# There was 71 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-13-000075 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 183 page(s) found.
# There was 183 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-13-000025 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q/A was parsed.
# There was 4 page(s) found.
# There was 6 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-12-000070 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 89 page(s) found.
# There was 91 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-12-000060 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 82 page(s) found.
# There was 84 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-12-000047 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 69 page(s) found.
# There was 69 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-12-000029 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 216 page(s) found.
# There was 216 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001467858-12-000014 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 110 page(s) found.
# There was 110 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-11-303419 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 104 page(s) found.
# There was 104 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-11-211642 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 91 page(s) found.
# There was 91 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-11-130473 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 326 page(s) found.
# There was 326 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-11-051462 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 170 page(s) found.
# There was 170 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-10-255233 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 134 page(s) found.
# There was 134 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-10-189968 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-12G/A was parsed.
# There was 20 page(s) found.
# There was 20 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-10-121894 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 91 page(s) found.
# There was 91 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-10-121463 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-12G was parsed.
# There was 20 page(s) found.
# There was 20 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-10-078147 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 162 page(s) found.
# There was 162 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-10-078123 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 342 page(s) found.
# There was 342 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001193125-10-078119 were parsed and stored.

# %%
string_test = master_filings_dict['0000037996-20-000041']['filing_documents']['10-Q']['pages_code']
for page in string_test:
    if 'Cash and cash equivalents' in page:
        if 'CONSOLIDATED BALANCE SHEET' in page:
            print(page)
            print('~'*40)
#string_test[56]
# df01 = table(string_test, '10-Q')
# df = df01[0]
# df
# Out:
# <div><a id="sE1C0F790A66C554EB952CAF5379A108C"></a></div><div><div style="line-height:120%;text-align:left;padding-left:18px;text-indent:0px;font-size:10pt;"><span style="font-family:Arial;font-size:10pt;font-style:italic;">Item 1. Financial Statements (continued)</span></div></div><div><br/></div><div style="line-height:120%;text-align:center;font-size:10pt;"><span style="font-family:Arial;font-size:10pt;font-weight:bold;">FORD MOTOR COMPANY AND SUBSIDIARIES</span></div><div style="line-height:120%;text-align:center;font-size:10pt;"><span style="font-family:Arial;font-size:10pt;font-weight:bold;">CONSOLIDATED BALANCE SHEET</span></div><div style="line-height:120%;text-align:center;font-size:10pt;"><span style="font-family:Arial;font-size:10pt;font-weight:bold;">(in millions)</span></div><div style="line-height:120%;font-size:10pt;"><div style="padding-left:0px;text-indent:0px;line-height:normal;padding-top:10px;"><table cellpadding="0" cellspacing="0" style="font-family:Times New Roman;font-size:10pt;width:100%;border-collapse:collapse;text-align:left;"><tr><td colspan="8"></td></tr><tr><td style="width:75%;"></td><td style="width:1%;"></td><td style="width:10%;"></td><td style="width:1%;"></td><td style="width:1%;"></td><td style="width:1%;"></td><td style="width:10%;"></td><td style="width:1%;"></td></tr><tr><td style="vertical-align:bottom;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:left;font-size:8pt;"><span style="font-family:Arial;font-size:8pt;"> </span></div></td><td colspan="3" style="vertical-align:bottom;border-bottom:1px solid #000000;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:center;font-size:8pt;"><span style="font-family:Arial;font-size:8pt;">December 31, <br/>2019</span></div></td><td style="vertical-align:bottom;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="overflow:hidden;font-size:10pt;"><span style="font-family:inherit;font-size:10pt;"> </span></div></td><td colspan="3" style="vertical-align:bottom;border-bottom:1px solid #000000;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:center;font-size:8pt;"><span style="font-family:Arial;font-size:8pt;font-weight:bold;">March 31, <br/>2020</span></div></td></tr><tr><td style="vertical-align:bottom;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:left;font-size:8pt;"><span style="font-family:Arial;font-size:8pt;"> </span></div></td><td colspan="7" style="vertical-align:bottom;padding-left:2px;padding-top:2px;padding-bottom:2px;"><div style="text-align:center;font-size:8pt;"><span style="font-family:Arial;font-size:8pt;">(unaudited)</span></div></td></tr><tr><td style="vertical-align:bottom;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:left;font-size:8pt;"><span style="font-family:Arial;font-size:8pt;font-weight:bold;">ASSETS</span></div></td><td colspan="3" style="vertical-align:bottom;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:left;font-size:8pt;"><span style="font-family:Arial;font-size:8pt;"> </span></div></td><td style="vertical-align:bottom;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="overflow:hidden;font-size:10pt;"><span style="font-family:inherit;font-size:10pt;"> </span></div></td><td colspan="3" style="vertical-align:bottom;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:left;font-size:8pt;"><span style="font-family:Arial;font-size:8pt;"> </span></div></td></tr><tr><td style="vertical-align:bottom;background-color:#cceeff;padding-left:2px;padding-top:2px;padding-bottom:2px;padding-right:2px;"><div style="text-align:left;font-size:8pt;"><span style="font-family:Arial;font-size:8pt;">Cash and cash equivalents (Note 7)</span></div></td><td style ...
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## Anchor Check Function

# %%
# Variations of HTML anchors.
CBS_A = 'CONSOLIDATED BALANCE SHEETS'
# CBS_B = 'name="BALANCE_SHEETS"'
# CBS_D = 'BALANCE SHEETS '
CBS_C = 'Cash and cash equivalents'
# SoO_A = '<a name="Statements_of_Operations"' 
# SoO_B = 'id="CONSOLIDATED_STATEMENTS_OPERATIONS"'
# SoO3 = 'name="CONSOLIDATED_STATEMENTS_OPERATIONS"'
# CSoO10K = 'name="Consolidated_Statements_of_Operations"'
# CSoO10Knew = 'id="Consolidated_Statements_of_Operations"'

# CF_A = '<a name="Statements_of_Cash'
# CF_B = 'id="CONSOLIDATED_STATEMENTS_CASH_FLOWS"'
# CF3 = 'name="CONSOLIDATED_STATEMENTS_CASH_FLOWS"'
# CCF10K = 'name="Consolidated_Statements_of_Cash_Flows"'
# CCF10Knew = 'id="Consolidated_Statements_of_Cash_Flows"'

def anchor_check(page_code):
    
    # if the page has one of these anchors
    if (CBS_A in page_code): #and (CBS_C in page_code):
        return True

    #elif (SoO_A in page_code) or (SoO_B in page_code) or (SoO3 in page_code) or (CSoO10K in page_code) or (CSoO10Knew in page_code) :
        #return True

    #elif (CF_A in page_code) or (CF_B in page_code) or (CF3 in page_code) or (CCF10K in page_code) or (CCF10Knew in page_code):
        #return True


    else:
        return False

# %% [markdown]
# ## Cleaning Columns Function

# %%
month_dict = {'December' : 'Q4',
              'November' : 'Q4',
             'October' : 'Q4',
             'September' : 'Q3',
             'August': 'Q3',
             'July' : 'Q3',
             'June' : 'Q2',
             'May' : 'Q2',
             'April' : 'Q2',
             'March' : 'Q1',
             'Feburary' : 'Q1',
             'January' : 'Q1'}

# %%
col_name_variants = {
    'Inventor' : 'Inventory',
    'Total liabilities and' : 'Total liabilities and equity',
    'Common stock.*' : 'Common Stock',
    'Preferred stock.*': 'Preferred Stock',
    'Accounts receivable.*' : 'Accounts Receivable',
    'Accrued liabilities.*' : 'Accrued Liabilities',
    'Deferred revenue.*' : 'Deferred Revenue',
    'Redeemable noncontrolling interests in subsidiaries.*' : 'Noncontrolling interests in subsidiaries',
    'Short term investments.*' : 'Short term investments', 
    'Property|equipment.' : 'Property and Equipment',
    'Retained earnings.*' : 'Retained Earnings',
    'stockholders.*' : 'Shareholder Equity',
    '^Cash.*' : 'Cash',
    'Convertible senior notes.*' : 'Convertible Senior Notes'
}

# %%
def clean_col_name( name ):
    
    for detect, replacement in col_name_variants.items():

        if re.findall(detect, name, flags=re.I):

            n_column = name.replace(name, replacement) 

            return n_column 
            
    return name

# %%
# Throw column list-like object into cleaning function. 
def cleaning_column(r_column, m):
     
    column_list = []
    column_name = []
    
    for element_post, element in enumerate(r_column):
        try:
            ele= element.encode('cp1252').decode("utf-8", "ignore")
                
        except:
            ele= element.encode('latin1').decode("utf-8", "ignore")
            
        if ele =='':
            continue
            
        ele_norm = unicodedata.normalize('NFKD', ele)
        
        # Handling the first "row" in the table i.e. column name.
        if element_post == 0:
#             print(element)
            
            ele_norm = ele_norm.replace('net', '')
            
            ele_norm = ele_norm.replace( '-', ' ')
            
            s_ele_norm = re.sub(r"^\s+|\s+$", "", ele_norm)
            
            name = re.sub(r'(?=,|:|\.|\(){1}.*', repl='', string= s_ele_norm, flags=re.I)
            
            # clean_col_name function Choose old_if or new_dict
            clean_name = clean_col_name( name )
            ###
            column_name.append(clean_name)
            ###
            column_list.append(clean_name)
        
        # Handling the all the remaining "rows" in the table i.e. data/numbers.
        elif ele_norm not in ['\n$', '\n\xa0', '\n', '\xa0']:
            
            n_element = ele_norm.replace( ',', '' )

            pattern = re.compile(r'[\d]+,[\d]+|[\d]+')

            res = pattern.findall(n_element)
            
            result = [int(clean_ele) * m for clean_ele in res]

            column_list.extend(result)

    return column_list

# %%
# This always picks the larger year. The row with the smaller year will always be deleted. 
def pick_row_del( single_table ):
    
    year = single_table[1]
    
    name, a, b = year # boardcast
    
    if a > b: # string comparison works if just string just numbers. 
        return year.index(b)# this will be deleted in .drop() 
    
    if b > a: 
        return year.index(a)# this will be deleted in .drop()

# %% [markdown]
# ## Cleaning Tables Function

# %%
# New and imporved.
def Quarter( column , k):
    
    print('column used for quarter', column)
    
    multi_list = [element.split() for element in column if element.split() != []]
#     print('multi_list', multi_list)
    new_column = [item for sublist in multi_list for item in sublist]
    print('new_column used for year', new_column)
    
    Q = []
    Y = []
    
    for letter in column:
#         print('letter', letter)
        try:
            month = re.findall(r'\w{}+'.format(list(month_dict.keys())), letter.replace(' ',  '') )[0]
            
            Q_num = month_dict[month] 
    #         print('Q_num' , Q_num)
    
            if Q_num != []:
                Q.append(Q_num)
                
        except:
            continue
    #         print('~'*20)
        
#     print('Q' , Q) 
#     Q_final = Q[0] 
#     print('Q_final' , Q_final)
    
  
    for letter in new_column:   
                
        Year = [re.compile(r'^[0-9]{4}$').findall(p_s_ele_norm) for p_s_ele_norm in letter.split(',') if re.compile(r'^[0-9]{4}$').findall(p_s_ele_norm) != []]
        if Year != []:
            Y.append(Year[0][0])
    print(f'Y - {Y}')   # Y - Y - [['2020'], ['2019']]

    Q_final =['Quarter'] + Q
        
    Y.insert(0, 'Year')
    
    
#     print( '\n', 'Q_final', Q_final, 'Y', Y)
    return Q_final, Y

# %%
def table_extractor( page, multiplier, k ):
    
    # Convert string to BS object
    soup = BeautifulSoup(page, 'html5')

    year = int(vv.split(sep='-')[1])
    
    # Get only the first table in the page. 
    for table_num, table in enumerate(soup.find_all('tbody')):
        if table_num == 0: 
            
            # then get all the rows in the table.
            table_rows = soup.find_all('tr')

            if len( [tr.text for tr in table_rows[0].find_all('td')] ) < 3:
                del table_rows[0]

            single_table = []
            Date_column = []

            # Loop through each column, adding in three structures to single_table.
            for tr_post, tr in enumerate(table_rows):
                td = tr.find_all('td')

                try: 
                    column = [tr.text.encode('cp1252').decode("utf-8", "ignore") for tr in td]

                except: 
                    column  =[tr.text.encode('ISO-8859-1').decode("utf-8", "ignore") for tr in td]

#                 print( 'tr_post', tr_post, len(column), column)
#                 print(f'k - {k}    year - {year}')
                if k == '10-Q' and year < 11 or k == '10-K' and year < 13:

                    if tr_post == 2:

                        # Quarter Column
                        col_Q, col_year = Quarter( column, k )
                        single_table.append( col_Q )
                        # Year Column
                        single_table.append( col_year )

                    elif tr_post > 1: 
#                                     print(column)
                        # Features Columns
                        cleaned_data = cleaning_column( column , multiplier )
                        #print(cleaned_data)
                        if len(cleaned_data) > 10:
                            del cleaned_data[3]

                        if cleaned_data == ['']:
                            break
                        single_table.append( cleaned_data )
                else: 

                    if tr_post == 1:

                        # Quarter Column
                        col_Q, col_year = Quarter( column, k )
                        single_table.append( col_Q )
                        # Year Column
                        single_table.append( col_year )

                    elif tr_post > 1: 
#                         print(column)
                        # Features Columns
                        cleaned_data = cleaning_column( column , multiplier )
                        #print(cleaned_data)
                        if len(cleaned_data) > 10:
                            del cleaned_data[3]

                        if cleaned_data == ['']:
                            break
                        single_table.append( cleaned_data )

            return single_table

# %%
def df_clean( single_table ):
#     print(single_table)
    table_df = pd.DataFrame(single_table)
    
    table_df = table_df.transpose()  
    #print(table_df)
    
    table_df.drop(table_df.index[pick_row_del(single_table):], 0, inplace=True)

    table_df.columns = table_df.iloc[0]

    table_df = table_df.drop(table_df.index[0])
    
    return table_df

# %%
def table(page_code, k):
    
    doc_tables=[]

    for page_post, page in enumerate(page_code):

        if anchor_check(page) and search(r'million', page, flags=re.I):
            print('pass anchor check')
            single_table = table_extractor( page, 10**6, k )
            #print(single_table)
            table_df = df_clean(single_table)
                        
            doc_tables.append(table_df)
        
        elif anchor_check(page) and search(r'thousand', page, flags=re.I):
            
            #print('page_post', page_post)
            
            single_table = table_extractor( page, 10**3, k )

            table_df = df_clean(single_table)

            doc_tables.append(table_df)
            
#         else:
#             print(page_post+1, 'anchor_check / in thousands/million problem')

                
    return doc_tables

# %% [markdown]
# # Exploring the Data

# %%
for QK, N_O in explore_dict.items():
    
    for an_postition, vv in enumerate(N_O):
        
        pages = master_filings_dict[vv]['filing_documents'][QK]['pages_code']
        print('\n', 'This is {} a {} document.'.format(vv, QK))
        
        test_df_list = table(pages, QK)
        test_df = test_df_list[0]
        
        table_df = test_df.drop(test_df.index[1:]).reset_index(drop=True)
        print('Shape - ', table_df.shape)
        ICD.display(table_df)
# Out:
#  This is 0001467858-20-000069 a 10-Q document.
# pass anchor check
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# column used for quarter ['', 'March31, 2020', '', 'December31, 2019']
# new_column used for year ['March31,', '2020', 'December31,', '2019']
# Y - ['2020', '2019']
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# k - 10-Q    year - 20
# Shape -  (1, 49)
# 0 Quarter  Year ASSETS Current Assets         Cash  \
# 0      Q1  2020   None           None  38506000000
#
# 0 Marketable debt securities  Accounts and notes receivable  \
# 0                  7620000000                    7536000000
#
# 0 GM Financial receivables    Inventory Other current assets   \
# 0              26320000000  10799000000            6918000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 0          97699000000               None              25948000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 0                                       7521000000            37969000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 0                     5225000000            41296000000           24441000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 0    6525000000             148925000000  246624000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 0                   None                None       20031000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 0                                               None      1730000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 0   43331000000         26200000000               91292000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 0                    None            None  28581000000   52858000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 0                                   5766000000  11505000000       12305000000
#
# 0 Total non current liabilities Total Liabilities  \
# 0                  111015000000      202307000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 0                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 0                26014000000       25885000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 0                          11800000000        40113000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 0               4204000000  44317000000                 246624000000
#  This is 0001193125-10-078123 a 10-Q document.
# pass anchor check
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# column used for quarter ['', '', 'September30,2009\n', '', '', '', '', 'December31,2008\n', '']
# new_column used for year ['September30,2009', 'December31,2008']
# Y - ['2009', '2008']
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# k - 10-Q    year - 10
# Shape -  (1, 70)
# 0 Quarter  Year   NaN ASSETS Current Assets         Cash  \
# 0      Q3  2009  None   None           None  25092000000
#
# 0 Marketable securities   NaN   Total cash  \
# 0             137000000  None  25229000000
#
# 0 Restricted cash and marketable securities Accounts and notes receivable  \
# 0                               19009000000                    7725000000
#
# 0    Inventory Assets held for sale Property and Equipment  \
# 0  10610000000            663000000             3142000000
#
# 0 Other current assets and deferred income taxes   NaN Total current assets  \
# 0                                     1966000000  None          68344000000
#
# 0 Non Current Assets Restricted cash and marketable securities  \
# 0               None                                1553000000
#
# 0 Equity in  assets of nonconsolidated affiliates Property and Equipment  \
# 0                                      6088000000                5000000
#
# 0 Property and Equipment     Goodwill Intangible assets Deferred income taxes  \
# 0            18639000000  30633000000       15385000000             698000000
#
# 0 Prepaid pension Other assets   NaN Total non current assets   NaN  \
# 0        96000000   2903000000  None              76000000000  None
#
# 0  Total Assets   NaN LIABILITIES AND EQUITY  Current Liabilities  \
# 0  144344000000  None                    None                None
#
# 0 Accounts payable  Short term debt and current portion of long term debt  \
# 0       20322000000                                        12815000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 0                 492000000                                  1339000000
#
# 0 Accrued expenses   NaN Total current liabilities Non Current Liabilities  \
# 0      23812000000  None               58780000000                    None
#
# 0 Long term debt Postretirement benefits other than pensions     Pensions  \
# 0     2659000000                                 18640000000  28915000000
#
# 0 Other liabilities and deferred income taxes   NaN  \
# 0                                 14364000000  None
#
# 0 Total non current liabilities   NaN Total Liabilities  \
# 0                   64578000000  None      123358000000
#
# 0 Commitments and contingencies  Preferred Stock Equity  Old GM  \
# 0                           None      1741000000    None   None
#
# 0 Preferred Stock Preference stock Common Stock General Motors Company  \
# 0            None             None   1017000000                   None
#
# 0 Common Stock Capital surplus  Accumulated deficit  \
# 0      4000000      18787000000           899000000
#
# 0 Accumulated other comprehensive income    NaN Shareholder Equity  \
# 0                               677000000  None        18569000000
#
# 0 Noncontrolling interests   NaN Total equity    NaN  \
# 0                676000000  None   19245000000  None
#
# 0 Total liabilities and equity   NaN
# 0                 144344000000  None
#  This is 0001467858-20-000028 a 10-K document.
# pass anchor check
# k - 10-K    year - 20
# k - 10-K    year - 20
# column used for quarter ['', 'December31, 2019', '', 'December31, 2018']
# new_column used for year ['December31,', '2019', 'December31,', '2018']
# Y - ['2019', '2018']
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# k - 10-K    year - 20
# Shape -  (1, 49)
# 0 Quarter  Year ASSETS Current Assets         Cash  \
# 0      Q4  2019   None           None  19069000000
#
# 0 Marketable debt securities  Accounts and notes receivable   \
# 0                  4174000000                     6797000000
#
# 0 GM Financial receivables    Inventory Other current assets   \
# 0              26601000000  10398000000            7953000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 0          74992000000               None              26355000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 0                                       8562000000            38750000000
#
# 0 Goodwill and intangible assets Property and Equipment  \
# 0                     5337000000            42055000000
#
# 0 Deferred income taxes  Other assets  Total non current assets  Total Assets  \
# 0            24640000000    7346000000             153045000000  228037000000
#
# 0 LIABILITIES AND EQUITY   NaN Current Liabilities Accounts payable   \
# 0                   None  None                None       21018000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 0                                               None      1897000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 0   35503000000         26487000000               84905000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 0                    None            None  12489000000   53435000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 0                                   5935000000  12170000000
#
# 0 Other liabilities  Total non current liabilities Total Liabilities  \
# 0        13146000000                   97175000000      182080000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 0                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 0                26074000000       26860000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 0                          11156000000        41792000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 0               4165000000  45957000000                 228037000000
#  This is 0001193125-10-078119 a 10-K document.
# pass anchor check
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# column used for quarter ['', '', 'December31,2009', '', '', '', '', 'December31,2008', '']
# new_column used for year ['December31,2009', 'December31,2008']
# Y - ['2009', '2008']
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# k - 10-K    year - 10
# Shape -  (1, 71)
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities  \
# 0      Q4  2009   None           None  22679000000             134000000
#
# 0   NaN   Total cash Restricted cash Accounts and notes receivable   \
# 0  None  22813000000     13917000000                     7518000000
#
# 0    Inventory Assets held for sale Property and Equipment  \
# 0  10107000000            388000000             2727000000
#
# 0 Other current assets and deferred income taxes   NaN Total current assets  \
# 0                                     1777000000  None          59247000000
#
# 0 Non Current Assets Restricted cash  \
# 0               None      1489000000
#
# 0 Equity in  assets of nonconsolidated affiliates Assets held for sale  \
# 0                                      7936000000            530000000
#
# 0 Property and Equipment Property and Equipment     Goodwill  \
# 0                3000000            18687000000  30672000000
#
# 0 Intangible assets Deferred income taxes Prepaid pension Other assets   NaN  \
# 0       14547000000             564000000        98000000   2522000000  None
#
# 0 Total non current assets   NaN  Total Assets   NaN LIABILITIES AND EQUITY   \
# 0              77048000000  None  136295000000  None                    None
#
# 0 Current Liabilities Accounts payable   \
# 0                None       18725000000
#
# 0 Short term debt and current portion of long term debt  \
# 0                                        10221000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 0                 355000000                                   846000000
#
# 0 Accrued expenses   NaN Total current liabilities Non Current Liabilities  \
# 0      22288000000  None               52435000000                    None
#
# 0 Long term debt Liabilities held for sale  \
# 0     5562000000                 270000000
#
# 0 Postretirement benefits other than pensions     Pensions  \
# 0                                  8708000000  27086000000
#
# 0 Other liabilities and deferred income taxes   NaN  \
# 0                                 13279000000  None
#
# 0 Total non current liabilities   NaN Total liabilities  \
# 0                   54905000000  None      107340000000
#
# 0 Commitments and contingencies  Preferred Stock Equity  Old GM  \
# 0                           None      6998000000    None   None
#
# 0 Preferred Stock Preference stock Common Stock General Motors Company  \
# 0            None             None   1017000000                   None
#
# 0 Common Stock Capital surplus  Accumulated deficit  \
# 0      5000000      24050000000          4394000000
#
# 0 Accumulated other comprehensive income    NaN Shareholder Equity  \
# 0                              1588000000  None        21249000000
#
# 0 Noncontrolling interests   NaN Total equity    NaN  \
# 0                708000000  None   21957000000  None
#
# 0 Total liabilities and equity   NaN
# 0                 136295000000  None

# %% [markdown]
# # Debugging Logs
# ## Anchor Problem - resolved using regex
# ## Made a function to select the row in df if year is larger.

# %%
explore_dict = {}
for QK, AccNum_list in QorK.items():
    
    #for an_postition, acc_num in enumerate(AccNum_list): 
    if QK== '10-Q':
        Q_new = AccNum_list[0]
        Q_old = AccNum_list[-1]
        explore_dict[QK] = [Q_new, Q_old]

    if QK == '10-K':
        K_new = AccNum_list[0]
        K_old = AccNum_list[-1]
        explore_dict[QK] = [K_new, K_old]

# %%
explore_dict
# Out:
# {'10-Q': ['0001467858-20-000069', '0001193125-10-078123'],
#  '10-K': ['0001467858-20-000028', '0001193125-10-078119']}

# %%
#This works
for QK, N_O in QorK.items():
    
    for an_postition, acc_num in enumerate(N_O):
        year = int(acc_num.split(sep='-')[1])
        print(f'year - {year}')
        pages = master_filings_dict[acc_num]['filing_documents'][QK]['pages_code']
        print('\n', 'This is {} a {} document.'.format(acc_num, QK))
        print(len(pages))
        
        for page in pages: 
            
            if anchor_check(page) and search(r'million', page, flags=re.I):
                print('anchor check')
                # Convert string to BS object
                soup = BeautifulSoup(page, 'html5')

                # Get only the first table in the page.
                for table_num, table in enumerate(soup.find_all('tbody')):
                    
                    if table_num == 0:
                        
                        # then get all the rows in the table.
                        table_rows = soup.findAll('tr')
                       
                        if len( [tr.text for tr in table_rows[0].find_all('td')] ) < 3:
                            del table_rows[0]

                        single_table = []
                        Date_column = []

                        # Loop through each column, adding in three structures to single_table.
                        for tr_post, tr in enumerate(table_rows):
                            td = tr.find_all('td')

                            try: 
                                column = [tr.text.encode('cp1252').decode("utf-8", "ignore") for tr in td]
                                
                            except: 
                                column  =[tr.text.encode('ISO-8859-1').decode("utf-8", "ignore") for tr in td]
                                
#                             print( 'tr_post', tr_post, len(column), column)

                            if QK == '10-Q' and year < 11 or QK == '10-K' and year < 13:
                                
                                if tr_post == 2:

                                    # Quarter Column
                                    col_Q, col_year = Quarter( column, '10-Q' )
                                    single_table.append( col_Q )
                                    # Year Column
                                    single_table.append( col_year )

                                elif tr_post > 1: 
#                                     print(column)
                                    # Features Columns
                                    cleaned_data = cleaning_column( column , 10**6 )
                                    #print(cleaned_data)
                                    if len(cleaned_data) > 10:
                                        del cleaned_data[3]

                                    if cleaned_data == ['']:
                                        break
                                    single_table.append( cleaned_data )
                            else: 

                                if tr_post == 1:

                                    # Quarter Column
                                    col_Q, col_year = Quarter( column, '10-Q' )
                                    single_table.append( col_Q )
                                    # Year Column
                                    single_table.append( col_year )

                                elif tr_post > 1: 
            #                         print(column)
                                    # Features Columns
                                    cleaned_data = cleaning_column( column , 10**6 )
                                    #print(cleaned_data)
                                    if len(cleaned_data) > 10:
                                        del cleaned_data[3]

                                    if cleaned_data == ['']:
                                        break
                                    single_table.append( cleaned_data )
                        print(single_table[1])
                        table_df = pd.DataFrame(single_table)
        #                 print(table_df)
                        table_df = table_df.transpose()
        #                 print(table_df[0])

                table_df.drop(table_df.index[pick_row_del(single_table):], 0, inplace=True)

                table_df.columns = table_df.iloc[0]

                table_df = table_df.drop(table_df.index[0])
                ICD.display(table_df)
            
        else:
            print( '\n', '~'*40, '\n')
# Out:
# year - 20
#
#  This is 0001467858-20-000069 a 10-Q document.
# 53
# anchor check
# column used for quarter ['', 'March31, 2020', '', 'December31, 2019']
# new_column used for year ['March31,', '2020', 'December31,', '2019']
# Y - ['2020', '2019']
# ['Year', '2020', '2019']
# 0 Quarter  Year ASSETS Current Assets         Cash  \
# 1      Q1  2020   None           None  38506000000
#
# 0 Marketable debt securities  Accounts and notes receivable  \
# 1                  7620000000                    7536000000
#
# 0 GM Financial receivables    Inventory Other current assets   \
# 1              26320000000  10799000000            6918000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          97699000000               None              25948000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       7521000000            37969000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5225000000            41296000000           24441000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    6525000000             148925000000  246624000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       20031000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1730000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   43331000000         26200000000               91292000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  28581000000   52858000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5766000000  11505000000       12305000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  111015000000      202307000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                26014000000       25885000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                          11800000000        40113000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               4204000000  44317000000                 246624000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 19
#
#  This is 0001467858-19-000121 a 10-Q document.
# 53
# anchor check
# column used for quarter ['', 'September30, 2019', '', 'December31, 2018']
# new_column used for year ['September30,', '2019', 'December31,', '2018']
# Y - ['2019', '2018']
# ['Year', '2019', '2018']
# 0 Quarter  Year ASSETS Current Assets         Cash  \
# 1      Q3  2019   None           None  20051000000
#
# 0 Marketable debt securities  Accounts and notes receivable  \
# 1                  6725000000                    6924000000
#
# 0 GM Financial receivables    Inventory Other current assets   \
# 1              28017000000  11797000000            7051000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          80565000000               None              25743000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8496000000            37969000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5408000000            42527000000           23783000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    7038000000             150964000000  231529000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       21406000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2890000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   31884000000         28072000000               84252000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12448000000   57244000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5301000000  10223000000       13290000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   98506000000      182758000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25928000000       27609000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8997000000        44554000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               4217000000  48771000000                 231529000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 19
#
#  This is 0001467858-19-000107 a 10-Q document.
# 51
# anchor check
# column used for quarter ['', 'June30, 2019', '', 'December31, 2018']
# new_column used for year ['June30,', '2019', 'December31,', '2018']
# Y - ['2019', '2018']
# ['Year', '2019', '2018']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2019   None           None  17072000000             7049000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10362000000              27925000000  11447000000
#
# 0 Other current assets  Total current assets Non current Assets  \
# 1            7451000000          81306000000               None
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              26264000000                                       8340000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            38188000000                     5457000000
#
# 0 Property and Equipment Deferred income taxes Other assets   \
# 1            42938000000           23987000000    7257000000
#
# 0 Total non current assets  Total Assets   NaN LIABILITIES AND EQUITY  \
# 1             152431000000  233737000000  None                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       22717000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2490000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   30659000000         28428000000               84294000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12957000000   60455000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5357000000  10791000000       12794000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  102354000000      186648000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25765000000       25807000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8770000000        42816000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               4273000000  47089000000                 233737000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 19
#
#  This is 0001467858-19-000084 a 10-Q document.
# 46
# anchor check
# column used for quarter ['', 'March31, 2019', '', 'December31, 2018']
# new_column used for year ['March31,', '2019', 'December31,', '2018']
# Y - ['2019', '2018']
# ['Year', '2019', '2018']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2019   None           None  17176000000             6021000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   12116000000              27230000000  11108000000
#
# 0 Other current assets  Total current assets Non current Assets  \
# 1            6439000000          80090000000               None
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              25448000000                                       8266000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            38336000000                     5518000000
#
# 0 Property and Equipment Deferred income taxes Other assets   \
# 1            43052000000           24303000000    8119000000
#
# 0 Total non current assets  Total Assets   NaN LIABILITIES AND EQUITY  \
# 1             153042000000  233132000000  None                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       24560000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1999000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   31273000000         27471000000               85303000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12954000000   60858000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5363000000  11099000000       12917000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  103191000000      188494000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25661000000       23939000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8849000000        40765000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               3873000000  44638000000                 233132000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 18
#
#  This is 0001467858-18-000104 a 10-Q document.
# 55
# anchor check
# column used for quarter ['', 'September30, 2018', '', 'December31, 2017']
# new_column used for year ['September30,', '2018', 'December31,', '2017']
# Y - ['2018', '2017']
# ['Year', '2018', '2017']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2018   None           None  18435000000             5916000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10376000000              23432000000  11334000000
#
# 0 Property and Equipment Other current assets  Total current assets  \
# 1              474000000            4881000000          74848000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              24086000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9155000000            38655000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5651000000            44128000000           23242000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    5946000000             150863000000  225711000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       25147000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2915000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   27950000000         28104000000               84116000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  13048000000   58427000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5832000000  11119000000       12261000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  100687000000      184803000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25503000000       20865000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8321000000        38061000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               2847000000  40908000000                 225711000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 18
#
#  This is 0001467858-18-000089 a 10-Q document.
# 56
# anchor check
# column used for quarter ['', 'June30, 2018', '', 'December31, 2017']
# new_column used for year ['June30,', '2018', 'December31,', '2017']
# Y - ['2018', '2017']
# ['Year', '2018', '2017']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2018   None           None  15087000000             6924000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                    9663000000              22005000000  10833000000
#
# 0 Property and Equipment Other current assets  Total current assets  \
# 1              690000000            5249000000          70451000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              22996000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8788000000            38003000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5720000000            44054000000           23285000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    5344000000             148190000000  218641000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       24660000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2807000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   25457000000         27368000000               80292000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  11012000000   58983000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5853000000  11989000000       11876000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   99713000000      180005000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25465000000       18873000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8171000000        36181000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               2455000000  38636000000                 218641000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 18
#
#  This is 0001467858-18-000068 a 10-Q document.
# 49
# anchor check
# column used for quarter ['', 'March31, 2018', '', 'December31, 2017']
# new_column used for year ['March31,', '2018', 'December31,', '2017']
# Y - ['2018', '2017']
# ['Year', '2018', '2017']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2018   None           None  14256000000             7110000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10769000000              21157000000  11461000000
#
# 0 Property and Equipment Other current assets  Total current assets  \
# 1              789000000            5893000000          71435000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              22146000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9883000000            37321000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5790000000            43444000000           23538000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    5169000000             147291000000  218726000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       26039000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      4341000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   25006000000         27330000000               82716000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  10957000000   58514000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5927000000  13209000000       11945000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  100552000000      183268000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25337000000       17028000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8081000000        34298000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               1160000000  35458000000                 218726000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 17
#
#  This is 0001467858-17-000133 a 10-Q document.
# 54
# anchor check
# column used for quarter ['', 'September30, 2017', '', 'December31, 2016']
# new_column used for year ['September30,', '2017', 'December31,', '2016']
# Y - ['2017', '2016']
# ['Year', '2017', '2016']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2017   None           None  12792000000             8454000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10013000000              19399000000  11789000000
#
# 0 Property and Equipment Other current assets  Current assets held for sale   \
# 1             1632000000            4909000000                    7630000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          76618000000               None              21021000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8820000000            35178000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5854000000            41775000000           30723000000
#
# 0 Other assets  Non current assets held for sale  Total non current assets  \
# 1    5005000000                        4508000000             152884000000
#
# 0  Total Assets   NaN LIABILITIES AND EQUITY Current Liabilities  \
# 1  229502000000  None                   None                None
#
# 0 Accounts payable  Short term debt and current portion of long term debt   \
# 1       23265000000                                               None
#
# 0  Automotive GM Financial  Accrued Liabilities  \
# 1  1127000000   24480000000         26603000000
#
# 0 Current liabilities held for sale  Total current liabilities  \
# 1                         6374000000               81849000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12508000000   54558000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5758000000  14119000000       12743000000
#
# 0 Non current liabilities held for sale  Total non current liabilities  \
# 1                             4490000000                  104176000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Common Stock  \
# 1      186025000000                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25782000000       24230000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7783000000        42243000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               1234000000  43477000000                 229502000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 17
#
#  This is 0001467858-17-000103 a 10-Q document.
# 53
# anchor check
# column used for quarter ['', 'June30, 2017', '', 'December31, 2016']
# new_column used for year ['June30,', '2017', 'December31,', '2016']
# Y - ['2017', '2016']
# ['Year', '2017', '2016']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2017   None           None  16598000000             9133000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                    9796000000              19296000000  11289000000
#
# 0 Property and Equipment Other current assets  Current assets held for sale   \
# 1             1883000000            4324000000                   12762000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          85081000000               None              20137000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8248000000            34301000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5989000000            39725000000           32425000000
#
# 0 Other assets  Non current assets held for sale  Total non current assets  \
# 1    3994000000                       10400000000             155219000000
#
# 0  Total Assets LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1  240300000000                   None                None       23404000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1066000000
#
# 0 GM Financial  Accrued Liabilities Current liabilities held for sale   \
# 1   28942000000         26601000000                        14293000000
#
# 0 Total current liabilities Non current Liabilities Long term debt   \
# 1               94306000000                    None            None
#
# 0  Automotive GM Financial  Postretirement benefits other than pensions   \
# 1  9544000000   49537000000                                   5750000000
#
# 0    Pensions  Other liabilities Non current liabilities held for sale   \
# 1  14777000000       12438000000                             8223000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  100269000000      194575000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                26328000000       28547000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           9369000000        45521000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                204000000  45725000000                 240300000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 17
#
#  This is 0001467858-17-000070 a 10-Q document.
# 46
# anchor check
# column used for quarter ['', 'March31, 2017', '', 'December31, 2016']
# new_column used for year ['March31,', '2017', 'December31,', '2016']
# Y - ['2017', '2016']
# ['Year', '2017', '2016']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2017   None           None  12864000000            10260000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10898000000              23903000000  14686000000
#
# 0 Property and Equipment Other current assets Total current assets  \
# 1             2283000000           4704000000          79598000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              22540000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9416000000            37202000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     6193000000            37302000000           34263000000
#
# 0 Other assets Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1   4279000000             151195000000  230793000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       28725000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1350000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   32351000000         28478000000               90904000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9602000000   47598000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5771000000  17636000000       13068000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   93675000000      184579000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27012000000       28195000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           9250000000        45972000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                242000000  46214000000                 230793000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 16
#
#  This is 0001467858-16-000363 a 10-Q document.
# 49
# anchor check
# column used for quarter ['', 'September30, 2016', '', 'December31, 2015']
# new_column used for year ['September30,', '2016', 'December31,', '2015']
# Y - ['2016', '2015']
# ['Year', '2016', '2015']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2016   None           None  15932000000             8172000000
#
# 0 Restricted cash  Accounts and notes receivable GM Financial receivables  \
# 1       1644000000                   10737000000              20495000000
#
# 0    Inventory Property and Equipment Other current assets  \
# 1  15427000000             2055000000           2034000000
#
# 0 Total current assets Non current Assets Restricted cash   \
# 1          76496000000               None        581000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              20299000000                                       8645000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            34713000000                     6354000000
#
# 0 Property and Equipment Deferred income taxes  Other assets  \
# 1            31775000000            35025000000   3688000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             141080000000  217576000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       28628000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1012000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   24362000000         28533000000               82535000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9740000000   43986000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5621000000  17595000000       13084000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   90026000000      172561000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27241000000       25417000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7953000000        44720000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                295000000  45015000000                 217576000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 16
#
#  This is 0001467858-16-000341 a 10-Q document.
# 48
# anchor check
# column used for quarter ['', 'June30, 2016', '', 'December31, 2015']
# new_column used for year ['June30,', '2016', 'December31,', '2015']
# Y - ['2016', '2015']
# ['Year', '2016', '2015']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2016   None           None  18923000000             4247000000
#
# 0 Restricted cash  Accounts and notes receivable GM Financial receivables  \
# 1       1595000000                   10461000000              19800000000
#
# 0    Inventory Property and Equipment Other current assets  \
# 1  15026000000             2505000000           2073000000
#
# 0 Total current assets Non current Assets Restricted cash   \
# 1          74630000000               None        603000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              19309000000                                       8198000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            33510000000                     6433000000
#
# 0 Property and Equipment Deferred income taxes  Other assets  \
# 1            28442000000            35627000000   3697000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             135819000000  210449000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       26959000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1031000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   20199000000         27854000000               76043000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9789000000   44301000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5675000000  17939000000       12699000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   90403000000      166446000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27734000000       23785000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7905000000        43630000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                373000000  44003000000                 210449000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 16
#
#  This is 0001467858-16-000317 a 10-Q document.
# 43
# anchor check
# column used for quarter ['', 'March31, 2016', '', 'December31, 2015']
# new_column used for year ['March31,', '2016', 'December31,', '2015']
# Y - ['2016', '2015']
# ['Year', '2016', '2015']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2016   None           None  14894000000             6537000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable  \
# 1                                 1716000000                    8988000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              19225000000  15817000000             2199000000
#
# 0 Other current assets Total current assets Non current Assets  \
# 1           1658000000          71034000000               None
#
# 0 Restricted cash and marketable securities  GM Financial receivables  \
# 1                                  639000000              19145000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9640000000            32652000000
#
# 0 Goodwill and intangible assets Property and Equipment  \
# 1                     5891000000            24538000000
#
# 0 Deferred income taxes  Other assets Total non current assets  Total Assets  \
# 1            36374000000   3705000000             132584000000  203618000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       26766000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      832000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   20756000000         26633000000               74987000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9946000000   39615000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5720000000  19245000000       12780000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   87306000000      162293000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27463000000       21508000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8054000000        40932000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                393000000  41325000000                 203618000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 15
#
#  This is 0001467858-15-000217 a 10-Q document.
# 53
# anchor check
# column used for quarter ['', 'September30, 2015', '', 'December31, 2014']
# new_column used for year ['September30,', '2015', 'December31,', '2014']
# Y - ['2015', '2014']
# ['Year', '2015', '2014']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2015   None           None  15433000000             8029000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1519000000                    10486000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              17217000000  14368000000             4596000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9208000000           1485000000          82341000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  593000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              17671000000                                       8872000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            29381000000                     6083000000
#
# 0 Property and Equipment Deferred income taxes Other assets  \
# 1            16915000000           24799000000   2345000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             106659000000  189000000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       25188000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      641000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   16361000000         30549000000               72739000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  8503000000   31898000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5959000000  21618000000       13148000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   81126000000      153865000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27744000000       14912000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8034000000        34638000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                497000000  35135000000                 189000000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 15
#
#  This is 0001467858-15-000175 a 10-Q document.
# 52
# anchor check
# column used for quarter ['', 'June30, 2015', '', 'December31, 2014']
# new_column used for year ['June30,', '2015', 'December31,', '2014']
# Y - ['2015', '2014']
# ['Year', '2015', '2014']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2015   None           None  17627000000             7200000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1442000000                    10604000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              16932000000  14218000000             5722000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9289000000           1520000000          84554000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  623000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              17277000000                                       8403000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            28431000000                     6181000000
#
# 0 Property and Equipment Deferred income taxes Other assets  \
# 1            12904000000           24998000000   2441000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             101258000000  185812000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       24247000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      462000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   13941000000         30878000000               69528000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  8725000000   30389000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   6075000000  22177000000       13248000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   80614000000      150142000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                28161000000       14512000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7543000000        35146000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                524000000  35670000000                 185812000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 15
#
#  This is 0001467858-15-000122 a 10-Q document.
# 48
# anchor check
# column used for quarter ['', 'March31, 2015', '', 'December31, 2014']
# new_column used for year ['March31,', '2015', 'December31,', '2014']
# Y - ['2015', '2014']
# ['Year', '2015', '2014']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2015   None           None  15776000000             8409000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1414000000                    11569000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              16127000000  14051000000             4563000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9704000000           1618000000          83231000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  625000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              16180000000                                       9756000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            27755000000                     6297000000
#
# 0 Property and Equipment Deferred income taxes Other assets  \
# 1             8939000000           24782000000   2353000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1              96687000000  179918000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       25187000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      411000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   13940000000         27804000000               67342000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  8722000000   25185000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   6089000000  22206000000       13551000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   75753000000      143095000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                28819000000       14825000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7331000000        36329000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                494000000  36823000000                 179918000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 14
#
#  This is 0001467858-14-000247 a 10-Q document.
# 60
# anchor check
# column used for quarter ['', 'September30, 2014', '', 'December31, 2013']
# new_column used for year ['September30,', '2014', 'December31,', '2013']
# Y - ['2014', '2013']
# ['Year', '2014', '2013']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2014   None           None  18060000000             9570000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1375000000                    10892000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              15660000000  15210000000             4044000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9978000000           1851000000          86640000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  915000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              15604000000                                       7983000000
#
# 0 Property and Equipment    Goodwill Intangible assets Property and Equipment  \
# 1            27375000000  1559000000        5085000000             5796000000
#
# 0 Deferred income taxes Other assets Total non current assets  Total Assets  \
# 1           23574000000   2377000000              90268000000  176908000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       24773000000
#
# 0 Short term debt and current portion of long term debt  Automotive   \
# 1                                               None       578000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   12808000000         29170000000               67329000000
#
# 0 Non current Liabilities Long term debt  Automotive  GM Financial   \
# 1                    None            None  6753000000   20966000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   5815000000  18111000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 14371000000                   66016000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Preferred Stock  \
# 1      133345000000                           None    None      3109000000
#
# 0 Common Stock Additional paid in capital Retained Earnings  \
# 1     16000000                28832000000       13975000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           2930000000        43002000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                561000000  43563000000                 176908000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 14
#
#  This is 0001467858-14-000213 a 10-Q document.
# 60
# anchor check
# column used for quarter ['', 'June30, 2014', '', 'December31, 2013']
# new_column used for year ['June30,', '2014', 'December31,', '2013']
# Y - ['2014', '2013']
# ['Year', '2014', '2013']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2014   None           None  19864000000             9935000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1325000000                    11480000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              15797000000  15200000000             4633000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1           11499000000           1910000000          91643000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  969000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              15430000000                                       7485000000
#
# 0 Property and Equipment    Goodwill Intangible assets Property and Equipment  \
# 1            27023000000  1573000000        5220000000             4748000000
#
# 0 Deferred income taxes Other assets Total non current assets  Total Assets  \
# 1           22582000000   2425000000              87455000000  179098000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       26992000000
#
# 0 Short term debt and current portion of long term debt  Automotive   \
# 1                                               None       610000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   15193000000         29552000000               72347000000
#
# 0 Non current Liabilities Long term debt  Automotive  GM Financial   \
# 1                    None            None  6864000000   17409000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   5826000000  19068000000
#
# ...
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              14278000000  14039000000             2398000000
#
# 0 Deferred income taxes  Other current assets Total current assets  \
# 1            10349000000           1662000000          81501000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  829000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              14354000000                                       8094000000
#
# 0 Property and Equipment   Goodwill  Intangible assets Property and Equipment  \
# 1            25867000000  1560000000        5668000000             3383000000
#
# 0 Deferred income taxes  Other assets Total non current assets  Total Assets  \
# 1            22736000000   2352000000              84843000000  166344000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       23621000000
#
# 0 Short term debt and current portion of long term debt  Automotive   \
# 1                                               None       564000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   13594000000         24633000000               62412000000
#
# 0 Non current Liabilities Long term debt  Automotive  GM Financial   \
# 1                    None            None  6573000000   15452000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   5897000000  19483000000
#
# 0 Other liabilities and deferred income taxes  Total non current liabilities  \
# 1                                  13353000000                   60758000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Preferred Stock  \
# 1      123170000000                           None    None            None
#
# 0    Series A    Series B Common Stock Additional paid in capital  \
# 1  3109000000  4855000000     15000000                28780000000
#
# 0 Retained Earnings Accumulated other comprehensive loss Shareholder Equity  \
# 1       13816000000                           3113000000        42607000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                567000000  43174000000                 166344000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 13
#
#  This is 0001467858-13-000025 a 10-K document.
# 184
# anchor check
# column used for quarter ['', 'December31, 2012', '', 'December31, 2011']
# new_column used for year ['December31,', '2012', 'December31,', '2011']
# Y - ['2012', '2011']
# ['Year', '2012', '2011']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities  \
# 1      Q4  2012   None           None  18422000000            8988000000
#
# 0 Restricted cash and marketable securities Accounts and notes receivable   \
# 1                                 686000000                    10395000000
#
# 0 GM Financial finance receivables    Inventory Property and Equipment  \
# 1                       4044000000  14714000000             1782000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9429000000           1536000000          69996000000
#
# 0 Non current Assets Restricted cash and marketable securities  \
# 1               None                                 682000000
#
# 0 GM Financial finance receivables  \
# 1                       6954000000
#
# 0 Equity in  assets of nonconsolidated affiliates Property and Equipment  \
# 1                                      6883000000            24196000000
#
# 0    Goodwill Intangible assets Property and Equipment Deferred income taxes  \
# 1  1973000000        6809000000             1649000000           27922000000
#
# 0 Other assets Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1   2358000000              79426000000  149422000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       25166000000
#
# 0 Short term debt and current portion of long term debt Automotive   \
# 1                                               None     1748000000
#
# 0 GM Financial Accrued Liabilities Total current liabilities  \
# 1   3770000000         23308000000               53992000000
#
# 0 Non current Liabilities Long term debt Automotive  GM Financial  \
# 1                    None           None  3424000000   7108000000
#
# 0 Postretirement benefits other than pensions     Pensions  \
# 1                                  7309000000  27420000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 13169000000                   58430000000
#
# 0 Total Liabilities Commitments and contingencies  Equity Preferred Stock  \
# 1      112422000000                           None   None            None
#
# 0   Series A    Series B  Common Stock Capital surplus  Retained Earnings  \
# 1  5536000000  4855000000     14000000      23834000000       10057000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8052000000        36244000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                756000000  37000000000                 149422000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 12
#
#  This is 0001467858-12-000014 a 10-K document.
# 217
# anchor check
# column used for quarter ['', 'December31, 2011', '', 'December31, 2010']
# new_column used for year ['December31,', '2011', 'December31,', '2010']
# Y - ['2011', '2010']
# ['Year', '2011', '2010']
# 0 Quarter  Year ASSETS Automotive Current Assets         Cash  \
# 1      Q4  2011   None                      None  15499000000
#
# 0 Marketable securities Restricted cash and marketable securities  \
# 1           16148000000                                 206000000
#
# 0 Accounts and notes receivable     Inventory Property and Equipment  \
# 1                     9949000000  14324000000             2464000000
#
# 0 Other current assets and deferred income taxes Total current assets  \
# 1                                     1657000000          60247000000
#
# 0 Automotive Non current Assets Restricted cash and marketable securities  \
# 1                          None                                 912000000
#
# 0 Equity in  assets of nonconsolidated affiliates Property and Equipment  \
# 1                                      6790000000            22957000000
#
# 0     Goodwill Intangible assets Other assets and deferred income taxes  \
# 1  27741000000       10013000000                             2900000000
#
# 0 Total non current assets Total Automotive Assets GM Financial Assets  \
# 1              71313000000            131560000000                None
#
# 0 Finance receivables Restricted cash    Goodwill Other assets   \
# 1          9162000000      1115000000  1278000000    1488000000
#
# 0 Total GM Financial Assets  Total Assets LIABILITIES AND EQUITY  \
# 1               13043000000  144603000000                   None
#
# 0 Automotive Current Liabilities Accounts payable   \
# 1                           None       24494000000
#
# 0 Short term debt and current portion of long term debt  Accrued Liabilities  \
# 1                                         1682000000             22756000000
#
# 0 Total current liabilities Automotive Non current Liabilities  \
# 1               48932000000                               None
#
# 0 Long term debt  Postretirement benefits other than pensions     Pensions  \
# 1      3613000000                                  6836000000  25075000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 12336000000                   47860000000
#
# 0 Total Automotive Liabilities GM Financial Liabilities  \
# 1                  96792000000                     None
#
# 0 Securitization notes payable  Credit facilities Other liabilities  \
# 1                    6938000000        1099000000         783000000
#
# 0 Total GM Financial Liabilities Total Liabilities  \
# 1                     8820000000      105612000000
#
# 0 Commitments and contingencies  Equity Preferred Stock   Series A   \
# 1                           None   None            None  5536000000
#
# 0   Series B  Common Stock Capital surplus  Retained Earnings  \
# 1  4855000000     16000000      26391000000        7183000000
#
# 0 Accumulated other comprehensive income  Shareholder Equity  \
# 1                              5861000000        38120000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                871000000  38991000000                 144603000000
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 11
#
#  This is 0001193125-11-051462 a 10-K document.
# 327
# anchor check
# column used for quarter ['', '', 'December31,2010', '', '', 'December31,2009', '']
# new_column used for year ['December31,2010', 'December31,2009']
# Y - ['2010', '2009']
# ['Year', '2010', '2009']
# 0 Quarter  Year ASSETS Automotive Current Assets         Cash  \
# 1      Q4  2010   None                      None  21061000000
#
# 0 Marketable securities   NaN   Total cash  \
# 1            5555000000  None  26616000000
#
# 0 Restricted cash and marketable securities Accounts and notes receivable   \
# 1                                1240000000                     8699000000
#
# 0    Inventory Assets held for sale Property and Equipment  \
# 1  12125000000            388000000             2568000000
#
# 0 Other current assets and deferred income taxes   NaN Total current assets  \
# 1                                     1805000000  None          53053000000
#
# 0 Automotive Non current Assets Restricted cash and marketable securities  \
# 1                          None                                1160000000
#
# 0 Equity in  assets of nonconsolidated affiliates Property and Equipment  \
# 1                                      8529000000            19235000000
#
# 0     Goodwill Intangible assets Deferred income taxes Assets held for sale  \
# 1  30513000000       11882000000             308000000            530000000
#
# 0 Other assets   NaN Total non current assets   NaN Total Automotive Assets  \
# 1   3286000000  None              74913000000  None            127966000000
#
# 0 GM Financial Assets Finance receivables \nNote7) Restricted cash  \
# 1                None                   8197000000      1090000000
#
# 0    Goodwill Other assets   NaN Total GM Financial Assets   NaN  \
# 1  1265000000    380000000  None               10932000000  None
#
# 0  Total Assets   NaN LIABILITIES AND EQUITY Automotive Current Liabilities  \
# 1  138898000000  None                   None                           None
#
# 0 Accounts payable   \
# 1       21497000000
#
# 0 Short term debt and current portion of long term debt \n17)  \
# 1                                         1616000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 1                 355000000                                   625000000
#
# 0 Accrued Liabilities   NaN Total current liabilities  \
# 1         23419000000  None               47157000000
#
# 0 Automotive Non current Liabilities Long term debt   \
# 1                               None      3014000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 1                 270000000                                  9294000000
#
# 0     Pensions Other liabilities and deferred income taxes   NaN  \
# 1  21894000000                                 13021000000  None
#
# 0 Total non current liabilities   NaN Total Automotive Liabilities  \
# 1                   47223000000  None                  94380000000
#
# 0 GM Financial Liabilities Securitization notes payable  Credit facilities  \
# 1                     None                    6128000000         832000000
#
# 0 Other liabilities   NaN Total GM Financial Liabilities   NaN  \
# 1         399000000  None                     7359000000  None
#
# 0 Total Liabilities Commitments and contingencies  Preferred Stock Equity  \
# 1      101739000000                           None      6998000000   None
#
# 0 Preferred Stock Series A \n2010) Series B \n2010) Common Stock  \
# 1            None       5536000000       4855000000     15000000
#
# 0 Capital surplus  Retained Earnings Accumulated other comprehensive income  \
# 1      24257000000         266000000                             1251000000
#
# 0   NaN Shareholder Equity Noncontrolling interests   NaN Total equity   NaN  \
# 1  None        36180000000                979000000  None  37159000000  None
#
# 0 Total liabilities and equity   NaN
# 1                 138898000000  None
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# year - 10
#
#  This is 0001193125-10-078119 a 10-K document.
# 343
# anchor check
# column used for quarter ['', '', 'December31,2009', '', '', '', '', 'December31,2008', '']
# new_column used for year ['December31,2009', 'December31,2008']
# Y - ['2009', '2008']
# ['Year', '2009', '2008']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities  \
# 1      Q4  2009   None           None  22679000000             134000000
#
# 0   NaN   Total cash Restricted cash Accounts and notes receivable   \
# 1  None  22813000000     13917000000                     7518000000
#
# 0    Inventory Assets held for sale Property and Equipment  \
# 1  10107000000            388000000             2727000000
#
# 0 Other current assets and deferred income taxes   NaN Total current assets  \
# 1                                     1777000000  None          59247000000
#
# 0 Non Current Assets Restricted cash  \
# 1               None      1489000000
#
# 0 Equity in  assets of nonconsolidated affiliates Assets held for sale  \
# 1                                      7936000000            530000000
#
# 0 Property and Equipment Property and Equipment     Goodwill  \
# 1                3000000            18687000000  30672000000
#
# 0 Intangible assets Deferred income taxes Prepaid pension Other assets   NaN  \
# 1       14547000000             564000000        98000000   2522000000  None
#
# 0 Total non current assets   NaN  Total Assets   NaN LIABILITIES AND EQUITY   \
# 1              77048000000  None  136295000000  None                    None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       18725000000
#
# 0 Short term debt and current portion of long term debt  \
# 1                                        10221000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 1                 355000000                                   846000000
#
# 0 Accrued expenses   NaN Total current liabilities Non Current Liabilities  \
# 1      22288000000  None               52435000000                    None
#
# 0 Long term debt Liabilities held for sale  \
# 1     5562000000                 270000000
#
# 0 Postretirement benefits other than pensions     Pensions  \
# 1                                  8708000000  27086000000
#
# 0 Other liabilities and deferred income taxes   NaN  \
# 1                                 13279000000  None
#
# 0 Total non current liabilities   NaN Total liabilities  \
# 1                   54905000000  None      107340000000
#
# 0 Commitments and contingencies  Preferred Stock Equity  Old GM  \
# 1                           None      6998000000    None   None
#
# 0 Preferred Stock Preference stock Common Stock General Motors Company  \
# 1            None             None   1017000000                   None
#
# 0 Common Stock Capital surplus  Accumulated deficit  \
# 1      5000000      24050000000          4394000000
#
# 0 Accumulated other comprehensive income    NaN Shareholder Equity  \
# 1                              1588000000  None        21249000000
#
# 0 Noncontrolling interests   NaN Total equity    NaN  \
# 1                708000000  None   21957000000  None
#
# 0 Total liabilities and equity   NaN
# 1                 136295000000  None
#  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# # Save Files Locally.

# %%
Checklist = {}

for k, v in QorK.items():
    value_list = []
    for i, vv in enumerate(v):

        pages = master_filings_dict[v[i]]['filing_documents'][k]['pages_code']

        try:
            # Extract Table from html code and wrap it as a list of df.
            table_df = table(pages, k)                 
            ICD.display(table_df[0])

            with open('{}-{}.csv'.format(v[i], k), "wb") as fp:   # Pickling
                pickle.dump(table_df, fp)
                
            # display a status to the user.
            print('All the pages from {} document {} have been tableized and saved.'.format(k, v[i]))
        
        except: 
            value_list.append(vv)
            print('Something went wrong in file {}, file type = {}'.format(v[i], k))
        
        print('-'*80) 
    Checklist['{}'.format(k)] = value_list
    del value_list
# Out:
# pass anchor check
# column used for quarter ['', 'March31, 2020', '', 'December31, 2019']
# new_column used for year ['March31,', '2020', 'December31,', '2019']
# Y - ['2020', '2019']
# 0 Quarter  Year ASSETS Current Assets         Cash  \
# 1      Q1  2020   None           None  38506000000
#
# 0 Marketable debt securities  Accounts and notes receivable  \
# 1                  7620000000                    7536000000
#
# 0 GM Financial receivables    Inventory Other current assets   \
# 1              26320000000  10799000000            6918000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          97699000000               None              25948000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       7521000000            37969000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5225000000            41296000000           24441000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    6525000000             148925000000  246624000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       20031000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1730000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   43331000000         26200000000               91292000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  28581000000   52858000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5766000000  11505000000       12305000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  111015000000      202307000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                26014000000       25885000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                          11800000000        40113000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               4204000000  44317000000                 246624000000
# All the pages from 10-Q document 0001467858-20-000069 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'September30, 2019', '', 'December31, 2018']
# new_column used for year ['September30,', '2019', 'December31,', '2018']
# Y - ['2019', '2018']
# 0 Quarter  Year ASSETS Current Assets         Cash  \
# 1      Q3  2019   None           None  20051000000
#
# 0 Marketable debt securities  Accounts and notes receivable  \
# 1                  6725000000                    6924000000
#
# 0 GM Financial receivables    Inventory Other current assets   \
# 1              28017000000  11797000000            7051000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          80565000000               None              25743000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8496000000            37969000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5408000000            42527000000           23783000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    7038000000             150964000000  231529000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       21406000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2890000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   31884000000         28072000000               84252000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12448000000   57244000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5301000000  10223000000       13290000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   98506000000      182758000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25928000000       27609000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8997000000        44554000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               4217000000  48771000000                 231529000000
# All the pages from 10-Q document 0001467858-19-000121 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'June30, 2019', '', 'December31, 2018']
# new_column used for year ['June30,', '2019', 'December31,', '2018']
# Y - ['2019', '2018']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2019   None           None  17072000000             7049000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10362000000              27925000000  11447000000
#
# 0 Other current assets  Total current assets Non current Assets  \
# 1            7451000000          81306000000               None
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              26264000000                                       8340000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            38188000000                     5457000000
#
# 0 Property and Equipment Deferred income taxes Other assets   \
# 1            42938000000           23987000000    7257000000
#
# 0 Total non current assets  Total Assets   NaN LIABILITIES AND EQUITY  \
# 1             152431000000  233737000000  None                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       22717000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2490000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   30659000000         28428000000               84294000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12957000000   60455000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5357000000  10791000000       12794000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  102354000000      186648000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25765000000       25807000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8770000000        42816000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               4273000000  47089000000                 233737000000
# All the pages from 10-Q document 0001467858-19-000107 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'March31, 2019', '', 'December31, 2018']
# new_column used for year ['March31,', '2019', 'December31,', '2018']
# Y - ['2019', '2018']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2019   None           None  17176000000             6021000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   12116000000              27230000000  11108000000
#
# 0 Other current assets  Total current assets Non current Assets  \
# 1            6439000000          80090000000               None
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              25448000000                                       8266000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            38336000000                     5518000000
#
# 0 Property and Equipment Deferred income taxes Other assets   \
# 1            43052000000           24303000000    8119000000
#
# 0 Total non current assets  Total Assets   NaN LIABILITIES AND EQUITY  \
# 1             153042000000  233132000000  None                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       24560000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1999000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   31273000000         27471000000               85303000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12954000000   60858000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5363000000  11099000000       12917000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  103191000000      188494000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25661000000       23939000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8849000000        40765000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               3873000000  44638000000                 233132000000
# All the pages from 10-Q document 0001467858-19-000084 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'September30, 2018', '', 'December31, 2017']
# new_column used for year ['September30,', '2018', 'December31,', '2017']
# Y - ['2018', '2017']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2018   None           None  18435000000             5916000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10376000000              23432000000  11334000000
#
# 0 Property and Equipment Other current assets  Total current assets  \
# 1              474000000            4881000000          74848000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              24086000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9155000000            38655000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5651000000            44128000000           23242000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    5946000000             150863000000  225711000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       25147000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2915000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   27950000000         28104000000               84116000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  13048000000   58427000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5832000000  11119000000       12261000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  100687000000      184803000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25503000000       20865000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8321000000        38061000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               2847000000  40908000000                 225711000000
# All the pages from 10-Q document 0001467858-18-000104 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'June30, 2018', '', 'December31, 2017']
# new_column used for year ['June30,', '2018', 'December31,', '2017']
# Y - ['2018', '2017']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2018   None           None  15087000000             6924000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                    9663000000              22005000000  10833000000
#
# 0 Property and Equipment Other current assets  Total current assets  \
# 1              690000000            5249000000          70451000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              22996000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8788000000            38003000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5720000000            44054000000           23285000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    5344000000             148190000000  218641000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       24660000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2807000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   25457000000         27368000000               80292000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  11012000000   58983000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5853000000  11989000000       11876000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   99713000000      180005000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25465000000       18873000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8171000000        36181000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               2455000000  38636000000                 218641000000
# All the pages from 10-Q document 0001467858-18-000089 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'March31, 2018', '', 'December31, 2017']
# new_column used for year ['March31,', '2018', 'December31,', '2017']
# Y - ['2018', '2017']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2018   None           None  14256000000             7110000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10769000000              21157000000  11461000000
#
# 0 Property and Equipment Other current assets  Total current assets  \
# 1              789000000            5893000000          71435000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              22146000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9883000000            37321000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5790000000            43444000000           23538000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    5169000000             147291000000  218726000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       26039000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      4341000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   25006000000         27330000000               82716000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  10957000000   58514000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5927000000  13209000000       11945000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  100552000000      183268000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25337000000       17028000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8081000000        34298000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               1160000000  35458000000                 218726000000
# All the pages from 10-Q document 0001467858-18-000068 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'September30, 2017', '', 'December31, 2016']
# new_column used for year ['September30,', '2017', 'December31,', '2016']
# Y - ['2017', '2016']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2017   None           None  12792000000             8454000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10013000000              19399000000  11789000000
#
# 0 Property and Equipment Other current assets  Current assets held for sale   \
# 1             1632000000            4909000000                    7630000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          76618000000               None              21021000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8820000000            35178000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5854000000            41775000000           30723000000
#
# 0 Other assets  Non current assets held for sale  Total non current assets  \
# 1    5005000000                        4508000000             152884000000
#
# 0  Total Assets   NaN LIABILITIES AND EQUITY Current Liabilities  \
# 1  229502000000  None                   None                None
#
# 0 Accounts payable  Short term debt and current portion of long term debt   \
# 1       23265000000                                               None
#
# 0  Automotive GM Financial  Accrued Liabilities  \
# 1  1127000000   24480000000         26603000000
#
# 0 Current liabilities held for sale  Total current liabilities  \
# 1                         6374000000               81849000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12508000000   54558000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5758000000  14119000000       12743000000
#
# 0 Non current liabilities held for sale  Total non current liabilities  \
# 1                             4490000000                  104176000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Common Stock  \
# 1      186025000000                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25782000000       24230000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7783000000        42243000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               1234000000  43477000000                 229502000000
# All the pages from 10-Q document 0001467858-17-000133 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'June30, 2017', '', 'December31, 2016']
# new_column used for year ['June30,', '2017', 'December31,', '2016']
# Y - ['2017', '2016']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2017   None           None  16598000000             9133000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                    9796000000              19296000000  11289000000
#
# 0 Property and Equipment Other current assets  Current assets held for sale   \
# 1             1883000000            4324000000                   12762000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          85081000000               None              20137000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8248000000            34301000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5989000000            39725000000           32425000000
#
# 0 Other assets  Non current assets held for sale  Total non current assets  \
# 1    3994000000                       10400000000             155219000000
#
# 0  Total Assets LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1  240300000000                   None                None       23404000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1066000000
#
# 0 GM Financial  Accrued Liabilities Current liabilities held for sale   \
# 1   28942000000         26601000000                        14293000000
#
# 0 Total current liabilities Non current Liabilities Long term debt   \
# 1               94306000000                    None            None
#
# 0  Automotive GM Financial  Postretirement benefits other than pensions   \
# 1  9544000000   49537000000                                   5750000000
#
# 0    Pensions  Other liabilities Non current liabilities held for sale   \
# 1  14777000000       12438000000                             8223000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  100269000000      194575000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                26328000000       28547000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           9369000000        45521000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                204000000  45725000000                 240300000000
# All the pages from 10-Q document 0001467858-17-000103 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'March31, 2017', '', 'December31, 2016']
# new_column used for year ['March31,', '2017', 'December31,', '2016']
# Y - ['2017', '2016']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2017   None           None  12864000000            10260000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10898000000              23903000000  14686000000
#
# 0 Property and Equipment Other current assets Total current assets  \
# 1             2283000000           4704000000          79598000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              22540000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9416000000            37202000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     6193000000            37302000000           34263000000
#
# 0 Other assets Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1   4279000000             151195000000  230793000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       28725000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1350000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   32351000000         28478000000               90904000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9602000000   47598000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5771000000  17636000000       13068000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   93675000000      184579000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27012000000       28195000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           9250000000        45972000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                242000000  46214000000                 230793000000
# All the pages from 10-Q document 0001467858-17-000070 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'September30, 2016', '', 'December31, 2015']
# new_column used for year ['September30,', '2016', 'December31,', '2015']
# Y - ['2016', '2015']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2016   None           None  15932000000             8172000000
#
# 0 Restricted cash  Accounts and notes receivable GM Financial receivables  \
# 1       1644000000                   10737000000              20495000000
#
# 0    Inventory Property and Equipment Other current assets  \
# 1  15427000000             2055000000           2034000000
#
# 0 Total current assets Non current Assets Restricted cash   \
# 1          76496000000               None        581000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              20299000000                                       8645000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            34713000000                     6354000000
#
# 0 Property and Equipment Deferred income taxes  Other assets  \
# 1            31775000000            35025000000   3688000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             141080000000  217576000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       28628000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1012000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   24362000000         28533000000               82535000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9740000000   43986000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5621000000  17595000000       13084000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   90026000000      172561000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27241000000       25417000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7953000000        44720000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                295000000  45015000000                 217576000000
# All the pages from 10-Q document 0001467858-16-000363 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'June30, 2016', '', 'December31, 2015']
# new_column used for year ['June30,', '2016', 'December31,', '2015']
# Y - ['2016', '2015']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2016   None           None  18923000000             4247000000
#
# 0 Restricted cash  Accounts and notes receivable GM Financial receivables  \
# 1       1595000000                   10461000000              19800000000
#
# 0    Inventory Property and Equipment Other current assets  \
# 1  15026000000             2505000000           2073000000
#
# 0 Total current assets Non current Assets Restricted cash   \
# 1          74630000000               None        603000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              19309000000                                       8198000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            33510000000                     6433000000
#
# 0 Property and Equipment Deferred income taxes  Other assets  \
# 1            28442000000            35627000000   3697000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             135819000000  210449000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       26959000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1031000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   20199000000         27854000000               76043000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9789000000   44301000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5675000000  17939000000       12699000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   90403000000      166446000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27734000000       23785000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7905000000        43630000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                373000000  44003000000                 210449000000
# All the pages from 10-Q document 0001467858-16-000341 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'March31, 2016', '', 'December31, 2015']
# new_column used for year ['March31,', '2016', 'December31,', '2015']
# Y - ['2016', '2015']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2016   None           None  14894000000             6537000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable  \
# 1                                 1716000000                    8988000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              19225000000  15817000000             2199000000
#
# 0 Other current assets Total current assets Non current Assets  \
# 1           1658000000          71034000000               None
#
# 0 Restricted cash and marketable securities  GM Financial receivables  \
# 1                                  639000000              19145000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9640000000            32652000000
#
# 0 Goodwill and intangible assets Property and Equipment  \
# 1                     5891000000            24538000000
#
# 0 Deferred income taxes  Other assets Total non current assets  Total Assets  \
# 1            36374000000   3705000000             132584000000  203618000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       26766000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      832000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   20756000000         26633000000               74987000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9946000000   39615000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5720000000  19245000000       12780000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   87306000000      162293000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27463000000       21508000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8054000000        40932000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                393000000  41325000000                 203618000000
# All the pages from 10-Q document 0001467858-16-000317 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'September30, 2015', '', 'December31, 2014']
# new_column used for year ['September30,', '2015', 'December31,', '2014']
# Y - ['2015', '2014']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2015   None           None  15433000000             8029000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1519000000                    10486000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              17217000000  14368000000             4596000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9208000000           1485000000          82341000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  593000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              17671000000                                       8872000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            29381000000                     6083000000
#
# 0 Property and Equipment Deferred income taxes Other assets  \
# 1            16915000000           24799000000   2345000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             106659000000  189000000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       25188000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      641000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   16361000000         30549000000               72739000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  8503000000   31898000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5959000000  21618000000       13148000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   81126000000      153865000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27744000000       14912000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8034000000        34638000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                497000000  35135000000                 189000000000
# All the pages from 10-Q document 0001467858-15-000217 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'June30, 2015', '', 'December31, 2014']
# new_column used for year ['June30,', '2015', 'December31,', '2014']
# Y - ['2015', '2014']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2015   None           None  17627000000             7200000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1442000000                    10604000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              16932000000  14218000000             5722000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9289000000           1520000000          84554000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  623000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              17277000000                                       8403000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            28431000000                     6181000000
#
# 0 Property and Equipment Deferred income taxes Other assets  \
# 1            12904000000           24998000000   2441000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             101258000000  185812000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       24247000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      462000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   13941000000         30878000000               69528000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  8725000000   30389000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   6075000000  22177000000       13248000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   80614000000      150142000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                28161000000       14512000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7543000000        35146000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                524000000  35670000000                 185812000000
# All the pages from 10-Q document 0001467858-15-000175 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'March31, 2015', '', 'December31, 2014']
# new_column used for year ['March31,', '2015', 'December31,', '2014']
# Y - ['2015', '2014']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2015   None           None  15776000000             8409000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1414000000                    11569000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              16127000000  14051000000             4563000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9704000000           1618000000          83231000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  625000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              16180000000                                       9756000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            27755000000                     6297000000
#
# 0 Property and Equipment Deferred income taxes Other assets  \
# 1             8939000000           24782000000   2353000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1              96687000000  179918000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       25187000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      411000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   13940000000         27804000000               67342000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  8722000000   25185000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   6089000000  22206000000       13551000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   75753000000      143095000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                28819000000       14825000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7331000000        36329000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                494000000  36823000000                 179918000000
# All the pages from 10-Q document 0001467858-15-000122 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'September30, 2014', '', 'December31, 2013']
# new_column used for year ['September30,', '2014', 'December31,', '2013']
# Y - ['2014', '2013']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2014   None           None  18060000000             9570000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1375000000                    10892000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              15660000000  15210000000             4044000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9978000000           1851000000          86640000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  915000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              15604000000                                       7983000000
#
# 0 Property and Equipment    Goodwill Intangible assets Property and Equipment  \
# 1            27375000000  1559000000        5085000000             5796000000
#
# 0 Deferred income taxes Other assets Total non current assets  Total Assets  \
# 1           23574000000   2377000000              90268000000  176908000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       24773000000
#
# 0 Short term debt and current portion of long term debt  Automotive   \
# 1                                               None       578000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   12808000000         29170000000               67329000000
#
# 0 Non current Liabilities Long term debt  Automotive  GM Financial   \
# 1                    None            None  6753000000   20966000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   5815000000  18111000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 14371000000                   66016000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Preferred Stock  \
# 1      133345000000                           None    None      3109000000
#
# 0 Common Stock Additional paid in capital Retained Earnings  \
# 1     16000000                28832000000       13975000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           2930000000        43002000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                561000000  43563000000                 176908000000
# All the pages from 10-Q document 0001467858-14-000247 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'June30, 2014', '', 'December31, 2013']
# new_column used for year ['June30,', '2014', 'December31,', '2013']
# Y - ['2014', '2013']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2014   None           None  19864000000             9935000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1325000000                    11480000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              15797000000  15200000000             4633000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1           11499000000           1910000000          91643000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  969000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              15430000000                                       7485000000
#
# 0 Property and Equipment    Goodwill Intangible assets Property and Equipment  \
# 1            27023000000  1573000000        5220000000             4748000000
#
# 0 Deferred income taxes Other assets Total non current assets  Total Assets  \
# 1           22582000000   2425000000              87455000000  179098000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# ...
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  829000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              14354000000                                       8094000000
#
# 0 Property and Equipment   Goodwill  Intangible assets Property and Equipment  \
# 1            25867000000  1560000000        5668000000             3383000000
#
# 0 Deferred income taxes  Other assets Total non current assets  Total Assets  \
# 1            22736000000   2352000000              84843000000  166344000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       23621000000
#
# 0 Short term debt and current portion of long term debt  Automotive   \
# 1                                               None       564000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   13594000000         24633000000               62412000000
#
# 0 Non current Liabilities Long term debt  Automotive  GM Financial   \
# 1                    None            None  6573000000   15452000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   5897000000  19483000000
#
# 0 Other liabilities and deferred income taxes  Total non current liabilities  \
# 1                                  13353000000                   60758000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Preferred Stock  \
# 1      123170000000                           None    None            None
#
# 0    Series A    Series B Common Stock Additional paid in capital  \
# 1  3109000000  4855000000     15000000                28780000000
#
# 0 Retained Earnings Accumulated other comprehensive loss Shareholder Equity  \
# 1       13816000000                           3113000000        42607000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                567000000  43174000000                 166344000000
# All the pages from 10-K document 0001467858-14-000043 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'December31, 2012', '', 'December31, 2011']
# new_column used for year ['December31,', '2012', 'December31,', '2011']
# Y - ['2012', '2011']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities  \
# 1      Q4  2012   None           None  18422000000            8988000000
#
# 0 Restricted cash and marketable securities Accounts and notes receivable   \
# 1                                 686000000                    10395000000
#
# 0 GM Financial finance receivables    Inventory Property and Equipment  \
# 1                       4044000000  14714000000             1782000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9429000000           1536000000          69996000000
#
# 0 Non current Assets Restricted cash and marketable securities  \
# 1               None                                 682000000
#
# 0 GM Financial finance receivables  \
# 1                       6954000000
#
# 0 Equity in  assets of nonconsolidated affiliates Property and Equipment  \
# 1                                      6883000000            24196000000
#
# 0    Goodwill Intangible assets Property and Equipment Deferred income taxes  \
# 1  1973000000        6809000000             1649000000           27922000000
#
# 0 Other assets Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1   2358000000              79426000000  149422000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       25166000000
#
# 0 Short term debt and current portion of long term debt Automotive   \
# 1                                               None     1748000000
#
# 0 GM Financial Accrued Liabilities Total current liabilities  \
# 1   3770000000         23308000000               53992000000
#
# 0 Non current Liabilities Long term debt Automotive  GM Financial  \
# 1                    None           None  3424000000   7108000000
#
# 0 Postretirement benefits other than pensions     Pensions  \
# 1                                  7309000000  27420000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 13169000000                   58430000000
#
# 0 Total Liabilities Commitments and contingencies  Equity Preferred Stock  \
# 1      112422000000                           None   None            None
#
# 0   Series A    Series B  Common Stock Capital surplus  Retained Earnings  \
# 1  5536000000  4855000000     14000000      23834000000       10057000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8052000000        36244000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                756000000  37000000000                 149422000000
# All the pages from 10-K document 0001467858-13-000025 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', 'December31, 2011', '', 'December31, 2010']
# new_column used for year ['December31,', '2011', 'December31,', '2010']
# Y - ['2011', '2010']
# 0 Quarter  Year ASSETS Automotive Current Assets         Cash  \
# 1      Q4  2011   None                      None  15499000000
#
# 0 Marketable securities Restricted cash and marketable securities  \
# 1           16148000000                                 206000000
#
# 0 Accounts and notes receivable     Inventory Property and Equipment  \
# 1                     9949000000  14324000000             2464000000
#
# 0 Other current assets and deferred income taxes Total current assets  \
# 1                                     1657000000          60247000000
#
# 0 Automotive Non current Assets Restricted cash and marketable securities  \
# 1                          None                                 912000000
#
# 0 Equity in  assets of nonconsolidated affiliates Property and Equipment  \
# 1                                      6790000000            22957000000
#
# 0     Goodwill Intangible assets Other assets and deferred income taxes  \
# 1  27741000000       10013000000                             2900000000
#
# 0 Total non current assets Total Automotive Assets GM Financial Assets  \
# 1              71313000000            131560000000                None
#
# 0 Finance receivables Restricted cash    Goodwill Other assets   \
# 1          9162000000      1115000000  1278000000    1488000000
#
# 0 Total GM Financial Assets  Total Assets LIABILITIES AND EQUITY  \
# 1               13043000000  144603000000                   None
#
# 0 Automotive Current Liabilities Accounts payable   \
# 1                           None       24494000000
#
# 0 Short term debt and current portion of long term debt  Accrued Liabilities  \
# 1                                         1682000000             22756000000
#
# 0 Total current liabilities Automotive Non current Liabilities  \
# 1               48932000000                               None
#
# 0 Long term debt  Postretirement benefits other than pensions     Pensions  \
# 1      3613000000                                  6836000000  25075000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 12336000000                   47860000000
#
# 0 Total Automotive Liabilities GM Financial Liabilities  \
# 1                  96792000000                     None
#
# 0 Securitization notes payable  Credit facilities Other liabilities  \
# 1                    6938000000        1099000000         783000000
#
# 0 Total GM Financial Liabilities Total Liabilities  \
# 1                     8820000000      105612000000
#
# 0 Commitments and contingencies  Equity Preferred Stock   Series A   \
# 1                           None   None            None  5536000000
#
# 0   Series B  Common Stock Capital surplus  Retained Earnings  \
# 1  4855000000     16000000      26391000000        7183000000
#
# 0 Accumulated other comprehensive income  Shareholder Equity  \
# 1                              5861000000        38120000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                871000000  38991000000                 144603000000
# All the pages from 10-K document 0001467858-12-000014 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', '', 'December31,2010', '', '', 'December31,2009', '']
# new_column used for year ['December31,2010', 'December31,2009']
# Y - ['2010', '2009']
# 0 Quarter  Year ASSETS Automotive Current Assets         Cash  \
# 1      Q4  2010   None                      None  21061000000
#
# 0 Marketable securities   NaN   Total cash  \
# 1            5555000000  None  26616000000
#
# 0 Restricted cash and marketable securities Accounts and notes receivable   \
# 1                                1240000000                     8699000000
#
# 0    Inventory Assets held for sale Property and Equipment  \
# 1  12125000000            388000000             2568000000
#
# 0 Other current assets and deferred income taxes   NaN Total current assets  \
# 1                                     1805000000  None          53053000000
#
# 0 Automotive Non current Assets Restricted cash and marketable securities  \
# 1                          None                                1160000000
#
# 0 Equity in  assets of nonconsolidated affiliates Property and Equipment  \
# 1                                      8529000000            19235000000
#
# 0     Goodwill Intangible assets Deferred income taxes Assets held for sale  \
# 1  30513000000       11882000000             308000000            530000000
#
# 0 Other assets   NaN Total non current assets   NaN Total Automotive Assets  \
# 1   3286000000  None              74913000000  None            127966000000
#
# 0 GM Financial Assets Finance receivables \nNote7) Restricted cash  \
# 1                None                   8197000000      1090000000
#
# 0    Goodwill Other assets   NaN Total GM Financial Assets   NaN  \
# 1  1265000000    380000000  None               10932000000  None
#
# 0  Total Assets   NaN LIABILITIES AND EQUITY Automotive Current Liabilities  \
# 1  138898000000  None                   None                           None
#
# 0 Accounts payable   \
# 1       21497000000
#
# 0 Short term debt and current portion of long term debt \n17)  \
# 1                                         1616000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 1                 355000000                                   625000000
#
# 0 Accrued Liabilities   NaN Total current liabilities  \
# 1         23419000000  None               47157000000
#
# 0 Automotive Non current Liabilities Long term debt   \
# 1                               None      3014000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 1                 270000000                                  9294000000
#
# 0     Pensions Other liabilities and deferred income taxes   NaN  \
# 1  21894000000                                 13021000000  None
#
# 0 Total non current liabilities   NaN Total Automotive Liabilities  \
# 1                   47223000000  None                  94380000000
#
# 0 GM Financial Liabilities Securitization notes payable  Credit facilities  \
# 1                     None                    6128000000         832000000
#
# 0 Other liabilities   NaN Total GM Financial Liabilities   NaN  \
# 1         399000000  None                     7359000000  None
#
# 0 Total Liabilities Commitments and contingencies  Preferred Stock Equity  \
# 1      101739000000                           None      6998000000   None
#
# 0 Preferred Stock Series A \n2010) Series B \n2010) Common Stock  \
# 1            None       5536000000       4855000000     15000000
#
# 0 Capital surplus  Retained Earnings Accumulated other comprehensive income  \
# 1      24257000000         266000000                             1251000000
#
# 0   NaN Shareholder Equity Noncontrolling interests   NaN Total equity   NaN  \
# 1  None        36180000000                979000000  None  37159000000  None
#
# 0 Total liabilities and equity   NaN
# 1                 138898000000  None
# All the pages from 10-K document 0001193125-11-051462 have been tableized and saved.
# --------------------------------------------------------------------------------
# pass anchor check
# column used for quarter ['', '', 'December31,2009', '', '', '', '', 'December31,2008', '']
# new_column used for year ['December31,2009', 'December31,2008']
# Y - ['2009', '2008']
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities  \
# 1      Q4  2009   None           None  22679000000             134000000
#
# 0   NaN   Total cash Restricted cash Accounts and notes receivable   \
# 1  None  22813000000     13917000000                     7518000000
#
# 0    Inventory Assets held for sale Property and Equipment  \
# 1  10107000000            388000000             2727000000
#
# 0 Other current assets and deferred income taxes   NaN Total current assets  \
# 1                                     1777000000  None          59247000000
#
# 0 Non Current Assets Restricted cash  \
# 1               None      1489000000
#
# 0 Equity in  assets of nonconsolidated affiliates Assets held for sale  \
# 1                                      7936000000            530000000
#
# 0 Property and Equipment Property and Equipment     Goodwill  \
# 1                3000000            18687000000  30672000000
#
# 0 Intangible assets Deferred income taxes Prepaid pension Other assets   NaN  \
# 1       14547000000             564000000        98000000   2522000000  None
#
# 0 Total non current assets   NaN  Total Assets   NaN LIABILITIES AND EQUITY   \
# 1              77048000000  None  136295000000  None                    None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       18725000000
#
# 0 Short term debt and current portion of long term debt  \
# 1                                        10221000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 1                 355000000                                   846000000
#
# 0 Accrued expenses   NaN Total current liabilities Non Current Liabilities  \
# 1      22288000000  None               52435000000                    None
#
# 0 Long term debt Liabilities held for sale  \
# 1     5562000000                 270000000
#
# 0 Postretirement benefits other than pensions     Pensions  \
# 1                                  8708000000  27086000000
#
# 0 Other liabilities and deferred income taxes   NaN  \
# 1                                 13279000000  None
#
# 0 Total non current liabilities   NaN Total liabilities  \
# 1                   54905000000  None      107340000000
#
# 0 Commitments and contingencies  Preferred Stock Equity  Old GM  \
# 1                           None      6998000000    None   None
#
# 0 Preferred Stock Preference stock Common Stock General Motors Company  \
# 1            None             None   1017000000                   None
#
# 0 Common Stock Capital surplus  Accumulated deficit  \
# 1      5000000      24050000000          4394000000
#
# 0 Accumulated other comprehensive income    NaN Shareholder Equity  \
# 1                              1588000000  None        21249000000
#
# 0 Noncontrolling interests   NaN Total equity    NaN  \
# 1                708000000  None   21957000000  None
#
# 0 Total liabilities and equity   NaN
# 1                 136295000000  None
# All the pages from 10-K document 0001193125-10-078119 have been tableized and saved.
# --------------------------------------------------------------------------------

# %%
# Checklist of erroneous filings.  
for a, b in Checklist.items():
    if b != []:
        print('These have a problem.', '\n', a, b)

    else: 
        print(a, 'has no problem!! :) ' , '\n')
    
print(Checklist)
# Out:
# 10-Q has no problem!! :)
#
# 10-K has no problem!! :)
#
# {'10-Q': [], '10-K': []}

# %%
for k, v in QorK.items():
    
    for i, vv in enumerate(v):

        with open('{}-{}.csv'.format(v[i], k), "rb") as fp:   # Pickling
            df = pickle.load(fp)
        ICD.display(df[0])
# Out:
# 0 Quarter  Year ASSETS Current Assets         Cash  \
# 1      Q1  2020   None           None  38506000000
#
# 0 Marketable debt securities  Accounts and notes receivable  \
# 1                  7620000000                    7536000000
#
# 0 GM Financial receivables    Inventory Other current assets   \
# 1              26320000000  10799000000            6918000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          97699000000               None              25948000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       7521000000            37969000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5225000000            41296000000           24441000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    6525000000             148925000000  246624000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       20031000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1730000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   43331000000         26200000000               91292000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  28581000000   52858000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5766000000  11505000000       12305000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  111015000000      202307000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                26014000000       25885000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                          11800000000        40113000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               4204000000  44317000000                 246624000000
# 0 Quarter  Year ASSETS Current Assets         Cash  \
# 1      Q3  2019   None           None  20051000000
#
# 0 Marketable debt securities  Accounts and notes receivable  \
# 1                  6725000000                    6924000000
#
# 0 GM Financial receivables    Inventory Other current assets   \
# 1              28017000000  11797000000            7051000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          80565000000               None              25743000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8496000000            37969000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5408000000            42527000000           23783000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    7038000000             150964000000  231529000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       21406000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2890000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   31884000000         28072000000               84252000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12448000000   57244000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5301000000  10223000000       13290000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   98506000000      182758000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25928000000       27609000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8997000000        44554000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               4217000000  48771000000                 231529000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2019   None           None  17072000000             7049000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10362000000              27925000000  11447000000
#
# 0 Other current assets  Total current assets Non current Assets  \
# 1            7451000000          81306000000               None
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              26264000000                                       8340000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            38188000000                     5457000000
#
# 0 Property and Equipment Deferred income taxes Other assets   \
# 1            42938000000           23987000000    7257000000
#
# 0 Total non current assets  Total Assets   NaN LIABILITIES AND EQUITY  \
# 1             152431000000  233737000000  None                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       22717000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2490000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   30659000000         28428000000               84294000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12957000000   60455000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5357000000  10791000000       12794000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  102354000000      186648000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25765000000       25807000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8770000000        42816000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               4273000000  47089000000                 233737000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2019   None           None  17176000000             6021000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   12116000000              27230000000  11108000000
#
# 0 Other current assets  Total current assets Non current Assets  \
# 1            6439000000          80090000000               None
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              25448000000                                       8266000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            38336000000                     5518000000
#
# 0 Property and Equipment Deferred income taxes Other assets   \
# 1            43052000000           24303000000    8119000000
#
# 0 Total non current assets  Total Assets   NaN LIABILITIES AND EQUITY  \
# 1             153042000000  233132000000  None                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       24560000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1999000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   31273000000         27471000000               85303000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12954000000   60858000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5363000000  11099000000       12917000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  103191000000      188494000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25661000000       23939000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8849000000        40765000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               3873000000  44638000000                 233132000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2018   None           None  18435000000             5916000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10376000000              23432000000  11334000000
#
# 0 Property and Equipment Other current assets  Total current assets  \
# 1              474000000            4881000000          74848000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              24086000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9155000000            38655000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5651000000            44128000000           23242000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    5946000000             150863000000  225711000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       25147000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2915000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   27950000000         28104000000               84116000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  13048000000   58427000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5832000000  11119000000       12261000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  100687000000      184803000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25503000000       20865000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8321000000        38061000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               2847000000  40908000000                 225711000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2018   None           None  15087000000             6924000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                    9663000000              22005000000  10833000000
#
# 0 Property and Equipment Other current assets  Total current assets  \
# 1              690000000            5249000000          70451000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              22996000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8788000000            38003000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5720000000            44054000000           23285000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    5344000000             148190000000  218641000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       24660000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      2807000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   25457000000         27368000000               80292000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  11012000000   58983000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5853000000  11989000000       11876000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   99713000000      180005000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25465000000       18873000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8171000000        36181000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               2455000000  38636000000                 218641000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2018   None           None  14256000000             7110000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10769000000              21157000000  11461000000
#
# 0 Property and Equipment Other current assets  Total current assets  \
# 1              789000000            5893000000          71435000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              22146000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9883000000            37321000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5790000000            43444000000           23538000000
#
# 0 Other assets  Total non current assets  Total Assets   NaN  \
# 1    5169000000             147291000000  218726000000  None
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       26039000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      4341000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   25006000000         27330000000               82716000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  10957000000   58514000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5927000000  13209000000       11945000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  100552000000      183268000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25337000000       17028000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8081000000        34298000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               1160000000  35458000000                 218726000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2017   None           None  12792000000             8454000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10013000000              19399000000  11789000000
#
# 0 Property and Equipment Other current assets  Current assets held for sale   \
# 1             1632000000            4909000000                    7630000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          76618000000               None              21021000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8820000000            35178000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5854000000            41775000000           30723000000
#
# 0 Other assets  Non current assets held for sale  Total non current assets  \
# 1    5005000000                        4508000000             152884000000
#
# 0  Total Assets   NaN LIABILITIES AND EQUITY Current Liabilities  \
# 1  229502000000  None                   None                None
#
# 0 Accounts payable  Short term debt and current portion of long term debt   \
# 1       23265000000                                               None
#
# 0  Automotive GM Financial  Accrued Liabilities  \
# 1  1127000000   24480000000         26603000000
#
# 0 Current liabilities held for sale  Total current liabilities  \
# 1                         6374000000               81849000000
#
# 0 Non current Liabilities Long term debt    Automotive GM Financial   \
# 1                    None            None  12508000000   54558000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5758000000  14119000000       12743000000
#
# 0 Non current liabilities held for sale  Total non current liabilities  \
# 1                             4490000000                  104176000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Common Stock  \
# 1      186025000000                           None    None     14000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                25782000000       24230000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7783000000        42243000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1               1234000000  43477000000                 229502000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2017   None           None  16598000000             9133000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                    9796000000              19296000000  11289000000
#
# 0 Property and Equipment Other current assets  Current assets held for sale   \
# 1             1883000000            4324000000                   12762000000
#
# 0 Total current assets Non current Assets GM Financial receivables  \
# 1          85081000000               None              20137000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       8248000000            34301000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     5989000000            39725000000           32425000000
#
# 0 Other assets  Non current assets held for sale  Total non current assets  \
# 1    3994000000                       10400000000             155219000000
#
# 0  Total Assets LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1  240300000000                   None                None       23404000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1066000000
#
# 0 GM Financial  Accrued Liabilities Current liabilities held for sale   \
# 1   28942000000         26601000000                        14293000000
#
# 0 Total current liabilities Non current Liabilities Long term debt   \
# 1               94306000000                    None            None
#
# 0  Automotive GM Financial  Postretirement benefits other than pensions   \
# 1  9544000000   49537000000                                   5750000000
#
# 0    Pensions  Other liabilities Non current liabilities held for sale   \
# 1  14777000000       12438000000                             8223000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                  100269000000      194575000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                26328000000       28547000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           9369000000        45521000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                204000000  45725000000                 240300000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2017   None           None  12864000000            10260000000
#
# 0 Accounts and notes receivable GM Financial receivables    Inventory  \
# 1                   10898000000              23903000000  14686000000
#
# 0 Property and Equipment Other current assets Total current assets  \
# 1             2283000000           4704000000          79598000000
#
# 0 Non current Assets GM Financial receivables  \
# 1               None              22540000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9416000000            37202000000
#
# 0 Goodwill and intangible assets Property and Equipment Deferred income taxes  \
# 1                     6193000000            37302000000           34263000000
#
# 0 Other assets Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1   4279000000             151195000000  230793000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       28725000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1350000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   32351000000         28478000000               90904000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9602000000   47598000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5771000000  17636000000       13068000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   93675000000      184579000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27012000000       28195000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           9250000000        45972000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                242000000  46214000000                 230793000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2016   None           None  15932000000             8172000000
#
# 0 Restricted cash  Accounts and notes receivable GM Financial receivables  \
# 1       1644000000                   10737000000              20495000000
#
# 0    Inventory Property and Equipment Other current assets  \
# 1  15427000000             2055000000           2034000000
#
# 0 Total current assets Non current Assets Restricted cash   \
# 1          76496000000               None        581000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              20299000000                                       8645000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            34713000000                     6354000000
#
# 0 Property and Equipment Deferred income taxes  Other assets  \
# 1            31775000000            35025000000   3688000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             141080000000  217576000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       28628000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1012000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   24362000000         28533000000               82535000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9740000000   43986000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5621000000  17595000000       13084000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   90026000000      172561000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27241000000       25417000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7953000000        44720000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                295000000  45015000000                 217576000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2016   None           None  18923000000             4247000000
#
# 0 Restricted cash  Accounts and notes receivable GM Financial receivables  \
# 1       1595000000                   10461000000              19800000000
#
# 0    Inventory Property and Equipment Other current assets  \
# 1  15026000000             2505000000           2073000000
#
# 0 Total current assets Non current Assets Restricted cash   \
# 1          74630000000               None        603000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              19309000000                                       8198000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            33510000000                     6433000000
#
# 0 Property and Equipment Deferred income taxes  Other assets  \
# 1            28442000000            35627000000   3697000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             135819000000  210449000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       26959000000
#
# 0 Short term debt and current portion of long term debt   Automotive  \
# 1                                               None      1031000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   20199000000         27854000000               76043000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9789000000   44301000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5675000000  17939000000       12699000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   90403000000      166446000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27734000000       23785000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7905000000        43630000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                373000000  44003000000                 210449000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2016   None           None  14894000000             6537000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable  \
# 1                                 1716000000                    8988000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              19225000000  15817000000             2199000000
#
# 0 Other current assets Total current assets Non current Assets  \
# 1           1658000000          71034000000               None
#
# 0 Restricted cash and marketable securities  GM Financial receivables  \
# 1                                  639000000              19145000000
#
# 0 Equity in  assets of nonconsolidated affiliates  Property and Equipment  \
# 1                                       9640000000            32652000000
#
# 0 Goodwill and intangible assets Property and Equipment  \
# 1                     5891000000            24538000000
#
# 0 Deferred income taxes  Other assets Total non current assets  Total Assets  \
# 1            36374000000   3705000000             132584000000  203618000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       26766000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      832000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   20756000000         26633000000               74987000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  9946000000   39615000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5720000000  19245000000       12780000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   87306000000      162293000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     15000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27463000000       21508000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8054000000        40932000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                393000000  41325000000                 203618000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2015   None           None  15433000000             8029000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1519000000                    10486000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              17217000000  14368000000             4596000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9208000000           1485000000          82341000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  593000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              17671000000                                       8872000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            29381000000                     6083000000
#
# 0 Property and Equipment Deferred income taxes Other assets  \
# 1            16915000000           24799000000   2345000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             106659000000  189000000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       25188000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      641000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   16361000000         30549000000               72739000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  8503000000   31898000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   5959000000  21618000000       13148000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   81126000000      153865000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                27744000000       14912000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8034000000        34638000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                497000000  35135000000                 189000000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2015   None           None  17627000000             7200000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1442000000                    10604000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              16932000000  14218000000             5722000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9289000000           1520000000          84554000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  623000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              17277000000                                       8403000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            28431000000                     6181000000
#
# 0 Property and Equipment Deferred income taxes Other assets  \
# 1            12904000000           24998000000   2441000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1             101258000000  185812000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       24247000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      462000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   13941000000         30878000000               69528000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  8725000000   30389000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   6075000000  22177000000       13248000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   80614000000      150142000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                28161000000       14512000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7543000000        35146000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                524000000  35670000000                 185812000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2015   None           None  15776000000             8409000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1414000000                    11569000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              16127000000  14051000000             4563000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9704000000           1618000000          83231000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  625000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              16180000000                                       9756000000
#
# 0 Property and Equipment Goodwill and intangible assets  \
# 1            27755000000                     6297000000
#
# 0 Property and Equipment Deferred income taxes Other assets  \
# 1             8939000000           24782000000   2353000000
#
# 0 Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1              96687000000  179918000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       25187000000
#
# 0 Short term debt and current portion of long term debt  Automotive  \
# 1                                               None      411000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   13940000000         27804000000               67342000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  8722000000   25185000000
#
# 0 Postretirement benefits other than pensions     Pensions  Other liabilities  \
# 1                                   6089000000  22206000000       13551000000
#
# 0 Total non current liabilities Total Liabilities  \
# 1                   75753000000      143095000000
#
# 0 Commitments and contingencies  Equity  Common Stock  \
# 1                           None    None     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                28819000000       14825000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           7331000000        36329000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                494000000  36823000000                 179918000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2014   None           None  18060000000             9570000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1375000000                    10892000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              15660000000  15210000000             4044000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9978000000           1851000000          86640000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  915000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              15604000000                                       7983000000
#
# 0 Property and Equipment    Goodwill Intangible assets Property and Equipment  \
# 1            27375000000  1559000000        5085000000             5796000000
#
# 0 Deferred income taxes Other assets Total non current assets  Total Assets  \
# 1           23574000000   2377000000              90268000000  176908000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       24773000000
#
# 0 Short term debt and current portion of long term debt  Automotive   \
# 1                                               None       578000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   12808000000         29170000000               67329000000
#
# 0 Non current Liabilities Long term debt  Automotive  GM Financial   \
# 1                    None            None  6753000000   20966000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   5815000000  18111000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 14371000000                   66016000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Preferred Stock  \
# 1      133345000000                           None    None      3109000000
#
# 0 Common Stock Additional paid in capital Retained Earnings  \
# 1     16000000                28832000000       13975000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           2930000000        43002000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                561000000  43563000000                 176908000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q2  2014   None           None  19864000000             9935000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1325000000                    11480000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              15797000000  15200000000             4633000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1           11499000000           1910000000          91643000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  969000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              15430000000                                       7485000000
#
# 0 Property and Equipment    Goodwill Intangible assets Property and Equipment  \
# 1            27023000000  1573000000        5220000000             4748000000
#
# 0 Deferred income taxes Other assets Total non current assets  Total Assets  \
# 1           22582000000   2425000000              87455000000  179098000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       26992000000
#
# 0 Short term debt and current portion of long term debt  Automotive   \
# 1                                               None       610000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   15193000000         29552000000               72347000000
#
# 0 Non current Liabilities Long term debt  Automotive  GM Financial   \
# 1                    None            None  6864000000   17409000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   5826000000  19068000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 14999000000                   64166000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Preferred Stock  \
# 1      136513000000                           None    None      3109000000
#
# 0 Common Stock Additional paid in capital Retained Earnings  \
# 1     16000000                28840000000       13162000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           3133000000        41994000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                591000000  42585000000                 179098000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q1  2014   None           None  19426000000             8716000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1288000000                    11734000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              15055000000  14837000000             3432000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1           10590000000           1747000000          86825000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  906000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              14866000000                                       8747000000
#
# 0 Property and Equipment    Goodwill Intangible assets Property and Equipment  \
# 1            26367000000  1563000000        5442000000             3726000000
#
# 0 Deferred income taxes Other assets Total non current assets  Total Assets  \
# 1           22840000000   2324000000              86781000000  173606000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       27715000000
#
# 0 Short term debt and current portion of long term debt  Automotive   \
# 1                                               None       522000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   14327000000         26658000000               69222000000
#
# 0 Non current Liabilities Long term debt  Automotive  GM Financial   \
# 1                    None            None  6687000000   16231000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   5814000000  19171000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 13641000000                   61544000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Preferred Stock  \
# 1      130766000000                           None    None      3109000000
#
# 0 Common Stock Additional paid in capital Retained Earnings  \
# 1     16000000                28778000000       13457000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           3138000000        42222000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                618000000  42840000000                 173606000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q3  2013   None           None  20355000000             8215000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                  959000000                    11067000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              11010000000  15357000000             2559000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9868000000           1774000000          81164000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  676000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              12222000000                                       7897000000
#
# 0 Property and Equipment   Goodwill  Intangible assets Property and Equipment  \
# 1            26247000000  1953000000        6364000000             3100000000
#
# 0 Deferred income taxes Other assets Total non current assets  Total Assets  \
# 1           26020000000   2896000000              87375000000  168539000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       27242000000
#
# 0 Short term debt and current portion of long term debt  Automotive   \
# 1                                               None      1786000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1    9653000000         23882000000               62563000000
#
# 0 Non current Liabilities Long term debt  Automotive  GM Financial   \
# 1                    None            None  6662000000   14022000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   6855000000  27030000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 14046000000                   68615000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Preferred Stock  \
# 1      131178000000                           None    None            None
#
# ...
# 1   14488000000         28184000000               65701000000
#
# 0 Non current Liabilities Long term debt   Automotive GM Financial   \
# 1                    None            None  8910000000   22943000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   6229000000  23788000000
#
# 0 Other liabilities  Total non current liabilities Total Liabilities  \
# 1        14082000000                   75952000000      141653000000
#
# 0 Commitments and contingencies  Equity  Preferred Stock Common Stock  \
# 1                           None    None      3109000000     16000000
#
# 0 Additional paid in capital Retained Earnings  \
# 1                28937000000       14577000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8073000000        35457000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                567000000  36024000000                 177677000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities   \
# 1      Q4  2013   None           None  20021000000             8972000000
#
# 0 Restricted cash and marketable securities  Accounts and notes receivable   \
# 1                                 1247000000                     8535000000
#
# 0 GM Financial receivables    Inventory Property and Equipment  \
# 1              14278000000  14039000000             2398000000
#
# 0 Deferred income taxes  Other current assets Total current assets  \
# 1            10349000000           1662000000          81501000000
#
# 0 Non current Assets Restricted cash and marketable securities   \
# 1               None                                  829000000
#
# 0 GM Financial receivables Equity in  assets of nonconsolidated affiliates   \
# 1              14354000000                                       8094000000
#
# 0 Property and Equipment   Goodwill  Intangible assets Property and Equipment  \
# 1            25867000000  1560000000        5668000000             3383000000
#
# 0 Deferred income taxes  Other assets Total non current assets  Total Assets  \
# 1            22736000000   2352000000              84843000000  166344000000
#
# 0 LIABILITIES AND EQUITY Current Liabilities Accounts payable   \
# 1                   None                None       23621000000
#
# 0 Short term debt and current portion of long term debt  Automotive   \
# 1                                               None       564000000
#
# 0 GM Financial  Accrued Liabilities Total current liabilities  \
# 1   13594000000         24633000000               62412000000
#
# 0 Non current Liabilities Long term debt  Automotive  GM Financial   \
# 1                    None            None  6573000000   15452000000
#
# 0 Postretirement benefits other than pensions     Pensions   \
# 1                                   5897000000  19483000000
#
# 0 Other liabilities and deferred income taxes  Total non current liabilities  \
# 1                                  13353000000                   60758000000
#
# 0 Total Liabilities Commitments and contingencies  Equity  Preferred Stock  \
# 1      123170000000                           None    None            None
#
# 0    Series A    Series B Common Stock Additional paid in capital  \
# 1  3109000000  4855000000     15000000                28780000000
#
# 0 Retained Earnings Accumulated other comprehensive loss Shareholder Equity  \
# 1       13816000000                           3113000000        42607000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                567000000  43174000000                 166344000000
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities  \
# 1      Q4  2012   None           None  18422000000            8988000000
#
# 0 Restricted cash and marketable securities Accounts and notes receivable   \
# 1                                 686000000                    10395000000
#
# 0 GM Financial finance receivables    Inventory Property and Equipment  \
# 1                       4044000000  14714000000             1782000000
#
# 0 Deferred income taxes Other current assets Total current assets  \
# 1            9429000000           1536000000          69996000000
#
# 0 Non current Assets Restricted cash and marketable securities  \
# 1               None                                 682000000
#
# 0 GM Financial finance receivables  \
# 1                       6954000000
#
# 0 Equity in  assets of nonconsolidated affiliates Property and Equipment  \
# 1                                      6883000000            24196000000
#
# 0    Goodwill Intangible assets Property and Equipment Deferred income taxes  \
# 1  1973000000        6809000000             1649000000           27922000000
#
# 0 Other assets Total non current assets  Total Assets LIABILITIES AND EQUITY  \
# 1   2358000000              79426000000  149422000000                   None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       25166000000
#
# 0 Short term debt and current portion of long term debt Automotive   \
# 1                                               None     1748000000
#
# 0 GM Financial Accrued Liabilities Total current liabilities  \
# 1   3770000000         23308000000               53992000000
#
# 0 Non current Liabilities Long term debt Automotive  GM Financial  \
# 1                    None           None  3424000000   7108000000
#
# 0 Postretirement benefits other than pensions     Pensions  \
# 1                                  7309000000  27420000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 13169000000                   58430000000
#
# 0 Total Liabilities Commitments and contingencies  Equity Preferred Stock  \
# 1      112422000000                           None   None            None
#
# 0   Series A    Series B  Common Stock Capital surplus  Retained Earnings  \
# 1  5536000000  4855000000     14000000      23834000000       10057000000
#
# 0 Accumulated other comprehensive loss Shareholder Equity  \
# 1                           8052000000        36244000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                756000000  37000000000                 149422000000
# 0 Quarter  Year ASSETS Automotive Current Assets         Cash  \
# 1      Q4  2011   None                      None  15499000000
#
# 0 Marketable securities Restricted cash and marketable securities  \
# 1           16148000000                                 206000000
#
# 0 Accounts and notes receivable     Inventory Property and Equipment  \
# 1                     9949000000  14324000000             2464000000
#
# 0 Other current assets and deferred income taxes Total current assets  \
# 1                                     1657000000          60247000000
#
# 0 Automotive Non current Assets Restricted cash and marketable securities  \
# 1                          None                                 912000000
#
# 0 Equity in  assets of nonconsolidated affiliates Property and Equipment  \
# 1                                      6790000000            22957000000
#
# 0     Goodwill Intangible assets Other assets and deferred income taxes  \
# 1  27741000000       10013000000                             2900000000
#
# 0 Total non current assets Total Automotive Assets GM Financial Assets  \
# 1              71313000000            131560000000                None
#
# 0 Finance receivables Restricted cash    Goodwill Other assets   \
# 1          9162000000      1115000000  1278000000    1488000000
#
# 0 Total GM Financial Assets  Total Assets LIABILITIES AND EQUITY  \
# 1               13043000000  144603000000                   None
#
# 0 Automotive Current Liabilities Accounts payable   \
# 1                           None       24494000000
#
# 0 Short term debt and current portion of long term debt  Accrued Liabilities  \
# 1                                         1682000000             22756000000
#
# 0 Total current liabilities Automotive Non current Liabilities  \
# 1               48932000000                               None
#
# 0 Long term debt  Postretirement benefits other than pensions     Pensions  \
# 1      3613000000                                  6836000000  25075000000
#
# 0 Other liabilities and deferred income taxes Total non current liabilities  \
# 1                                 12336000000                   47860000000
#
# 0 Total Automotive Liabilities GM Financial Liabilities  \
# 1                  96792000000                     None
#
# 0 Securitization notes payable  Credit facilities Other liabilities  \
# 1                    6938000000        1099000000         783000000
#
# 0 Total GM Financial Liabilities Total Liabilities  \
# 1                     8820000000      105612000000
#
# 0 Commitments and contingencies  Equity Preferred Stock   Series A   \
# 1                           None   None            None  5536000000
#
# 0   Series B  Common Stock Capital surplus  Retained Earnings  \
# 1  4855000000     16000000      26391000000        7183000000
#
# 0 Accumulated other comprehensive income  Shareholder Equity  \
# 1                              5861000000        38120000000
#
# 0 Noncontrolling interests Total Equity Total liabilities and equity
# 1                871000000  38991000000                 144603000000
# 0 Quarter  Year ASSETS Automotive Current Assets         Cash  \
# 1      Q4  2010   None                      None  21061000000
#
# 0 Marketable securities   NaN   Total cash  \
# 1            5555000000  None  26616000000
#
# 0 Restricted cash and marketable securities Accounts and notes receivable   \
# 1                                1240000000                     8699000000
#
# 0    Inventory Assets held for sale Property and Equipment  \
# 1  12125000000            388000000             2568000000
#
# 0 Other current assets and deferred income taxes   NaN Total current assets  \
# 1                                     1805000000  None          53053000000
#
# 0 Automotive Non current Assets Restricted cash and marketable securities  \
# 1                          None                                1160000000
#
# 0 Equity in  assets of nonconsolidated affiliates Property and Equipment  \
# 1                                      8529000000            19235000000
#
# 0     Goodwill Intangible assets Deferred income taxes Assets held for sale  \
# 1  30513000000       11882000000             308000000            530000000
#
# 0 Other assets   NaN Total non current assets   NaN Total Automotive Assets  \
# 1   3286000000  None              74913000000  None            127966000000
#
# 0 GM Financial Assets Finance receivables \nNote7) Restricted cash  \
# 1                None                   8197000000      1090000000
#
# 0    Goodwill Other assets   NaN Total GM Financial Assets   NaN  \
# 1  1265000000    380000000  None               10932000000  None
#
# 0  Total Assets   NaN LIABILITIES AND EQUITY Automotive Current Liabilities  \
# 1  138898000000  None                   None                           None
#
# 0 Accounts payable   \
# 1       21497000000
#
# 0 Short term debt and current portion of long term debt \n17)  \
# 1                                         1616000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 1                 355000000                                   625000000
#
# 0 Accrued Liabilities   NaN Total current liabilities  \
# 1         23419000000  None               47157000000
#
# 0 Automotive Non current Liabilities Long term debt   \
# 1                               None      3014000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 1                 270000000                                  9294000000
#
# 0     Pensions Other liabilities and deferred income taxes   NaN  \
# 1  21894000000                                 13021000000  None
#
# 0 Total non current liabilities   NaN Total Automotive Liabilities  \
# 1                   47223000000  None                  94380000000
#
# 0 GM Financial Liabilities Securitization notes payable  Credit facilities  \
# 1                     None                    6128000000         832000000
#
# 0 Other liabilities   NaN Total GM Financial Liabilities   NaN  \
# 1         399000000  None                     7359000000  None
#
# 0 Total Liabilities Commitments and contingencies  Preferred Stock Equity  \
# 1      101739000000                           None      6998000000   None
#
# 0 Preferred Stock Series A \n2010) Series B \n2010) Common Stock  \
# 1            None       5536000000       4855000000     15000000
#
# 0 Capital surplus  Retained Earnings Accumulated other comprehensive income  \
# 1      24257000000         266000000                             1251000000
#
# 0   NaN Shareholder Equity Noncontrolling interests   NaN Total equity   NaN  \
# 1  None        36180000000                979000000  None  37159000000  None
#
# 0 Total liabilities and equity   NaN
# 1                 138898000000  None
# 0 Quarter  Year ASSETS Current Assets         Cash Marketable securities  \
# 1      Q4  2009   None           None  22679000000             134000000
#
# 0   NaN   Total cash Restricted cash Accounts and notes receivable   \
# 1  None  22813000000     13917000000                     7518000000
#
# 0    Inventory Assets held for sale Property and Equipment  \
# 1  10107000000            388000000             2727000000
#
# 0 Other current assets and deferred income taxes   NaN Total current assets  \
# 1                                     1777000000  None          59247000000
#
# 0 Non Current Assets Restricted cash  \
# 1               None      1489000000
#
# 0 Equity in  assets of nonconsolidated affiliates Assets held for sale  \
# 1                                      7936000000            530000000
#
# 0 Property and Equipment Property and Equipment     Goodwill  \
# 1                3000000            18687000000  30672000000
#
# 0 Intangible assets Deferred income taxes Prepaid pension Other assets   NaN  \
# 1       14547000000             564000000        98000000   2522000000  None
#
# 0 Total non current assets   NaN  Total Assets   NaN LIABILITIES AND EQUITY   \
# 1              77048000000  None  136295000000  None                    None
#
# 0 Current Liabilities Accounts payable   \
# 1                None       18725000000
#
# 0 Short term debt and current portion of long term debt  \
# 1                                        10221000000
#
# 0 Liabilities held for sale Postretirement benefits other than pensions  \
# 1                 355000000                                   846000000
#
# 0 Accrued expenses   NaN Total current liabilities Non Current Liabilities  \
# 1      22288000000  None               52435000000                    None
#
# 0 Long term debt Liabilities held for sale  \
# 1     5562000000                 270000000
#
# 0 Postretirement benefits other than pensions     Pensions  \
# 1                                  8708000000  27086000000
#
# 0 Other liabilities and deferred income taxes   NaN  \
# 1                                 13279000000  None
#
# 0 Total non current liabilities   NaN Total liabilities  \
# 1                   54905000000  None      107340000000
#
# 0 Commitments and contingencies  Preferred Stock Equity  Old GM  \
# 1                           None      6998000000    None   None
#
# 0 Preferred Stock Preference stock Common Stock General Motors Company  \
# 1            None             None   1017000000                   None
#
# 0 Common Stock Capital surplus  Accumulated deficit  \
# 1      5000000      24050000000          4394000000
#
# 0 Accumulated other comprehensive income    NaN Shareholder Equity  \
# 1                              1588000000  None        21249000000
#
# 0 Noncontrolling interests   NaN Total equity    NaN  \
# 1                708000000  None   21957000000  None
#
# 0 Total liabilities and equity   NaN
# 1                 136295000000  None

# %%
QorK
# Out:
# {'10-Q': ['0001467858-20-000069',
#   '0001467858-19-000121',
#   '0001467858-19-000107',
#   '0001467858-19-000084',
#   '0001467858-18-000104',
#   '0001467858-18-000089',
#   '0001467858-18-000068',
#   '0001467858-17-000133',
#   '0001467858-17-000103',
#   '0001467858-17-000070',
#   '0001467858-16-000363',
#   '0001467858-16-000341',
#   '0001467858-16-000317',
#   '0001467858-15-000217',
#   '0001467858-15-000175',
#   '0001467858-15-000122',
#   '0001467858-14-000247',
#   '0001467858-14-000213',
#   '0001467858-14-000125',
#   '0001467858-13-000135',
#   '0001467858-13-000106',
#   '0001467858-13-000075',
#   '0001467858-12-000060',
#   '0001467858-12-000047',
#   '0001467858-12-000029',
#   '0001193125-11-303419',
#   '0001193125-11-211642',
#   '0001193125-11-130473',
#   '0001193125-10-255233',
#   '0001193125-10-189968',
#   '0001193125-10-121463',
#   '0001193125-10-078123'],
#  '10-K': ['0001467858-20-000028',
#   '0001467858-19-000033',
#   '0001467858-18-000022',
#   '0001467858-17-000028',
#   '0001467858-16-000255',
#   '0001467858-15-000036',
#   '0001467858-14-000043',
#   '0001467858-13-000025',
#   '0001467858-12-000014',
#   '0001193125-11-051462',
#   '0001193125-10-078119']}
