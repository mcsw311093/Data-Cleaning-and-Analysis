# %% [markdown]
# # Comparing the Old and the New.

# %%
# Import Library 

import re
import requests
import unicodedata
from bs4 import BeautifulSoup
from pprint import pprint
import numpy as np
from numpy import array
import pandas as pd 
import csv
import pickle
from IPython.display import display
import pickle
from collections import Counter
pd.set_option('display.max_columns', 100)
pd.set_option('display.precision',20)
from IPython.core import display as ICD

# %% [markdown]
# # Loading

# %%
QorK = {'10-Q': ['0000037996-20-000041',
  '0000037996-19-000078',
  '0000037996-19-000067',
  '0000037996-19-000026',
  '0000037996-18-000084',
  '0000037996-18-000063',
  '0000037996-18-000036',
  '0000037996-17-000092',
  '0000037996-17-000068',
  '0000037996-17-000036',
  '0000037996-16-000158',
  '0000037996-16-000133',
  '0000037996-16-000107',
  '0000037996-15-000064',
  '0000037996-15-000046',
  '0000037996-15-000029',
  '0000037996-14-000057',
  '0000037996-14-000043',
  '0000037996-14-000023',
  '0000037996-13-000055',
  '0000037996-13-000042',
  '0000037996-13-000027'],
 '10-K': ['0000037996-20-000010',
  '0000037996-19-000012',
  '0000037996-18-000015',
  '0000037996-17-000013',
  '0000037996-16-000092',
  '0000037996-15-000013',
  '0000037996-14-000010',
  '0000037996-13-000014']}

# %%
df = pd.read_pickle( "0000037996-20-000041-10-Q.csv")        
ICD.display(df)
# Out:
# 0 Quarter  Year ASSETS         Cash Marketable securities   \
# 1      Q1  2020   None  25971000000            20399000000
#
# 0 Ford Credit finance receivables Trade and other receivables    Inventory  \
# 1                     54889000000                  6625000000  11312000000
#
# 0 Assets held for sale  Other assets Total current assets   NaN  \
# 1             700000000   4380000000         124276000000  None
#
# 0 Ford Credit finance receivables Net investment in operating leases  \
# 1                     51141000000                        28514000000
#
# 0 Property and Equipment Equity in  assets of affiliated companies  \
# 1            35294000000                                2275000000
#
# 0 Deferred income taxes Other assets  Total assets   NaN LIABILITIES  \
# 1           10922000000  11728000000  264150000000  None        None
#
# 0     Payables Deferred Revenue Automotive debt payable within one year   \
# 1  18439000000      22674000000                               1609000000
#
# 0 Ford Credit debt payable within one year   \
# 1                               51303000000
#
# 0 Other debt payable within one year  Liabilities held for sale   \
# 1                                None                  469000000
#
# 0 Total current liabilities   NaN Deferred Revenue Automotive long term debt   \
# 1               94494000000  None      25105000000                28411000000
#
# 0 Ford Credit long term debt  Other long term debt  Deferred income taxes  \
# 1                 85533000000             470000000             439000000
#
# 0 Total liabilities   NaN EQUITY Common Stock Class B Stock  \
# 1      234452000000  None   None     40000000       1000000
#
# 0 Capital in excess of par value of stock Retained Earnings  \
# 1                             22150000000       17527000000
#
# 0 Accumulated other comprehensive income/ Treasury stock  \
# 1                              8461000000     1607000000
#
# 0 Total equity attributable to Ford Motor Company  \
# 1                                     29650000000
#
# 0 Equity attributable to noncontrolling interests Total equity  \
# 1                                        48000000  29698000000
#
# 0 Total liabilities and equity   NaN   NaN  \
# 1                 264150000000  None  None
#
# 0 The following table includes assets to be used to settle liabilities of the consolidated variable interest entities   \
# 1                                               None
#
# 0  31000000   NaN ASSETS        Cash Ford Credit finance receivables  \
# 1  31000000  None   None  2549000000                     54038000000
#
# 0 Net investment in operating leases Other assets LIABILITIES  \
# 1                        14410000000      1000000        None
#
# 0 Deferred Revenue         Debt
# 1        110000000  48379000000

# %%
def duplicate_columns( DataF ):
    
    try: 
        DataF.drop(DataF[None], axis =1, inplace=True)
        
    except:
        pass 
    
    new_col = list(DataF.columns)
    
    clean_col = [str(column).strip() for column in new_col ]

    DataF.set_axis(clean_col, axis=1, inplace=True)
    
    duplicates = [col_name for (col_name,freq) in Counter(DataF.columns).items() if freq > 1] 
    print('{} duplicates '.format(len(duplicates)), duplicates, '\n')
    
    for dupli in duplicates: 
#         print(type(DataF[dupli].values))            
        
        try:
            res = DataF[dupli].fillna(0).values.sum()
            DataF['Total {}'.format(dupli)] = res
            DataF.drop(columns =dupli, axis=1, inplace=True)

        except: 
            DataF.drop(columns =dupli, axis=1, inplace=True)

        #DataF.drop(dupli, axis=1, inplace=True)
        
    return DataF

# %%
df_list =[]
for k, v in QorK.items():
            
    for i, vv in enumerate(v):
        print(vv, k)
                
        dfs = pd.read_pickle( "{}-{}.csv".format(v[i], k))
        #dfm = dfs[0]
        
        #dfm.drop([2], inplace=True)
        
        # Add unique identity to row 
        dfs['Filing/Acc.No.'] = '{}, {}'.format(k, vv)
        print('original shape:', dfs.shape)
        
        final_df = duplicate_columns(dfs)
        ICD.display(final_df)
        # handle duplicate column name
        df_list.append( final_df )
        
        #print(df_list[0].shape)
        
#ICD.display(abt)
# Out:
# 0000037996-20-000041 10-Q
# original shape: (1, 61)
# 8 duplicates  ['ASSETS', 'Cash', 'Ford Credit finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q1  2020           20399000000                  6625000000
#
#      Inventory Assets held for sale Total current assets  \
# 1  11312000000            700000000         124276000000
#
#   Property and Equipment Equity in  assets of affiliated companies  \
# 1            35294000000                                2275000000
#
#    Total assets     Payables Automotive debt payable within one year  \
# 1  264150000000  18439000000                              1609000000
#
#   Ford Credit debt payable within one year Other debt payable within one year  \
# 1                              51303000000                               None
#
#   Liabilities held for sale Total current liabilities  \
# 1                 469000000               94494000000
#
#   Automotive long term debt Ford Credit long term debt Other long term debt  \
# 1               28411000000                85533000000            470000000
#
#   Total liabilities EQUITY Common Stock Class B Stock  \
# 1      234452000000   None     40000000       1000000
#
#   Capital in excess of par value of stock Retained Earnings  \
# 1                             22150000000       17527000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              8461000000     1607000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     29650000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        48000000  29698000000
#
#   Total liabilities and equity  \
# 1                 264150000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 1                                               None
#
#    31000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 1  31000000  48379000000  10-Q, 0000037996-20-000041             0
#
#     Total Cash  Total Ford Credit finance receivables  Total Other assets  \
# 1  28520000000                           160068000000         16109000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               42924000000                  11361000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             47889000000
# 0000037996-19-000078 10-Q
# original shape: (1, 63)
# 8 duplicates  ['ASSETS', 'Cash', 'Ford Credit finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q3  2019           16808000000                 10621000000
#
#      Inventory Assets of held for sale operations Total current assets  \
# 1  12451000000                               None         115754000000
#
#   Property and Equipment Equity in  assets of affiliated companies  \
# 1            35404000000                                2623000000
#
#    Total assets     Payables Automotive debt payable within one year  \
# 1  258157000000  22228000000                              1622000000
#
#   Ford Credit debt payable within one year Other debt payable within one year  \
# 1                              52852000000                               None
#
#   Liabilities of held for sale operations Total current liabilities  \
# 1                                    None               99087000000
#
#   Automotive long term debt Ford Credit long term debt Other long term debt  \
# 1               12615000000                86422000000            470000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 1      222770000000                               None   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             22179000000       22590000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              7842000000     1619000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     35349000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        38000000  35387000000
#
#   Total liabilities and equity  \
# 1                 258157000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 1                                               None
#
#    31000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 1  30000000  50981000000  10-Q, 0000037996-19-000078             0
#
#     Total Cash  Total Ford Credit finance receivables  Total Other assets  \
# 1  23183000000                           161259000000         14079000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               42123000000                  11124000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             45509000000
# 0000037996-19-000067 10-Q
# original shape: (1, 60)
# 8 duplicates  ['ASSETS', 'Cash', 'Ford Credit finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q2  2019           15931000000                 10941000000
#
#      Inventory Total current assets Property and Equipment  \
# 1  12437000000         118351000000            36581000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                2637000000  262184000000  22980000000
#
#   Automotive debt payable within one year  \
# 1                              2229000000
#
#   Ford Credit debt payable within one year Other debt payable within one year  \
# 1                              50492000000                               None
#
#   Total current liabilities Automotive long term debt  \
# 1               98334000000               11765000000
#
#   Ford Credit long term debt Other long term debt Total liabilities  \
# 1                90978000000            470000000      226048000000
#
#   Redeemable noncontrolling interest EQUITY Common Stock Class B Stock  \
# 1                               None   None     40000000       1000000
#
#   Capital in excess of par value of stock Retained Earnings  \
# 1                             22111000000       22769000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              7436000000     1388000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     36097000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        39000000  36136000000
#
#   Total liabilities and equity  \
# 1                 262184000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 1                                               None
#
#    31000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 1  30000000  51791000000  10-Q, 0000037996-19-000067             0
#
#     Total Cash  Total Ford Credit finance receivables  Total Other assets  \
# 1  25836000000                           165749000000         13966000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               43784000000                  10622000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             46597000000
# 0000037996-19-000026 10-Q
# original shape: (1, 59)
# 8 duplicates  ['ASSETS', 'Cash', 'Ford Credit finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q1  2019           16882000000                 12016000000
#
#      Inventory Total current assets Property and Equipment  \
# 1  12333000000         121195000000            36145000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                2605000000  263281000000  23325000000
#
#   Automotive debt payable within one year  \
# 1                              2523000000
#
#   Ford Credit debt payable within one year Other debt payable within one year  \
# 1                              51895000000                               None
#
#   Total current liabilities Automotive long term debt  \
# 1               99237000000               11087000000
#
#   Ford Credit long term debt Other long term debt Total liabilities  \
# 1                91055000000            470000000      226712000000
#
#   Redeemable noncontrolling interest EQUITY Common Stock Class B Stock  \
# 1                          135000000   None     40000000       1000000
#
#   Capital in excess of par value of stock Retained Earnings  \
# 1                             22026000000       23226000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              7501000000     1394000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     36398000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        36000000  36434000000
#
#   Total liabilities and equity  \
# 1                 263281000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 1                                               None
#
#    31000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 1  31000000  52248000000  10-Q, 0000037996-19-000026             0
#
#     Total Cash  Total Ford Credit finance receivables  Total Other assets  \
# 1  23838000000                           170521000000         13145000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               45242000000                  10963000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             45625000000
# 0000037996-18-000084 10-Q
# original shape: (1, 60)
# 8 duplicates  ['ASSETS', 'Cash', 'Ford Credit finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q3  2018           17780000000                 11244000000
#
#      Inventory Total current assets Property and Equipment  \
# 1  12810000000         114843000000            35762000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                2858000000  258966000000  23273000000
#
#   Automotive debt payable within one year  \
# 1                              3216000000
#
#   Ford Credit debt payable within one year Total current liabilities  \
# 1                              47547000000               94750000000
#
#   Automotive long term debt Ford Credit long term debt Other long term debt  \
# 1               11448000000                90620000000            600000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 1      222248000000                           99000000   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             22011000000       23384000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              7429000000     1417000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     36590000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        29000000  36619000000
#
#   Total liabilities and equity  \
# 1                 258966000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 1                                               None
#
#    31000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 1  30000000  50564000000  10-Q, 0000037996-18-000084             0
#
#     Total Cash  Total Ford Credit finance receivables  Total Other assets  \
# 1  21308000000                           164273000000         12051000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               41981000000                  11155000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             44944000000
# 0000037996-18-000063 10-Q
# original shape: (1, 60)
# 8 duplicates  ['ASSETS', 'Cash', 'Ford Credit finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q2  2018           19648000000                 11026000000
#
#      Inventory Total current assets Property and Equipment  \
# 1  12565000000         115025000000            35580000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                3087000000  258079000000  22743000000
#
#   Automotive debt payable within one year  \
# 1                              3968000000
#
#   Ford Credit debt payable within one year Total current liabilities  \
# 1                              46916000000               94861000000
#
#   Automotive long term debt Ford Credit long term debt Other long term debt  \
# 1               11642000000                89718000000            599000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 1      221511000000                           99000000   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             21953000000       22993000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              7204000000     1342000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     36441000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        28000000  36469000000
#
#   Total liabilities and equity  \
# 1                 258079000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 1                                               None
#
#    31000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 1  30000000  50012000000  10-Q, 0000037996-18-000063             0
#
#     Total Cash  Total Ford Credit finance receivables  Total Other assets  \
# 1  19907000000                           163305000000         11959000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               41572000000                  10955000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             45347000000
# 0000037996-18-000036 10-Q
# original shape: (1, 60)
# 8 duplicates  ['ASSETS', 'Cash', 'Ford Credit finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q1  2018           22131000000                 12386000000
#
#      Inventory Total current assets Property and Equipment  \
# 1  12371000000         123264000000            36118000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                3213000000  267230000000  25480000000
#
#   Automotive debt payable within one year  \
# 1                              3751000000
#
#   Ford Credit debt payable within one year Total current liabilities  \
# 1                              49232000000               99878000000
#
#   Automotive long term debt Ford Credit long term debt Other long term debt  \
# 1               12071000000                92681000000            599000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 1      230696000000                           98000000   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             21841000000       22529000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              6669000000     1342000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     36400000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        36000000  36436000000
#
#   Total liabilities and equity  \
# 1                 267230000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 1                                               None
#
#    31000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 1  31000000  50366000000  10-Q, 0000037996-18-000036             0
#
#     Total Cash  Total Ford Credit finance receivables  Total Other assets  \
# 1  20806000000                           170946000000         12365000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               40315000000                  11259000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             46265000000
# 0000037996-17-000092 10-Q
# original shape: (1, 59)
# 8 duplicates  ['ASSETS', 'Cash', 'Financial Services finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q3  2017           20492000000                 10277000000
#
#      Inventory Total current assets Property and Equipment  \
# 1  11263000000         112732000000            34760000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                3344000000  251273000000  23566000000
#
#   Automotive debt payable within one year  \
# 1                              3551000000
#
#   Financial Services debt payable within one year Total current liabilities  \
# 1                                     47623000000               94352000000
#
#   Automotive long term debt Financial Services long term debt  \
# 1               12633000000                       85305000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 1      217913000000                           97000000   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             21804000000       19405000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              6759000000     1253000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     33238000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        25000000  33263000000
#
#   Total liabilities and equity  \
# 1                 251273000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 1                                               None
#
#    31000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 1  30000000  43302000000  10-Q, 0000037996-17-000092             0
#
#     Total Cash  Total Financial Services finance receivables  \
# 1  20100000000                                  156698000000
#
#    Total Other assets  Total Net investment in operating leases  \
# 1         10671000000                               38622000000
#
#    Total Deferred income taxes  Total LIABILITIES  Total Deferred Revenue
# 1                  11163000000                  0             44433000000
# 0000037996-17-000068 10-Q
# original shape: (1, 59)
# 8 duplicates  ['ASSETS', 'Cash', 'Financial Services finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q2  2017           22886000000                 10159000000
#
#      Inventory Total current assets Property and Equipment  \
# 1  11092000000         113539000000            33794000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                3241000000  247469000000  23568000000
#
#   Automotive debt payable within one year  \
# 1                              2911000000
#
#   Financial Services debt payable within one year Total current liabilities  \
# 1                                     47862000000               94299000000
#
#   Automotive long term debt Financial Services long term debt  \
# 1               13277000000                       81959000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 1      215110000000                           97000000   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             21735000000       18437000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              6716000000     1253000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     32244000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        18000000  32262000000
#
#   Total liabilities and equity  \
# 1                 247469000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 1                                               None
#
#    31000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 1  30000000  43051000000  10-Q, 0000037996-17-000068             0
#
#     Total Cash  Total Financial Services finance receivables  \
# 1  18831000000                                  154798000000
#
#    Total Other assets  Total Net investment in operating leases  \
# 1          9932000000                               39600000000
#
#    Total Deferred income taxes  Total LIABILITIES  Total Deferred Revenue
# 1                  10880000000                  0             44800000000
# 0000037996-17-000036 10-Q
# original shape: (1, 59)
# 8 duplicates  ['ASSETS', 'Cash', 'Financial Services finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q1  2017           22166000000                 10685000000
#
#      Inventory Total current assets Property and Equipment  \
# 1  10535000000         113228000000            32668000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                3642000000  244094000000  23257000000
#
#   Automotive debt payable within one year  \
# 1                              3100000000
#
#   Financial Services debt payable within one year Total current liabilities  \
# 1                                     46157000000               91304000000
#
#   Automotive long term debt Financial Services long term debt  \
# 1               13110000000                       83610000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 1      213356000000                           97000000   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             21637000000       16992000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              6929000000     1122000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     30619000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        22000000  30641000000
#
#   Total liabilities and equity  \
# 1                 244094000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 1                                               None
#
#    31000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 1  31000000  42960000000  10-Q, 0000037996-17-000036             0
#
#     Total Cash  Total Financial Services finance receivables  \
# 1  20468000000                                  152159000000
#
#    Total Other assets  Total Net investment in operating leases  \
# 1          9336000000                               40239000000
#
#    Total Deferred income taxes  Total LIABILITIES  Total Deferred Revenue
# 1                  10804000000                  0             43377000000
# 0000037996-16-000158 10-Q
# original shape: (1, 59)
# 8 duplicates  ['ASSETS', 'Cash', 'Financial Services finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 0      Q3  2016           20825000000                 10029000000
#
#      Inventory Total current assets Property and Equipment  \
# 0  10219000000         103515000000            32257000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 0                                3795000000  234963000000  22384000000
#
#   Automotive debt payable within one year  \
# 0                              2472000000
#
#   Financial Services debt payable within one year Total current liabilities  \
# 0                                     44801000000               89188000000
#
#   Automotive long term debt Financial Services long term debt  \
# 0               10675000000                       79276000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 0      203368000000                           96000000   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 0       1000000                             21598000000       17013000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 0                              6046000000     1122000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     31484000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        15000000  31499000000
#
#   Total liabilities and equity  \
# 0                 234963000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 0                                               None
#
#      30000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 0  2016000000  39123000000  10-Q, 0000037996-16-000158             0
#
#     Total Cash  Total Financial Services finance receivables  \
# 0  15658000000                                  142791000000
#
#    Total Other assets  Total Net investment in operating leases  \
# 0         10670000000                               39147000000
#
#    Total Deferred income taxes  Total LIABILITIES  Total Deferred Revenue
# 0                  10052000000                  0             43193000000
# 0000037996-16-000133 10-Q
# original shape: (1, 59)
# 8 duplicates  ['ASSETS', 'Cash', 'Financial Services finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables   Inventory  \
# 0      Q2  2016           22234000000                 10728000000  9829000000
#
#   Total current assets Property and Equipment  \
# 0         110767000000            31940000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 0                                3349000000  239678000000  23084000000
#
#   Automotive debt payable within one year  \
# 0                              2417000000
#
#   Financial Services debt payable within one year Total current liabilities  \
# 0                                     42444000000               89408000000
#
#   Automotive long term debt Financial Services long term debt  \
# 0               10654000000                       84399000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 0      208429000000                           95000000   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 0       1000000                             21546000000       16652000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 0                              5976000000     1122000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     31141000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        13000000  31154000000
#
#   Total liabilities and equity  \
# 0                 239678000000
#
#   The following table includes assets to be used to settle liabilities of the consolidated variable interest entities  \
# 0                                               None
#
#      30000000         Debt              Filing/Acc.No.  Total ASSETS  \
# 0  2016000000  41515000000  10-Q, 0000037996-16-000133             0
#
#     Total Cash  Total Financial Services finance receivables  \
# 0  19481000000                                  145131000000
#
#    Total Other assets  Total Net investment in operating leases  \
# 0          9960000000                               41182000000
#
#    Total Deferred income taxes  Total LIABILITIES  Total Deferred Revenue
# 0                  10374000000                  0             44904000000
# 0000037996-16-000107 10-Q
# original shape: (1, 50)
# 8 duplicates  ['ASSETS', 'Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 0      Q1  2016           23556000000       11252000000  9770000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 0                                3820000000            31164000000
#
#    Total assets     Payables Automotive debt Financial Services debt  \
# 0  237288000000  22072000000     13022000000            127973000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Capital stock  \
# 0      207572000000                           95000000   None          None
#
#   Common Stock Class B Stock Capital in excess of par value of stock  \
# 0     40000000       1000000                             21454000000
#
#   Retained Earnings Accumulated other comprehensive income/ Treasury stock  \
# 0       15278000000                              6046000000     1122000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     29605000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        16000000  29621000000
#
#   Total liabilities and equity    31000000         Debt  \
# 0                 237288000000  2016000000  43258000000
#
#                Filing/Acc.No.  Total ASSETS   Total Cash  \
# 0  10-Q, 0000037996-16-000107             0  18519000000
#
#    Total Finance receivables  Total Net investment in operating leases  \
# 0               144315000000                               41507000000
#
#    Total Deferred income taxes  Total Other assets  Total LIABILITIES  \
# 0                  11135000000          8767000000                  0
#
#    Total Deferred Revenue
# 0             43975000000
# 0000037996-15-000064 10-Q
# original shape: (1, 49)
# 9 duplicates  ['ASSETS', 'Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Deferred Revenue', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 0      Q3  2015           17161000000       13373000000  9496000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 0                                3505000000            30137000000
#
#    Total assets     Payables Total liabilities  \
# 0  219431000000  22386000000      191853000000
#
#   Redeemable noncontrolling interest EQUITY Capital stock Common Stock  \
# 0                           94000000   None          None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 0       1000000                             21354000000       27489000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 0                             20442000000      977000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     27465000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        19000000  27484000000
#
#   Total liabilities and equity    30000000              Filing/Acc.No.  \
# 0                 219431000000  2015000000  10-Q, 0000037996-15-000064
#
#    Total ASSETS   Total Cash  Total Finance receivables  \
# 0             0  17129000000               129244000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 0                               38173000000                  11963000000
#
#    Total Other assets  Total LIABILITIES  Total Deferred Revenue    Total Debt
# 0          7588000000                  0             42543000000  168137000000
# 0000037996-15-000046 10-Q
# original shape: (1, 49)
# 9 duplicates  ['ASSETS', 'Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Deferred Revenue', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 0      Q2  2015           18405000000       12666000000  9438000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 0                                3469000000            30750000000
#
#    Total assets     Payables Total liabilities  \
# 0  216045000000  21844000000      189597000000
#
#   Redeemable noncontrolling interest EQUITY Capital stock Common Stock  \
# 0                           93000000   None          None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 0       1000000                             21317000000       26175000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 0                             20260000000      939000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     26334000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        21000000  26355000000
#
#   Total liabilities and equity    30000000              Filing/Acc.No.  \
# 0                 216045000000  2015000000  10-Q, 0000037996-15-000046
#
#    Total ASSETS   Total Cash  Total Finance receivables  \
# 0             0  15252000000               126384000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 0                               38026000000                  13075000000
#
#    Total Other assets  Total LIABILITIES  Total Deferred Revenue    Total Debt
# 0          7009000000                  0             43679000000  164121000000
# 0000037996-15-000029 10-Q
# original shape: (1, 49)
# 9 duplicates  ['ASSETS', 'Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Deferred Revenue', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 0      Q1  2015           20732000000       13005000000  9519000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 0                                3628000000            29612000000
#
#    Total assets     Payables Total liabilities  \
# 0  212374000000  22366000000      187311000000
#
#   Redeemable noncontrolling interest EQUITY Capital stock Common Stock  \
# 0                           89000000   None          None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 0       1000000                             21273000000       24887000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 0                             20406000000      848000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     24947000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        27000000  24974000000
#
#   Total liabilities and equity    31000000              Filing/Acc.No.  \
# 0                 212374000000  2015000000  10-Q, 0000037996-15-000029
#
#    Total ASSETS   Total Cash  Total Finance receivables  \
# 0             0  14700000000               120131000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 0                               34029000000                  13464000000
#
#    Total Other assets  Total LIABILITIES  Total Deferred Revenue    Total Debt
# 0          7558000000                  0             41682000000  162185000000
# 0000037996-14-000057 10-Q
# original shape: (1, 49)
# 9 duplicates  ['ASSETS', 'Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Deferred Revenue', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 0      Q3  2014           20643000000       11143000000  9296000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 0                                3103000000            30048000000
#
#    Total assets     Payables Total liabilities  \
# 0  208835000000  21155000000      182331000000
#
#   Redeemable noncontrolling interest EQUITY Capital stock Common Stock  \
# 0                          339000000   None          None     39000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 0       1000000                             21680000000       25051000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 0                             18165000000     2470000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     26136000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        29000000  26165000000
#
#   Total liabilities and equity    30000000              Filing/Acc.No.  \
# 0                 208835000000  2014000000  10-Q, 0000037996-14-000057
#
#    Total ASSETS   Total Cash  Total Finance receivables  \
# 0             0  15342000000               117472000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 0                               32937000000                  12888000000
#
#    Total Other assets  Total LIABILITIES  Total Deferred Revenue    Total Debt
# 0          6091000000                  0             41425000000  155062000000
# 0000037996-14-000043 10-Q
# original shape: (1, 49)
# 9 duplicates  ['ASSETS', 'Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Deferred Revenue', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 0      Q2  2014           24096000000       12853000000  9365000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 0                                3356000000            29294000000
#
#    Total assets     Payables Total liabilities  \
# 0  210945000000  22062000000      183801000000
#
#   Redeemable noncontrolling interest EQUITY Capital stock Common Stock  \
# 0                          337000000   None          None     39000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 0       1000000                             21605000000       24699000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 0                             18107000000     1461000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     26776000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        31000000  26807000000
#
#   Total liabilities and equity    30000000              Filing/Acc.No.  \
# 0                 210945000000  2014000000  10-Q, 0000037996-14-000043
#
#    Total ASSETS   Total Cash  Total Finance receivables  \
# 0             0  13759000000               123111000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 0                               31081000000                  13184000000
#
#    Total Other assets  Total LIABILITIES  Total Deferred Revenue    Total Debt
# 0          5720000000                  0             42484000000  157029000000
# 0000037996-14-000023 10-Q
# original shape: (1, 49)
# 9 duplicates  ['ASSETS', 'Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Deferred Revenue', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 0      Q1  2014           23546000000       12088000000  8874000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 0                                3982000000            28447000000
#
#    Total assets     Payables Total liabilities  \
# 0  207082000000  22209000000      179944000000
#
#   Redeemable noncontrolling interest EQUITY Capital stock Common Stock  \
# 0                          331000000   None          None     39000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 0       1000000                             21547000000       23882000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 0                             18190000000      506000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     26773000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        34000000  26807000000
#
#   Total liabilities and equity    31000000              Filing/Acc.No.  \
# 0                 207082000000  2014000000  10-Q, 0000037996-14-000023
#
#    Total ASSETS   Total Cash  Total Finance receivables  \
# 0             0  15751000000               122216000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 0                               29616000000                  13724000000
#
#    Total Other assets  Total LIABILITIES  Total Deferred Revenue    Total Debt
# 0          6232000000                  0             40214000000  155987000000
# 0000037996-13-000055 10-Q
# original shape: (1, 51)
# 9 duplicates  ['ASSETS', 'Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Accrued Liabilities', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 0      Q3  2013           22890000000       11693000000  8799000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 0                                3466000000            26836000000
#
#   Net intangible assets Assets held for sale  Total assets     Payables  \
# 0              86000000             98000000  201071000000  21640000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Capital stock  \
# 0      180232000000                          329000000   None          None
#
#   Common Stock Class B Stock Capital in excess of par value of stock  \
# 0     39000000       1000000                             21378000000
#
#   Retained Earnings Accumulated other comprehensive income/ Treasury stock  \
# 0       21014000000                             21509000000      456000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     20467000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        43000000  20510000000
#
#   Total liabilities and equity    30000000              Filing/Acc.No.  \
# 0                 201071000000  2013000000  10-Q, 0000037996-13-000055
#
#    Total ASSETS   Total Cash  Total Finance receivables  \
# 0             0  17457000000               116524000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 0                               27922000000                  13660000000
#
#    Total Other assets  Total LIABILITIES  Total Accrued Liabilities  \
# 0          5055000000                  0                47409000000
#
#      Total Debt
# 0  149159000000
# 0000037996-13-000042 10-Q
# original shape: (1, 51)
# 9 duplicates  ['ASSETS', 'Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Accrued Liabilities', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 0      Q2  2013           23344000000       11353000000  8192000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 0                                3223000000            25863000000
#
#   Net intangible assets Assets held for sale  Total assets     Payables  \
# 0              82000000            264000000  196210000000  20961000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Capital stock  \
# 0      176661000000                          327000000   None          None
#
#   Common Stock Class B Stock Capital in excess of par value of stock  \
# 0     39000000       1000000                             21219000000
#
#   Retained Earnings Accumulated other comprehensive income/ Treasury stock  \
# 0       20136000000                             21837000000      379000000
#
#   Total equity attributable to Ford Motor Company  \
# 0                                     19179000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                        43000000  19222000000
#
#   Total liabilities and equity    30000000              Filing/Acc.No.  \
# 0                 196210000000  2013000000  10-Q, 0000037996-13-000042
#
#    Total ASSETS   Total Cash  Total Finance receivables  \
# ...
#
#   Liabilities held for sale Total current liabilities  \
# 1                      None               98132000000
#
#   Automotive long term debt Ford Credit long term debt Other long term debt  \
# 1               13233000000                87658000000            470000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 1      225307000000                               None   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             22165000000       20320000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              7728000000     1613000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     33185000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        45000000  33230000000
#
#   Total liabilities and equity  31000000 ASSETS         Debt  \
# 1                 258537000000  31000000   None  50865000000
#
#                Filing/Acc.No.   Total Cash  \
# 1  10-K, 0000037996-20-000010  20706000000
#
#    Total Ford Credit finance receivables  Total Other assets  \
# 1                           165832000000         14057000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               44113000000                  12353000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             48330000000
# 0000037996-19-000012 10-K
# original shape: (1, 57)
# 7 duplicates  ['Cash', 'Ford Credit finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q4  2018           17233000000                 11195000000
#
#      Inventory Total current assets Property and Equipment  \
# 1  11220000000         114649000000            36178000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                2709000000  256540000000  21520000000
#
#   Automotive debt payable within one year  \
# 1                              2314000000
#
#   Ford Credit debt payable within one year Total current liabilities  \
# 1                              51179000000               95569000000
#
#   Automotive long term debt Ford Credit long term debt Other long term debt  \
# 1               11233000000                88887000000            600000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 1      220474000000                          100000000   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             22006000000       22668000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              7366000000     1417000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     35932000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        34000000  35966000000
#
#   Total liabilities and equity  31000000 ASSETS         Debt  \
# 1                 256540000000  31000000   None  53269000000
#
#                Filing/Acc.No.   Total Cash  \
# 1  10-K, 0000037996-19-000012  19446000000
#
#    Total Ford Credit finance receivables  Total Other assets  \
# 1                           168559000000         11886000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               45451000000                  11009000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             44168000000
# 0000037996-18-000015 10-K
# original shape: (1, 56)
# 7 duplicates  ['Cash', 'Financial Services finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables  \
# 1      Q4  2017           20435000000                 10599000000
#
#      Inventory Total current assets Property and Equipment  \
# 1  10277000000         115902000000            35327000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                3085000000  257808000000  23282000000
#
#   Automotive debt payable within one year  \
# 1                              3356000000
#
#   Financial Services debt payable within one year Total current liabilities  \
# 1                                     48265000000               94600000000
#
#   Automotive long term debt Financial Services long term debt  \
# 1               12575000000                       90091000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Common Stock  \
# 1      222792000000                           98000000   None     40000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             21843000000       21218000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                              6959000000     1253000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     34890000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        28000000  34918000000
#
#   Total liabilities and equity  31000000 ASSETS         Debt  \
# 1                 257808000000  31000000   None  46437000000
#
#                Filing/Acc.No.   Total Cash  \
# 1  10-K, 0000037996-18-000015  21971000000
#
#    Total Financial Services finance receivables  Total Other assets  \
# 1                                  164642000000         12057000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               39738000000                  11788000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             44410000000
# 0000037996-17-000013 10-K
# original shape: (1, 57)
# 7 duplicates  ['Cash', 'Financial Services finance receivables', 'Other assets', 'Net investment in operating leases', 'Deferred income taxes', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Trade and other receivables   Inventory  \
# 1      Q4  2016           22922000000                 11102000000  8898000000
#
#   Total current assets Property and Equipment  \
# 1         108461000000            32072000000
#
#   Equity in  assets of affiliated companies  Total assets     Payables  \
# 1                                3304000000  237951000000  21296000000
#
#   Automotive debt payable within one year  \
# 1                              2685000000
#
#   Financial Services debt payable within one year Total current liabilities  \
# 1                                     46984000000               90281000000
#
#   Automotive long term debt Financial Services long term debt  \
# 1               13222000000                       80079000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Capital stock  \
# 1      208668000000                           96000000   None          None
#
#   Common Stock Class B Stock Capital in excess of par value of stock  \
# 1     40000000       1000000                             21630000000
#
#   Retained Earnings Accumulated other comprehensive income/ Treasury stock  \
# 1       15634000000                              7013000000     1122000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     29170000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        17000000  29187000000
#
#   Total liabilities and equity  31000000 ASSETS         Debt  \
# 1                 237951000000  31000000   None  43730000000
#
#                Filing/Acc.No.   Total Cash  \
# 1  10-K, 0000037996-17-000013  18952000000
#
#    Total Financial Services finance receivables  Total Other assets  \
# 1                                  147047000000          9049000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               40590000000                  10396000000
#
#    Total LIABILITIES  Total Deferred Revenue
# 1                  0             43716000000
# 0000037996-16-000092 10-K
# original shape: (1, 48)
# 7 duplicates  ['Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Deferred Revenue']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 1      Q4  2015           20393000000       11708000000  7870000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 1                                3357000000            30126000000
#
#    Total assets     Payables Automotive debt Financial Services debt  \
# 1  208615000000  20035000000     13824000000            105347000000
#
#   Total liabilities Redeemable noncontrolling interest EQUITY Capital stock  \
# 1      183808000000                          342000000   None          None
#
#   Common Stock Class B Stock Capital in excess of par value of stock  \
# 1     39000000       1000000                             21089000000
#
#   Retained Earnings Accumulated other comprehensive income/ Treasury stock  \
# 1        9422000000                              5265000000      848000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     24438000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        27000000  24465000000
#
#   Total liabilities and equity  31000000 ASSETS         Debt  \
# 1                 208615000000  31000000   None  37156000000
#
#                Filing/Acc.No.   Total Cash  Total Finance receivables  \
# 1  10-K, 0000037996-16-000092  12851000000               120633000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               32848000000                  14594000000
#
#    Total Other assets  Total LIABILITIES  Total Deferred Revenue
# 1          6079000000                  0             44054000000
# 0000037996-15-000013 10-K
# original shape: (1, 47)
# 8 duplicates  ['Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Deferred Revenue', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 1      Q4  2014           22100000000        9828000000  7708000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 1                                3679000000            27616000000
#
#    Total assets     Payables Total liabilities  \
# 1  202179000000  19531000000      175703000000
#
#   Redeemable noncontrolling interest EQUITY Capital stock Common Stock  \
# 1                          331000000   None          None     39000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             21422000000       23386000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                             18230000000      506000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     26112000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        33000000  26145000000
#
#   Total liabilities and equity  31000000 ASSETS              Filing/Acc.No.  \
# 1                 202179000000  31000000   None  10-K, 0000037996-15-000013
#
#     Total Cash  Total Finance receivables  \
# 1  18666000000               123277000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               28100000000                  14066000000
#
#    Total Other assets  Total LIABILITIES  Total Deferred Revenue    Total Debt
# 1          5852000000                  0             40974000000  155416000000
# 0000037996-14-000010 10-K
# original shape: (1, 47)
# 8 duplicates  ['Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Deferred Revenue', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 1      Q4  2013           20284000000       10878000000  7362000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 1                                3246000000            24942000000
#
#    Total assets     Payables Total liabilities  \
# 1  189406000000  19308000000      173095000000
#
#   Redeemable noncontrolling interest EQUITY Capital stock Common Stock  \
# 1                          322000000   None          None     39000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             20976000000       18077000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                             22854000000      292000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     15947000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        42000000  15989000000
#
#   Total liabilities and equity  31000000 ASSETS              Filing/Acc.No.  \
# 1                 189406000000  31000000   None  10-K, 0000037996-14-000010
#
#     Total Cash  Total Finance receivables  \
# 1  18570000000               118506000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               21611000000                  15655000000
#
#    Total Other assets  Total LIABILITIES  Total Deferred Revenue    Total Debt
# 1          5560000000                  0             48393000000  145303000000
# 0000037996-13-000014 10-K
# original shape: (1, 48)
# 8 duplicates  ['Cash', 'Finance receivables', 'Net investment in operating leases', 'Deferred income taxes', 'Other assets', 'LIABILITIES', 'Accrued Liabilities', 'Debt']
#   Quarter  Year Marketable securities Other receivables   Inventory  \
# 1      Q4  2012           18618000000        8565000000  5901000000
#
#   Equity in  assets of affiliated companies Property and Equipment  \
# 1                                2936000000            22371000000
#
#   Net intangible assets  Total assets     Payables Total liabilities  \
# 1             100000000  178348000000  17724000000      163277000000
#
#   Redeemable noncontrolling interest EQUITY Capital stock Common Stock  \
# 1                               None   None          None     37000000
#
#   Class B Stock Capital in excess of par value of stock Retained Earnings  \
# 1       1000000                             20905000000       12985000000
#
#   Accumulated other comprehensive income/ Treasury stock  \
# 1                             18734000000      166000000
#
#   Total equity attributable to Ford Motor Company  \
# 1                                     15028000000
#
#   Equity attributable to noncontrolling interests Total equity  \
# 1                                        43000000  15071000000
#
#   Total liabilities and equity  31000000 ASSETS              Filing/Acc.No.  \
# 1                 178348000000  31000000   None  10-K, 0000037996-13-000014
#
#     Total Cash  Total Finance receivables  \
# 1  20550000000               119771000000
#
#    Total Net investment in operating leases  Total Deferred income taxes  \
# 1                               19192000000                  15821000000
#
#    Total Other assets  Total LIABILITIES  Total Accrued Liabilities  \
# 1          4927000000                  0                45466000000
#
#      Total Debt
# 1  140909000000

# %%
abt = pd.concat(df_list, sort=False)

# %%
abt.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Exploring the ABT

# %%
# All column names are unique, the duplicate column function did its job.
original_col = list(abt.columns)
len(original_col) == len(set(original_col))
# Out:
# True

# %%
original_col
# Out:
# ['Quarter',
#  'Year',
#  'Marketable securities',
#  'Trade and other receivables',
#  'Inventory',
#  'Assets held for sale',
#  'Total current assets',
#  'Property and Equipment',
#  'Equity in  assets of affiliated companies',
#  'Total assets',
#  'Payables',
#  'Automotive debt payable within one year',
#  'Ford Credit debt payable within one year',
#  'Other debt payable within one year',
#  'Liabilities held for sale',
#  'Total current liabilities',
#  'Automotive long term debt',
#  'Ford Credit long term debt',
#  'Other long term debt',
#  'Total liabilities',
#  'EQUITY',
#  'Common Stock',
#  'Class B Stock',
#  'Capital in excess of par value of stock',
#  'Retained Earnings',
#  'Accumulated other comprehensive income/',
#  'Treasury stock',
#  'Total equity attributable to Ford Motor Company',
#  'Equity attributable to noncontrolling interests',
#  'Total equity',
#  'Total liabilities and equity',
#  'The following table includes assets to be used to settle liabilities of the consolidated variable interest entities',
#  '31000000',
#  'Debt',
#  'Filing/Acc.No.',
#  'Total ASSETS',
#  'Total Cash',
#  'Total Ford Credit finance receivables',
#  'Total Other assets',
#  'Total Net investment in operating leases',
#  'Total Deferred income taxes',
#  'Total LIABILITIES',
#  'Total Deferred Revenue',
#  'Assets of held for sale operations',
#  'Liabilities of held for sale operations',
#  'Redeemable noncontrolling interest',
#  'Financial Services debt payable within one year',
#  'Financial Services long term debt',
#  'Total Financial Services finance receivables',
#  '30000000',
#  'Other receivables',
#  'Automotive debt',
#  'Financial Services debt',
#  'Capital stock',
#  'Total Finance receivables',
#  'Total Debt',
#  'Net intangible assets',
#  'Total Accrued Liabilities',
#  'ASSETS']

# %%
payable_list =['Payables', 'Automotive debt payable within one year',
 'Ford Credit debt payable within one year',
 'Other debt payable within one year',  'Financial Services debt payable within one year']

# %%
abt[payable_list]
# Out:
#        Payables Automotive debt payable within one year  \
# 0   18439000000                              1609000000
# 1   22228000000                              1622000000
# 2   22980000000                              2229000000
# 3   23325000000                              2523000000
# 4   23273000000                              3216000000
# 5   22743000000                              3968000000
# 6   25480000000                              3751000000
# 7   23566000000                              3551000000
# 8   23568000000                              2911000000
# 9   23257000000                              3100000000
# 10  22384000000                              2472000000
# 11  23084000000                              2417000000
# 12  22072000000                                     NaN
# 13  22386000000                                     NaN
# 14  21844000000                                     NaN
# 15  22366000000                                     NaN
# 16  21155000000                                     NaN
# 17  22062000000                                     NaN
# 18  22209000000                                     NaN
# 19  21640000000                                     NaN
# 20  20961000000                                     NaN
# 21  20600000000                                     NaN
# 22  20673000000                              1445000000
# 23  21520000000                              2314000000
# 24  23282000000                              3356000000
# 25  21296000000                              2685000000
# 26  20035000000                                     NaN
# 27  19531000000                                     NaN
# 28  19308000000                                     NaN
# 29  17724000000                                     NaN
#
#    Ford Credit debt payable within one year  \
# 0                               51303000000
# 1                               52852000000
# 2                               50492000000
# 3                               51895000000
# 4                               47547000000
# 5                               46916000000
# 6                               49232000000
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                              52371000000
# 23                              51179000000
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
#
#    Other debt payable within one year  \
# 0                                None
# 1                                None
# 2                                None
# 3                                None
# 4                                 NaN
# 5                                 NaN
# 6                                 NaN
# 7                                 NaN
# 8                                 NaN
# 9                                 NaN
# 10                                NaN
# 11                                NaN
# 12                                NaN
# 13                                NaN
# 14                                NaN
# 15                                NaN
# 16                                NaN
# 17                                NaN
# 18                                NaN
# 19                                NaN
# 20                                NaN
# 21                                NaN
# 22                               None
# 23                                NaN
# 24                                NaN
# 25                                NaN
# 26                                NaN
# 27                                NaN
# 28                                NaN
# 29                                NaN
#
#    Financial Services debt payable within one year
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                      47623000000
# 8                                      47862000000
# 9                                      46157000000
# 10                                     44801000000
# 11                                     42444000000
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                             NaN
# 21                                             NaN
# 22                                             NaN
# 23                                             NaN
# 24                                     48265000000
# 25                                     46984000000
# 26                                             NaN
# 27                                             NaN
# 28                                             NaN
# 29                                             NaN

# %% [markdown]
# ## Receivables

# %%
Receivable_list = ['Trade and other receivables', 'Total Ford Credit finance receivables', 'Total Financial Services finance receivables', 'Other receivables', 'Total Finance receivables']

# %%
abt[['Total Ford Credit finance receivables', 'Total Financial Services finance receivables', 'Total Finance receivables']]
# Out:
#     Total Ford Credit finance receivables  \
# 0                          160068000000.0
# 1                          161259000000.0
# 2                          165749000000.0
# 3                          170521000000.0
# 4                          164273000000.0
# 5                          163305000000.0
# 6                          170946000000.0
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                         165832000000.0
# 23                         168559000000.0
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
#
#     Total Financial Services finance receivables  Total Finance receivables
# 0                                            NaN                        NaN
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
# 3                                            NaN                        NaN
# 4                                            NaN                        NaN
# 5                                            NaN                        NaN
# 6                                            NaN                        NaN
# 7                                 156698000000.0                        NaN
# 8                                 154798000000.0                        NaN
# 9                                 152159000000.0                        NaN
# 10                                142791000000.0                        NaN
# 11                                145131000000.0                        NaN
# 12                                           NaN             144315000000.0
# 13                                           NaN             129244000000.0
# 14                                           NaN             126384000000.0
# 15                                           NaN             120131000000.0
# 16                                           NaN             117472000000.0
# 17                                           NaN             123111000000.0
# 18                                           NaN             122216000000.0
# 19                                           NaN             116524000000.0
# 20                                           NaN             116866000000.0
# 21                                           NaN             119249000000.0
# 22                                           NaN                        NaN
# 23                                           NaN                        NaN
# 24                                164642000000.0                        NaN
# 25                                147047000000.0                        NaN
# 26                                           NaN             120633000000.0
# 27                                           NaN             123277000000.0
# 28                                           NaN             118506000000.0
# 29                                           NaN             119771000000.0

# %%
abt['Accounts Receivable'] = abt[['Total Ford Credit finance receivables', 'Total Financial Services finance receivables', 'Total Finance receivables']].sum(axis=1)
abt.drop(Receivable_list, axis=1, inplace=True)

# %%
abt['Accounts Receivable']
# Out:
# 0     160068000000.0
# 1     161259000000.0
# 2     165749000000.0
# 3     170521000000.0
# 4     164273000000.0
# 5     163305000000.0
# 6     170946000000.0
# 7     156698000000.0
# 8     154798000000.0
# 9     152159000000.0
# 10    142791000000.0
# 11    145131000000.0
# 12    144315000000.0
# 13    129244000000.0
# 14    126384000000.0
# 15    120131000000.0
# 16    117472000000.0
# 17    123111000000.0
# 18    122216000000.0
# 19    116524000000.0
# 20    116866000000.0
# 21    119249000000.0
# 22    165832000000.0
# 23    168559000000.0
# 24    164642000000.0
# 25    147047000000.0
# 26    120633000000.0
# 27    123277000000.0
# 28    118506000000.0
# 29    119771000000.0
# Name: Accounts Receivable, dtype: float64

# %% [markdown]
# ### After running the del_empty_col one-time we get a list of columns that will be deleted.

# %%
new_col = ['Quarter', 'Year', 'Marketable securities',
       'Trade and other receivables', 'Inventory', 'Total current assets',
       'Property and Equipment', 'Equity in  assets of affiliated companies',
       'Total assets', 'Payables', 'Automotive debt payable within one year',
       'Total current liabilities', 'Automotive long term debt',
       'Total liabilities', 'Common Stock', 'Class B Stock',
       'Capital in excess of par value of stock', 'Retained Earnings',
       'Accumulated other comprehensive income/', 'Treasury stock',
       'Total equity attributable to Ford Motor Company',
       'Equity attributable to noncontrolling interests', 'Total equity',
       'Total liabilities and equity', '31000000', 'Debt', 'Filing/Acc.No.',
       'Total Cash', 'Total Other assets',
       'Total Net investment in operating leases',
       'Total Deferred income taxes', 'Total Deferred Revenue',
       'Redeemable noncontrolling interest']

# %% [markdown]
# ### But if left unattended, a lot of data will be unused.

# %%
### Following was deleted using .isna().astype(int).mean() > 0.1
del_col = set(original_col) - set(new_col)
print(f'{len(del_col)} of {len(original_col)} columns was deleted.')
print(del_col)
# Out:
# 26 of 59 columns was deleted.
# {'Liabilities held for sale', 'Assets held for sale', 'Total Finance receivables', 'Financial Services debt', 'Financial Services debt payable within one year', 'Other debt payable within one year', 'Ford Credit long term debt', 'Assets of held for sale operations', 'ASSETS', 'Total Debt', 'Net intangible assets', 'Other long term debt', 'Other receivables', 'Total LIABILITIES', 'Total Ford Credit finance receivables', 'Automotive debt', 'Liabilities of held for sale operations', 'Total Accrued Liabilities', '30000000', 'Financial Services long term debt', 'Total ASSETS', 'Total Financial Services finance receivables', 'EQUITY', 'Ford Credit debt payable within one year', 'The following table includes assets to be used to settle liabilities of the consolidated variable interest entities', 'Capital stock'}

# %%
# What is the percentage of nulls in a given column.
count = 1
shares = []
for columns in abt:
    
    ratio = abt[columns].notna().astype(int).mean()
    if  1 > ratio > 0.5:
        print(f' {count}.  "{columns}" ')
        print( ratio )
        print()
        count+=1
        shares.append(columns)
        
print('Length of Shares: ',len(shares) )
print( shares )
# Out:
#  1.  "Total current assets"
# 0.5333333333333333
#
#  2.  "Automotive debt payable within one year"
# 0.5333333333333333
#
#  3.  "Total current liabilities"
# 0.5333333333333333
#
#  4.  "Automotive long term debt"
# 0.5333333333333333
#
#  5.  "31000000"
# 0.7333333333333333
#
#  6.  "Debt"
# 0.6
#
#  7.  "Total ASSETS"
# 0.7333333333333333
#
#  8.  "Total Deferred Revenue"
# 0.8666666666666667
#
#  9.  "Redeemable noncontrolling interest"
# 0.8333333333333334
#
# Length of Shares:  9
# ['Total current assets', 'Automotive debt payable within one year', 'Total current liabilities', 'Automotive long term debt', '31000000', 'Debt', 'Total ASSETS', 'Total Deferred Revenue', 'Redeemable noncontrolling interest']

# %% [markdown]
# ##  Deleting columns with null values above a certain threshold.

# %%
def del_empty_col( df ):
    
    for columns in df:
        
        df.replace(0, np.nan, inplace=True)
        
        if df[columns].notna().astype(int).mean() < 0.5:
            df.drop([columns], inplace=True, axis=1)
            
    df.fillna(0)
        
    return df

# %%
test_df = del_empty_col(abt).fillna(0)

# %%
# Just for checking.
def checking_duplicate_columns( DataF ):
    
    duplicates = [k for (k,v) in Counter(DataF.columns).items() if v > 1] 
    
    print('Shape of df: ', DataF.shape )
    return duplicates

# %%
checking_duplicate_columns(abt)
# Out:
# Shape of df:  (30, 33)
# []

# %%
abt['Total Cash']
# Out:
# 0     28520000000
# 1     23183000000
# 2     25836000000
# 3     23838000000
# 4     21308000000
# 5     19907000000
# 6     20806000000
# 7     20100000000
# 8     18831000000
# 9     20468000000
# 10    15658000000
# 11    19481000000
# 12    18519000000
# 13    17129000000
# 14    15252000000
# 15    14700000000
# 16    15342000000
# 17    13759000000
# 18    15751000000
# 19    17457000000
# 20    16200000000
# 21    16797000000
# 22    20706000000
# 23    19446000000
# 24    21971000000
# 25    18952000000
# 26    12851000000
# 27    18666000000
# 28    18570000000
# 29    20550000000
# Name: Total Cash, dtype: int64

# %%
abt.to_csv('abt-Ford.csv', index=False)

# %%
ford_col = list(abt.columns)
print(len(ford_col))
# Out:
# 33

# %% [markdown]
# https://stackoverflow.com/questions/50950614/converting-column-into-multi-index-column

# %%
[entry for tag in tags for entry in entries if tag in entry]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-aeff2890e80b> in <module>
# ----> 1 [entry for tag in tags for entry in entries if tag in entry]
#
# NameError: name 'tags' is not defined

# %%
common = [  name  for name in apple_col and ford_col ]
print(common[0])

# %%
print(len(common))

# %%
type(common[0])

# %%
set_apple = set(apple_col)
print(set_apple)
set_ford = set(ford_col)
print(set_ford)

# %%
print(set_ford & set_apple)
