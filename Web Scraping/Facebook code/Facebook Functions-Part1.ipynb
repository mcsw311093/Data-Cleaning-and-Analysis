# %% [markdown]
# # Capstone Project

# %% [markdown]
# # Libraries

# %%
# Import Library 

import re
import requests
import unicodedata
from bs4 import BeautifulSoup
from pprint import pprint
import numpy as np
from numpy import array
import pandas as pd 
import csv
import pickle
from IPython.display import display
import pickle
from collections import Counter
pd.set_option('display.max_columns', 100)
from IPython.core import display as ICD

# %% [markdown]
# # Define Text Normalization Function

# %%
def restore_windows_1252_characters(restore_string):
    """
    Replace C1 control characters in the Unicode string s by the
    characters at the corresponding code points in Windows-1252,
    where possible.
    """

def to_windows_1252(match):
    try:
        return bytes([ord(match.group(0))]).decode('windows-1252')
    except UnicodeDecodeError:
        # No character at the corresponding code point: remove it.
        return ''

    return re.sub(r'[\u0080-\u0099]', to_windows_1252, restore_string)

# %% [markdown]
# # Grab the Document Content

# %%
def grab_doc_content( brand, CIK ):
    
    company = {}
    
    company['auto'] = {}
    auto = {brand : CIK
           }
    company['auto'] = auto 

    key = list(auto.copy().values())
    
    return key

# %%
grab_doc_content('Facebook', '0001326801')
# Out:
# ['0001326801']

# %%
master_filings_dict = {}
    
file_code = {}
    
file_text = {}

Accession_Number_URL = {}

# %%
# URL Directory For CIK    
dir_url = r'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-&dateb=&owner=include&count=100'
dir_url_list = [dir_url.format(x) for x in grab_doc_content('Facebook', '0001326801')]

#print('Directory URL: {}'.format(dir_url_list))
doc_url_list = [] 

# FOR-loop yielding Accession Numbers from CIK/URL Directory.
for CIK_num in grab_doc_content('Facebook', '0001326801'):

    doc_url = r'https://www.sec.gov/Archives/edgar/data/{CIKx}/{xx}/{yy}.txt'
    doc_url_new = doc_url.format(CIKx = CIK_num, xx='{xx}', yy ='{yy}')
    doc_url_list.append(doc_url_new)

# %%
def url_maker(dir_url):
    dir_url_list = [dir_url.format(x) for x in grab_doc_content('Facebook', '0001326801')]

    #print('Directory URL: {}'.format(dir_url_list))
    doc_url_list = [] 

    # FOR-loop yielding Accession Numbers from CIK/URL Directory.
    for CIK_num in grab_doc_content('Facebook', '0001326801'):

        doc_url = r'https://www.sec.gov/Archives/edgar/data/{CIKx}/{xx}/{yy}.txt'
        doc_url_new = doc_url.format(CIKx = CIK_num, xx='{xx}', yy ='{yy}')
        
        doc_url_list.append(doc_url_new)
        
        url_lists = zip( dir_url_list , doc_url_list )
        
    return url_lists

# %%
url = r'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-&dateb=&owner=include&count=100'
for dir_url, doc_url in url_maker(url): 
    print(1, dir_url)
    print(2, doc_url)
# Out:
# 1 https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK=0001326801&type=10-&dateb=&owner=include&count=100
# 2 https://www.sec.gov/Archives/edgar/data/0001326801/{xx}/{yy}.txt

# %%
Accession_Number_URL = {}
url = r'https://www.sec.gov/cgi-bin/browse-edgar?action=getcompany&CIK={}&type=10-&dateb=&owner=include&count=100'

for dir_url, doc_url in url_maker(url):
    
    response = requests.get(dir_url)
    soup = BeautifulSoup(response.content, 'lxml')
    text = soup.get_text(strip=True)

    cleaned_text = re.findall('Acc-no: \d+-\d+-\d+' , text)

    accession_number = [n.replace('Acc-no: ', '') for n in cleaned_text]
    accessionnumber = [num.replace('-', '') for num in accession_number]

    accession_numbers = zip(accessionnumber, accession_number)
    
    cikk = [ cikk_.replace('CIK=', '') for cikk_ in re.findall('CIK=\d+', dir_url) ][0]
    CIKK = {cikk : accessionnumber}
    
    for (a,b) in accession_numbers: 
        master_filings_dict[b] = {}
        master_filings_dict[b]['sec_header_content'] = {}
        master_filings_dict[b]['filing_documents'] = None

        doc_url_single = doc_url.format(xx = a, yy = b)

        file_url_list = []

        

        file_url_list.append( doc_url_single )
        
        Accession_Number_URL.update({ b : file_url_list})

# %%
A_N = []
for AN, url in Accession_Number_URL.items():
    
    if AN == '0001326801-14-000068':
        break
        
    else:
        A_N.append(AN)

print(A_N)
print(len(A_N))
# Out:
# ['0001326801-20-000048', '0001326801-20-000013', '0001326801-19-000069', '0001326801-19-000055', '0001326801-19-000037', '0001326801-19-000009', '0001326801-18-000067', '0001326801-18-000057', '0001326801-18-000032', '0001326801-18-000009', '0001326801-17-000053', '0001326801-17-000038', '0001326801-17-000024', '0001326801-17-000007', '0001326801-16-000087', '0001326801-16-000082', '0001326801-16-000067', '0001326801-16-000063', '0001326801-16-000043', '0001326801-15-000032', '0001326801-15-000028', '0001326801-15-000015', '0001326801-15-000010', '0001326801-15-000006']
# 24

# %% [markdown]
# ## Save each Filing.

# %%
QorK = {'10-Q' : [],
        '10-K' : []
       }

for acc_num, url in Accession_Number_URL.items():
    
    master_document_dict = {}
    
    # create a stop point
    if acc_num == '0001326801-14-000068':
        break

    else:
        
        # grab the response
        response = requests.get(url[0])

    # Soupify
        # pass it through the parser, in this case let's just use lxml because the tags seem to follow xml.
        soup = BeautifulSoup(response.content, 'lxml')
        filing_document = soup.find('document')
        
    # Parsing
        # Document type ->> document_id
        document_id = filing_document.type.find(text=True, recursive=False).strip()
        # Document sequence ->> document_sequence
        document_sequence = filing_document.sequence.find(text=True, recursive=False).strip()
        # Document filename ->> document_filename
        document_filename = filing_document.filename.find(text=True, recursive=False).strip()
        # Document description ->> document_description
        document_description = filing_document.description.find(text=True, recursive=False).strip()
        
    # Storage    
        # initalize our document dictionary
        master_document_dict[document_id] = {}

        # add the different parts, we parsed up above.
        master_document_dict[document_id]['document_sequence'] = document_sequence
        master_document_dict[document_id]['document_filename'] = document_filename
        master_document_dict[document_id]['document_description'] = document_description
        
# Scraping
        # grab the text portion of the document, this will be used to split the document into pages.
        filing_doc_text = filing_document.find('text').extract()

        # find all the thematic breaks, these help define page numbers and page breaks.
        all_thematic_breaks = filing_doc_text.find_all('hr')

        # Locate and store page number via list comprehension.
        all_page_numbers = [thematic_break.previous_sibling.previous_sibling.get_text(strip=True) for thematic_break in all_thematic_breaks]

        # convert all thematic breaks to a string so it can be used for parsing
        all_thematic_breaks = [str(thematic_break) for thematic_break in all_thematic_breaks]

        # prep the document text for splitting, this means converting it to a string.
        filing_doc_string = str(filing_doc_text)
    
        # handle the case where there are thematic breaks.
        if len(all_thematic_breaks) > 0: 

            # define the regex delimiter pattern, this would just be all of our thematic breaks.
            regex_delimiter_pattern = '|'.join(map(re.escape, all_thematic_breaks))

            # split the document along each thematic break.
            split_filing_string = re.split(regex_delimiter_pattern, filing_doc_string)

            # store the document itself
            master_document_dict[document_id]['pages_code'] = split_filing_string

        # handle the case where there are no thematic breaks.
        elif len(all_thematic_breaks) == 0:

            # handles so it will display correctly.
            split_filing_string = all_thematic_breaks

            # store the document as is, since there are no thematic breaks. In other words, no splitting.
            master_document_dict[document_id]['pages_code'] = [filing_doc_string]
            
        # display some information to the user.
        print('-'*80)
        print('The document {} was parsed.'.format(document_id))
        print('There was {} page(s) found.'.format(len(all_page_numbers)))
        print('There was {} thematic breaks(s) found.'.format(len(all_thematic_breaks)))

        # store the documents in the master_filing_dictionary.
        master_filings_dict[acc_num]['filing_documents'] = master_document_dict
        
        # if document is 10-Q
        if document_id == '10-Q':
            QorK['10-Q'].append(acc_num) # add acc_num to QorK in 10-Q as key
        
        # if document is 10-K
        if document_id == '10-K':
            QorK['10-K'].append(acc_num) # add acc_num to QorK in 10-K as key
        
        del master_document_dict
        
        print('-'*80)
        print('All the documents for filing {} were parsed and stored.'.format(acc_num))
# Out:
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 81 page(s) found.
# There was 81 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-20-000048 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 108 page(s) found.
# There was 108 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-20-000013 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 71 page(s) found.
# There was 71 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-19-000069 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 67 page(s) found.
# There was 67 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-19-000055 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 65 page(s) found.
# There was 65 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-19-000037 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 88 page(s) found.
# There was 88 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-19-000009 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 65 page(s) found.
# There was 65 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-18-000067 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 64 page(s) found.
# There was 64 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-18-000057 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 63 page(s) found.
# There was 63 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-18-000032 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 87 page(s) found.
# There was 87 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-18-000009 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 60 page(s) found.
# There was 60 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-17-000053 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 59 page(s) found.
# There was 59 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-17-000038 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 59 page(s) found.
# There was 59 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-17-000024 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 88 page(s) found.
# There was 88 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-17-000007 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 61 page(s) found.
# There was 61 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-16-000087 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 61 page(s) found.
# There was 61 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-16-000082 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 58 page(s) found.
# There was 58 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-16-000067 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K/A was parsed.
# There was 42 page(s) found.
# There was 42 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-16-000063 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 86 page(s) found.
# There was 86 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-16-000043 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 58 page(s) found.
# There was 58 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-15-000032 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 57 page(s) found.
# There was 57 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-15-000028 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-Q was parsed.
# There was 56 page(s) found.
# There was 56 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-15-000015 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K/A was parsed.
# There was 4 page(s) found.
# There was 4 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-15-000010 were parsed and stored.
# --------------------------------------------------------------------------------
# The document 10-K was parsed.
# There was 88 page(s) found.
# There was 88 thematic breaks(s) found.
# --------------------------------------------------------------------------------
# All the documents for filing 0001326801-15-000006 were parsed and stored.

# %%
string_test = master_filings_dict['0001326801-20-000048']['filing_documents']['10-Q']['pages_code']
string_test

# %% [markdown]
# ## Anchor Check Function

# %%
# Variations of HTML anchors.
CBS_A = 'CONDENSED CONSOLIDATED BALANCE SHEETS'
CBS_B = 'CONSOLIDATED BALANCE SHEETS'
# SoO_A = '<a name="Statements_of_Operations"' 
# SoO_B = 'id="CONSOLIDATED_STATEMENTS_OPERATIONS"'
# SoO3 = 'name="CONSOLIDATED_STATEMENTS_OPERATIONS"'
# CSoO10K = 'name="Consolidated_Statements_of_Operations"'
# CSoO10Knew = 'id="Consolidated_Statements_of_Operations"'

# CF_A = '<a name="Statements_of_Cash'
# CF_B = 'id="CONSOLIDATED_STATEMENTS_CASH_FLOWS"'
# CF3 = 'name="CONSOLIDATED_STATEMENTS_CASH_FLOWS"'
# CCF10K = 'name="Consolidated_Statements_of_Cash_Flows"'
# CCF10Knew = 'id="Consolidated_Statements_of_Cash_Flows"'

def anchor_check(page_code):
    
    # if the page has one of these anchors
    if (CBS_A in page_code) or (CBS_B in page_code):
        return True

    #elif (SoO_A in page_code) or (SoO_B in page_code) or (SoO3 in page_code) or (CSoO10K in page_code) or (CSoO10Knew in page_code) :
        #return True

    #elif (CF_A in page_code) or (CF_B in page_code) or (CF3 in page_code) or (CCF10K in page_code) or (CCF10Knew in page_code):
        #return True


    else:
        return False

# %%
# TESTING: CONDENSED CONSOLIDATED BALANCE SHEETS
for k, v in QorK.items():
        
    for i, vv in enumerate(v):
        print('\n', i, vv)
        # first grab 10-Q documents only
        pages = master_filings_dict[v[i]]['filing_documents'][k]['pages_code'] 


        for page in pages:

            if  anchor_check(page) and ('In millions' in page):
                print('\n', 'Pass Anchor check')

                # Convert string to BS object
                soup = BeautifulSoup(page, 'html5')

                # then get all the rows in the table.
                table_rows = soup.find_all('tr')

                if len( [tr.text for tr in table_rows[0].find_all('td')] ) < 3:
                    del table_rows[0]
                    print('another table row deleted', '\n')
                single_table = []

                # Loop through each column, adding in three structures to single_table.
                for tr_post, tr in enumerate(table_rows):

                    td = tr.find_all('td')

                    column = [tr.text for tr in td]
                    #print( len(column), column)
                    if tr_post == 3:

                        col_date = Quarter( column )
                        single_table.append( col_date )
                        
                        col_year = year( column )
                        single_table.append( col_year )
                    
                    elif tr_post > 5: 
                        
                        cleaned_data = cleaning_column( column , 10**6 )

                        if len(cleaned_data) > 10:
                            del cleaned_data[3]

                        single_table.append( cleaned_data )
                
                
                print(single_table)
# Out:
#  0 0001326801-20-000048
#
#  Pass Anchor check
# another table row deleted
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-dacf31907050> in <module>
#      33                     if tr_post == 3:
#      34
# ---> 35                         col_date = Quarter( column )
#      36                         single_table.append( col_date )
#      37
#
# NameError: name 'Quarter' is not defined

# %% [markdown]
# ## Cleaning Columns Function

# %%
month_dict = {'December' : 'Q4',
              'November' : 'Q4',
             'October' : 'Q4',
             'September' : 'Q3',
             'August': 'Q3',
             'July' : 'Q3',
             'June' : 'Q2',
             'May' : 'Q2',
             'April' : 'Q2',
             'March' : 'Q1',
             'Feburary' : 'Q1',
             'January' : 'Q1'}

# %%
col_name_variants = {
    'Inventor' : 'Inventory',
    'Total liabilities and' : 'Total liabilities and equity',
    'Common stock.*' : 'Common Stock',
    'Preferred stock.*': 'Preferred Stock',
    'Accounts receivable.*' : 'Accounts Receivable',
    'Accrued liabilities.*' : 'Accrued Liabilities',
    'Deferred revenue.*' : 'Deferred Revenue',
    'Redeemable noncontrolling interests in subsidiaries.*' : 'Noncontrolling interests in subsidiaries',
    'Short term investments.*' : 'Short term investments', 
    'Property|equipment.' : 'Property and Equipment',
    'Retained earnings.*' : 'Retained Earnings',
    'stockholders.*' : 'Shareholder Equity',
    '^Cash.*' : 'Cash',
    'Convertible senior notes.*' : 'Convertible Senior Notes'
}

# %% [markdown]
# ### Cleaning Functions.

# %%
def clean_col_name( name ):
    
    for detect, replacement in col_name_variants.items():

        if re.findall(detect, name, flags=re.I):

            n_column = name.replace(name, replacement) 

            return n_column 
            
    return name

# %%
# Throw column list-like object into cleaning function. 
def cleaning_column(r_column, m):
     
    column_list = []
    column_name = []
    
    for element_post, element in enumerate(r_column):
        try:
            ele= element.encode('cp1252').decode("utf-8", "ignore")
                
        except:
            ele= element.encode('latin1').decode("utf-8", "ignore")
            
        if ele =='':
            continue
            
        ele_norm = unicodedata.normalize('NFKD', ele)
        
        # Handling the first "row" in the table i.e. column name.
        if element_post == 0:
#             print(element)
            
            ele_norm = ele_norm.replace('net', '')
            
            ele_norm = ele_norm.replace( '-', ' ')
            
            s_ele_norm = re.sub(r"^\s+|\s+$", "", ele_norm)
            
            name = re.sub(r'(?=,|:|\.|\(){1}.*', repl='', string= s_ele_norm, flags=re.I)
            
            # clean_col_name function Choose old_if or new_dict
            clean_name = clean_col_name( name )
            ###
            column_name.append(clean_name)
            ###
            column_list.append(clean_name)
        
        # Handling the all the remaining "rows" in the table i.e. data/numbers.
        elif ele_norm not in ['\n$', '\n\xa0', '\n', '\xa0']:
            
            n_element = ele_norm.replace( ',', '' )

            pattern = re.compile(r'[\d]+,[\d]+|[\d]+')

            res = pattern.findall(n_element)
            
            result = [int(clean_ele) * m for clean_ele in res]

            column_list.extend(result)

    return column_list

# %% [markdown]
# # Throw column list-like object into cleaning function.
# def cleaning_column(column, m):
#
#     column_list = []
#
#     for element_post, element in enumerate(column):
#
#         # Handling the first "row" in the table i.e. column name.
#         if element_post == 0:
#
#             element = unicodedata.normalize('NFKD', element)
#
#             element = element.replace( '\n', '')
#
#             clean_ele = clean_col_name( element )
#
#             column_list.append(clean_ele)
#
#         # Use a dictionary to convert the Months into numbers.
#         #elif element_post == :
#             #month = re.sub('({})'.format('|'.join(map(re.escape, month_dict.keys()))), lambda m: month_dict[m.group()], dat)
#             #column_list.extend(month)
#         #elif element == '(' or ')':
#             #pint(element)
#             #continue
#
#         else:
#
#             element = element.replace( '\n$' and '\n\xa0' and '\n', '0')
#
#             element = element.replace( ',', '' )
#
#             pattern = re.compile(r'[\d]+,[\d]+|[\d]+')
#
#             res = pattern.findall(element)
#
#             res = [int(ele) * m for ele in res]
#
#             column_list.extend(res)
#
#     return column_list

# %% [markdown]
# ## Cleaning Tables Function

# %%
def Quarter( column ):
    
    Q = []
    
    for ele_num, ele in enumerate(column):
        
        if ele != '\xa0':
            
            date_data = re.sub('({})'.format('|'.join(map(re.escape, month_dict.keys()))), lambda m: month_dict[m.group()], ele)

            pattern = re.compile(r'\w+')

            res = pattern.findall(date_data)
            #print('Qres', '-' , res)

            Q.append(res[0])

    Q.insert(0, 'Quarter')
    
    return Q

# %%
def year( column ):
    
    years = []
    
    for ele_num, ele in enumerate(column):
        
        if ele != '\xa0':
            
            clean_year = re.sub('({})'.format('|'.join(map(re.escape, month_dict.keys()))), lambda m: month_dict[m.group()], ele)

            pattern = re.compile(r'\w+')

            res = pattern.findall(clean_year)
            #print('Yres', '-' , res)
            try:
                years.append(res[2])
            
            except:
                years.append(res[0])
                
    years.insert(0, 'Year')
    
    return years

# %%
['\xa0', 'As of December 31, 2015', '\xa0', 'As ofSeptember 30, 2016']

# %%
def table_extractor( page, multiplier, k ):
    
    # Convert string to BS object
    soup = BeautifulSoup(page, 'html5')

    # then get all the rows in the table.
    table_rows = soup.find_all('tr')
    
    if len( [tr.text for tr in table_rows[0].find_all('td')] ) < 3:
        del table_rows[0]
    
    single_table = []
    
    # Loop through each column, adding in three structures to single_table.
    for tr_post, tr in enumerate(table_rows):
        
        td = tr.find_all('td')

        column = [tr.text for tr in td]

        # 10-Q 
        if k == '10-Q':
            
            if tr_post == 3:

                # Quarter Column
                col_Q = Quarter( column )
                single_table.append( col_Q )

                # Years Column
                col_year = year( column )
                single_table.append( col_year )

            elif tr_post > 5: 

                # Features Columns
                cleaned_data = cleaning_column( column , multiplier )
                if len(cleaned_data) > 10:
                    del cleaned_data[3]
                    
                single_table.append( cleaned_data )
                
        # 10-K
        elif k == '10-K':
                
            if tr_post == 1:
                
                # Quarter Column
                col_date = Quarter( column )
                single_table.append( col_date )
            
            elif tr_post == 2:
                
                col_year = year( column )
                single_table.append( col_year )

            elif tr_post > 4: 
                
                cleaned_data = cleaning_column( column , 10**6 )
                if len(cleaned_data) > 10:
                    del cleaned_data[3]
                
                single_table.append( cleaned_data )
            
    return single_table

# %%
def df_clean( single_table ):
    #print(single_table)
    table_df = pd.DataFrame(single_table)

    table_df = table_df.transpose()  

    #table_df.drop(table_df.index[1:3], 0, inplace=True)

    #table_df.drop(table_df.index[2:], 0, inplace=True)

    table_df.columns = table_df.iloc[0]

    table_df = table_df.drop(table_df.index[0])
    
    return table_df

# %%
def table(page_code, k):
    
    doc_tables=[]

    for page_post, page in enumerate(page_code):
        
        if anchor_check(page) & ('In millions' in page):
            
            single_table = table_extractor( page, 10**6, k )
            
            table_df = df_clean(single_table)
                        
            doc_tables.append(table_df)
        
        elif anchor_check(page) & ('In thousands' in page):
            
            single_table = table_extractor( page, 10**3, k )
            
            table_df = df_clean(single_table)
            
            doc_tables.append(table_df)
                
    return doc_tables

# %% [markdown]
# # ***************Making this only to rectify 10-Ks in Facebook***************

# %%
explore_10_K =  {'10-K': ['0001326801-20-000013',
  '0001326801-19-000009',
  '0001326801-18-000009',
  '0001326801-17-000007',
  '0001326801-16-000043',
  '0001326801-15-000006']}

# %%
for QK, N_O in explore_10_K.items():
    
    for an_postition, acc_num in enumerate(N_O): 
        
        pages = master_filings_dict[acc_num]['filing_documents'][QK]['pages_code']
        print('\n', 'This is {} a {} document.'.format(acc_num, QK))
        test_df = table(pages, QK)
        
        # Hereinafter is executed in part 2.
        table_df = test_df[0].drop([1]).reset_index(drop=True)
        print('Shape - ', table_df.shape)
        ICD.display(table_df)
# Out:
#  This is 0001326801-20-000013 a 10-K document.
# Shape -  (1, 33)
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 0    None  2018  10019000000           31095000000          7587000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 0                                1779000000          50480000000
#
# 0 Property and Equipment Operating lease right of use assets  \
# 0            24683000000                                None
#
# 0 Intangible assets     Goodwill Other assets Total assets   NaN  \
# 0        1294000000  18301000000   2576000000  97334000000  None
#
# 0 Shareholder Equity Current liabilities Accounts payable Partners payable  \
# 0               None                None        820000000        541000000
#
# 0 Operating lease liabilities Accrued expenses and other current liabilities  \
# 0                        None                                     5509000000
#
# 0 Deferred Revenue Total current liabilities Operating lease liabilities  \
# 0        147000000                7017000000                        None
#
# 0 Other liabilities Total liabilities Commitments and contingencies  \
# 0        6190000000       13207000000                          None
#
# 0 Shareholder Equity Common Stock Additional paid in capital  \
# 0               None         None                42906000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 0                            760000000       41981000000        84127000000
#
# 0 Total liabilities and equity
# 0                  97334000000
#  This is 0001326801-19-000009 a 10-K document.
# Shape -  (1, 30)
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 0    None  2017  8079000000           33632000000          5832000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 0                                1020000000          48563000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 0            13721000000        1884000000  18221000000   2135000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 0  84524000000  None               None                None        380000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 0        390000000                                     2892000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 0         98000000                3760000000        6417000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 0       10177000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 0         None                40584000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 0                            227000000       33990000000        74347000000
#
# 0 Total liabilities and equity
# 0                  84524000000
#  This is 0001326801-18-000009 a 10-K document.
# Shape -  (1, 30)
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 0    None  2016  8903000000           20546000000          3993000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 0                                 959000000          34401000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 0             8591000000        2535000000  18122000000   1312000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 0  64961000000  None               None                None        302000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 0        280000000                                     2203000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 0         90000000                2875000000        2892000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 0        5767000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 0         None                38227000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 0                            703000000       21670000000        59194000000
#
# 0 Total liabilities and equity
# 0                  64961000000
#  This is 0001326801-17-000007 a 10-K document.
# Shape -  (1, 32)
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 0    None  2015  4907000000           13527000000          2559000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 0                                 659000000          21652000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 0             5687000000        3246000000  18026000000    796000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 0  49407000000  None               None                None        196000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 0        217000000                                     1449000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 0         56000000                                         None
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 0                1925000000                      None        3157000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 0        5189000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 0         None                34886000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 0                            455000000        9787000000        44218000000
#
# 0 Total liabilities and equity
# 0                  49407000000
#  This is 0001326801-16-000043 a 10-K document.
# Shape -  (1, 32)
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 0    None  2014  4315000000            6884000000          1678000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 0                                 513000000          13390000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 0             3967000000        3929000000  17981000000    699000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 0  39966000000  None               None                None        176000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 0        202000000                                      866000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 0         66000000                                    114000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 0                1424000000                 119000000        2327000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 0        3870000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 0         None                30225000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 0                            228000000        6099000000        36096000000
#
# 0 Total liabilities and equity
# 0                  39966000000
#  This is 0001326801-15-000006 a 10-K document.
# Shape -  (1, 32)
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 0    None  2013  3323000000            8126000000          1109000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 0                                 512000000          13070000000
#
# 0 Property and Equipment Intangible assets   Goodwill Other assets  \
# 0             2882000000         883000000  839000000    221000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 0  17895000000  None               None                None         87000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 0        181000000                                      555000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 0         38000000                                    239000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 0                1100000000                 237000000        1088000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 0        2425000000                          None               None
#
# 0 Common Stock Additional paid in capital Accumulated other comprehensive   \
# 0         None                12297000000                         14000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 0        3159000000        15470000000                  17895000000

# %% [markdown]
# # ***************Special Save for 10-Ks***************

# %%
Checklist = {}

for k, v in explore_10_K.items():
    value_list = []
    for i, vv in enumerate(v):

        # first grab 10-Q documents only
        pages = master_filings_dict[v[i]]['filing_documents'][k]['pages_code']

        try:
            # Extract Table from html code and wrap it as a list of df.
            table_df = table(pages, k)                 
            ICD.display(table_df[0])

            with open('{}-{}.csv'.format(v[i], k), "wb") as fp:   # Pickling
                pickle.dump(table_df, fp)

            # display a status to the user.
            print('All the pages from {} document {} have been tableized and saved.'.format(k, v[i]))
        
        except: 
            value_list.append(vv)
            print('Something went wrong in file {}, file type = {}'.format(v[i], k))
        
        print('-'*80) 
    Checklist['{}'.format(k)] = value_list
    del value_list
# Out:
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 1      Q4  2019  19079000000           35776000000          9518000000
# 2    None  2018  10019000000           31095000000          7587000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1852000000          66225000000
# 2                                1779000000          50480000000
#
# 0 Property and Equipment Operating lease right of use assets  \
# 1            35323000000                          9460000000
# 2            24683000000                                None
#
# 0 Intangible assets     Goodwill Other assets  Total assets   NaN  \
# 1         894000000  18715000000   2759000000  133376000000  None
# 2        1294000000  18301000000   2576000000   97334000000  None
#
# 0 Shareholder Equity Current liabilities Accounts payable Partners payable  \
# 1               None                None       1363000000        886000000
# 2               None                None        820000000        541000000
#
# 0 Operating lease liabilities Accrued expenses and other current liabilities  \
# 1                   800000000                                    11735000000
# 2                        None                                     5509000000
#
# 0 Deferred Revenue Total current liabilities Operating lease liabilities  \
# 1        269000000               15053000000                  9524000000
# 2        147000000                7017000000                        None
#
# 0 Other liabilities Total liabilities Commitments and contingencies  \
# 1        7745000000       32322000000                          None
# 2        6190000000       13207000000                          None
#
# 0 Shareholder Equity Common Stock Additional paid in capital  \
# 1               None         None                45851000000
# 2               None         None                42906000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            489000000       55692000000       101054000000
# 2                            760000000       41981000000        84127000000
#
# 0 Total liabilities and equity
# 1                 133376000000
# 2                  97334000000
# All the pages from 10-K document 0001326801-20-000013 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 1      Q4  2018  10019000000           31095000000          7587000000
# 2    None  2017   8079000000           33632000000          5832000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1779000000          50480000000
# 2                                1020000000          48563000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1            24683000000        1294000000  18301000000   2576000000
# 2            13721000000        1884000000  18221000000   2135000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  97334000000  None               None                None        820000000
# 2  84524000000  None               None                None        380000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        541000000                                     5509000000
# 2        390000000                                     2892000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 1        147000000                7017000000        6190000000
# 2         98000000                3760000000        6417000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1       13207000000                          None               None
# 2       10177000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 1         None                42906000000
# 2         None                40584000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            760000000       41981000000        84127000000
# 2                            227000000       33990000000        74347000000
#
# 0 Total liabilities and equity
# 1                  97334000000
# 2                  84524000000
# All the pages from 10-K document 0001326801-19-000009 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q4  2017  8079000000           33632000000          5832000000
# 2    None  2016  8903000000           20546000000          3993000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1020000000          48563000000
# 2                                 959000000          34401000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1            13721000000        1884000000  18221000000   2135000000
# 2             8591000000        2535000000  18122000000   1312000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  84524000000  None               None                None        380000000
# 2  64961000000  None               None                None        302000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        390000000                                     2892000000
# 2        280000000                                     2203000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 1         98000000                3760000000        6417000000
# 2         90000000                2875000000        2892000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1       10177000000                          None               None
# 2        5767000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 1         None                40584000000
# 2         None                38227000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            227000000       33990000000        74347000000
# 2                            703000000       21670000000        59194000000
#
# 0 Total liabilities and equity
# 1                  84524000000
# 2                  64961000000
# All the pages from 10-K document 0001326801-18-000009 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q4  2016  8903000000           20546000000          3993000000
# 2    None  2015  4907000000           13527000000          2559000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                 959000000          34401000000
# 2                                 659000000          21652000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             8591000000        2535000000  18122000000   1312000000
# 2             5687000000        3246000000  18026000000    796000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  64961000000  None               None                None        302000000
# 2  49407000000  None               None                None        196000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        280000000                                     2203000000
# 2        217000000                                     1449000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         90000000                                      7000000
# 2         56000000                                         None
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                2875000000                 107000000        2892000000
# 2                1925000000                      None        3157000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1        5767000000                          None               None
# 2        5189000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 1         None                38227000000
# 2         None                34886000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            703000000       21670000000        59194000000
# 2                            455000000        9787000000        44218000000
#
# 0 Total liabilities and equity
# 1                  64961000000
# 2                  49407000000
# All the pages from 10-K document 0001326801-17-000007 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q4  2015  4907000000           13527000000          2559000000
# 2    None  2014  4315000000            6884000000          1678000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                 659000000          21652000000
# 2                                 513000000          13390000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             5687000000        3246000000  18026000000    796000000
# 2             3967000000        3929000000  17981000000    699000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  49407000000  None               None                None        196000000
# 2  39966000000  None               None                None        176000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        217000000                                     1449000000
# 2        202000000                                      866000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         56000000                                      7000000
# 2         66000000                                    114000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                1925000000                 107000000        3157000000
# 2                1424000000                 119000000        2327000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1        5189000000                          None               None
# 2        3870000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 1         None                34886000000
# 2         None                30225000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            455000000        9787000000        44218000000
# 2                            228000000        6099000000        36096000000
#
# 0 Total liabilities and equity
# 1                  49407000000
# 2                  39966000000
# All the pages from 10-K document 0001326801-16-000043 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q4  2014  4315000000            6884000000          1678000000
# 2    None  2013  3323000000            8126000000          1109000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                 793000000          13670000000
# 2                                 512000000          13070000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             3967000000        3929000000  17981000000    637000000
# 2             2882000000         883000000    839000000    221000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  40184000000  None               None                None        176000000
# 2  17895000000  None               None                None         87000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        202000000                                      866000000
# 2        181000000                                      555000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         66000000                                    114000000
# 2         38000000                                    239000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                1424000000                 119000000        2545000000
# 2                1100000000                 237000000        1088000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1        4088000000                          None               None
# 2        2425000000                          None               None
#
# 0 Common Stock Additional paid in capital Accumulated other comprehensive   \
# 1         None                30225000000                        228000000
# 2         None                12297000000                         14000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1        6099000000        36096000000                  40184000000
# 2        3159000000        15470000000                  17895000000
# All the pages from 10-K document 0001326801-15-000006 have been tableized and saved.
# --------------------------------------------------------------------------------

# %% [markdown]
# # ***************10-K special ends***************

# %% [markdown]
# # Exploring the Data

# %%
explore_dict = {}
for QK, AccNum_list in QorK.items():
    
    #for an_postition, acc_num in enumerate(AccNum_list): 
    if QK== '10-Q':
        Q_new = AccNum_list[0]
        Q_old = AccNum_list[-1]
        explore_dict[QK] = [Q_new, Q_old]

    if QK == '10-K':
        K_new = AccNum_list[0]
        K_old = AccNum_list[-1]
        explore_dict[QK] = [K_new, K_old]

# %%
explore_dict
# Out:
# {'10-Q': ['0001326801-20-000048', '0001326801-15-000015'],
#  '10-K': ['0001326801-20-000013', '0001326801-15-000006']}

# %%
for QK, N_O in explore_dict.items():
    
    for an_postition, acc_num in enumerate(N_O): 
        
        pages = master_filings_dict[acc_num]['filing_documents'][QK]['pages_code']
        print('\n', 'This is {} a {} document.'.format(acc_num, QK))
        test_df = table(pages, QK)
        
        # Hereinafter is executed in part 2.
        table_df = test_df[0].drop([2]).reset_index(drop=True)
        print('Shape - ', table_df.shape)
        ICD.display(table_df)
# Out:
#  This is 0001326801-20-000048 a 10-Q document.
# Shape -  (1, 33)
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 0      Q1  2020  23618000000           36671000000          7289000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 0                                1771000000          69349000000
#
# 0 Property and Equipment Operating lease right of use assets  \
# 0            37127000000                          9359000000
#
# 0 Intangible assets     Goodwill Other assets  Total assets   NaN  \
# 0         838000000  18811000000   2887000000  138371000000  None
#
# 0 Shareholder Equity Current liabilities Accounts payable Partners payable  \
# 0               None                None        829000000        712000000
#
# 0 Operating lease liabilities Accrued expenses and other current liabilities  \
# 0                   835000000                                    12446000000
#
# 0 Deferred Revenue Total current liabilities Operating lease liabilities  \
# 0        247000000               15069000000                  9509000000
#
# 0 Other liabilities Total liabilities Commitments and contingencies  \
# 0        8489000000       33067000000                          None
#
# 0 Shareholder Equity Common Stock Additional paid in capital  \
# 0               None         None                46688000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 0                            544000000       59160000000       105304000000
#
# 0 Total liabilities and equity
# 0                 138371000000
#  This is 0001326801-15-000015 a 10-Q document.
# Shape -  (1, 30)
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 0      Q1  2015  3419000000            8994000000          1508000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 0                                1083000000          15004000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 0             4619000000        3774000000  18005000000    605000000
#
# 0 Total assets Shareholder Equity Current liabilities Accounts payable  \
# 0  42007000000               None                None        129000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 0        189000000                                     1300000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 0         55000000                                     73000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 0                1746000000                 113000000        2647000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 0        4506000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 0                31337000000                            447000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 0        6611000000        37501000000                  42007000000
#  This is 0001326801-20-000013 a 10-K document.
# Shape -  (1, 33)
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 0      Q4  2019  19079000000           35776000000          9518000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 0                                1852000000          66225000000
#
# 0 Property and Equipment Operating lease right of use assets  \
# 0            35323000000                          9460000000
#
# 0 Intangible assets     Goodwill Other assets  Total assets   NaN  \
# 0         894000000  18715000000   2759000000  133376000000  None
#
# 0 Shareholder Equity Current liabilities Accounts payable Partners payable  \
# 0               None                None       1363000000        886000000
#
# 0 Operating lease liabilities Accrued expenses and other current liabilities  \
# 0                   800000000                                    11735000000
#
# 0 Deferred Revenue Total current liabilities Operating lease liabilities  \
# 0        269000000               15053000000                  9524000000
#
# 0 Other liabilities Total liabilities Commitments and contingencies  \
# 0        7745000000       32322000000                          None
#
# 0 Shareholder Equity Common Stock Additional paid in capital  \
# 0               None         None                45851000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 0                            489000000       55692000000       101054000000
#
# 0 Total liabilities and equity
# 0                 133376000000
#  This is 0001326801-15-000006 a 10-K document.
# Shape -  (1, 32)
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 0      Q4  2014  4315000000            6884000000          1678000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 0                                 793000000          13670000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 0             3967000000        3929000000  17981000000    637000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 0  40184000000  None               None                None        176000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 0        202000000                                      866000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 0         66000000                                    114000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 0                1424000000                 119000000        2545000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 0        4088000000                          None               None
#
# 0 Common Stock Additional paid in capital Accumulated other comprehensive   \
# 0         None                30225000000                        228000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 0        6099000000        36096000000                  40184000000

# %%
QorK
# Out:
# {'10-Q': ['0001326801-20-000048',
#   '0001326801-19-000069',
#   '0001326801-19-000055',
#   '0001326801-19-000037',
#   '0001326801-18-000067',
#   '0001326801-18-000057',
#   '0001326801-18-000032',
#   '0001326801-17-000053',
#   '0001326801-17-000038',
#   '0001326801-17-000024',
#   '0001326801-16-000087',
#   '0001326801-16-000082',
#   '0001326801-16-000067',
#   '0001326801-15-000032',
#   '0001326801-15-000028',
#   '0001326801-15-000015'],
#  '10-K': ['0001326801-20-000013',
#   '0001326801-19-000009',
#   '0001326801-18-000009',
#   '0001326801-17-000007',
#   '0001326801-16-000043',
#   '0001326801-15-000006']}

# %% [markdown]
# # Save Files Locally.

# %%
for k, v in QorK.items():
            
    for i, vv in enumerate(v):

        # first grab 10-Q documents only
        pages = master_filings_dict[v[i]]['filing_documents'][k]['pages_code']

        try:
            # Extract Table from html code and wrap it as a list of df.
            table_df = table(pages, k)                 
            ICD.display(table_df[0])
        except: 
            print('Something went wrong in file {}, file type = {}'.format(v[i], k))

        with open('{}-{}.csv'.format(v[i], k), "wb") as fp:   # Pickling
            pickle.dump(table_df, fp)

        # display a status to the user.
        print('All the pages from {} document {} have been tableized and saved.'.format(k, v[i]))
        
        print('-'*80)
# Out:
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 1      Q1  2020  23618000000           36671000000          7289000000
# 2      Q4  2019  19079000000           35776000000          9518000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1771000000          69349000000
# 2                                1852000000          66225000000
#
# 0 Property and Equipment Operating lease right of use assets  \
# 1            37127000000                          9359000000
# 2            35323000000                          9460000000
#
# 0 Intangible assets     Goodwill Other assets  Total assets   NaN  \
# 1         838000000  18811000000   2887000000  138371000000  None
# 2         894000000  18715000000   2759000000  133376000000  None
#
# 0 Shareholder Equity Current liabilities Accounts payable Partners payable  \
# 1               None                None        829000000        712000000
# 2               None                None       1363000000        886000000
#
# 0 Operating lease liabilities Accrued expenses and other current liabilities  \
# 1                   835000000                                    12446000000
# 2                   800000000                                    11735000000
#
# 0 Deferred Revenue Total current liabilities Operating lease liabilities  \
# 1        247000000               15069000000                  9509000000
# 2        269000000               15053000000                  9524000000
#
# 0 Other liabilities Total liabilities Commitments and contingencies  \
# 1        8489000000       33067000000                          None
# 2        7745000000       32322000000                          None
#
# 0 Shareholder Equity Common Stock Additional paid in capital  \
# 1               None         None                46688000000
# 2               None         None                45851000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            544000000       59160000000       105304000000
# 2                            489000000       55692000000       101054000000
#
# 0 Total liabilities and equity
# 1                 138371000000
# 2                 133376000000
# All the pages from 10-Q document 0001326801-20-000048 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 1      Q3  2019  15979000000           36290000000          7673000000
# 2      Q4  2018  10019000000           31095000000          7587000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                2137000000          62079000000
# 2                                1779000000          50480000000
#
# 0 Property and Equipment Operating lease right of use assets  \
# 1            32284000000                          8403000000
# 2            24683000000                                None
#
# 0 Intangible assets     Goodwill Other assets  Total assets   NaN  \
# 1         853000000  18338000000   2461000000  124418000000  None
# 2        1294000000  18301000000   2576000000   97334000000  None
#
# 0 Shareholder Equity Current liabilities Accounts payable Partners payable  \
# 1               None                None        860000000        590000000
# 2               None                None        820000000        541000000
#
# 0 Operating lease liabilities Accrued expenses and other current liabilities  \
# 1                   776000000                                    10877000000
# 2                        None                                     5509000000
#
# 0 Deferred Revenue Total current liabilities Operating lease liabilities  \
# 1        225000000               13328000000                  8356000000
# 2        147000000                7017000000                        None
#
# 0 Other liabilities Total liabilities Commitments and contingencies  \
# 1        8735000000       30419000000                          None
# 2        6190000000       13207000000                          None
#
# 0 Shareholder Equity Common Stock Additional paid in capital  \
# 1               None         None                45059000000
# 2               None         None                42906000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            849000000       49789000000        93999000000
# 2                            760000000       41981000000        84127000000
#
# 0 Total liabilities and equity
# 1                 124418000000
# 2                  97334000000
# All the pages from 10-Q document 0001326801-19-000069 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 1      Q2  2019  13877000000           34719000000          7513000000
# 2      Q4  2018  10019000000           31095000000          7587000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1852000000          57961000000
# 2                                1779000000          50480000000
#
# 0 Property and Equipment Operating lease right of use assets  \
# 1            29999000000                          7272000000
# 2            24683000000                                None
#
# 0 Intangible assets     Goodwill Other assets  Total assets   NaN  \
# 1         994000000  18334000000   2446000000  117006000000  None
# 2        1294000000  18301000000   2576000000   97334000000  None
#
# 0 Shareholder Equity Current liabilities Accounts payable Partners payable  \
# 1               None                None        655000000        560000000
# 2               None                None        820000000        541000000
#
# 0 Operating lease liabilities Accrued expenses and other current liabilities  \
# 1                   688000000                                    10878000000
# 2                        None                                     5509000000
#
# 0 Deferred Revenue Total current liabilities Operating lease liabilities  \
# 1        198000000               12979000000                  7122000000
# 2        147000000                7017000000                        None
#
# 0 Other liabilities Total liabilities Commitments and contingencies  \
# 1        8143000000       28244000000                          None
# 2        6190000000       13207000000                          None
#
# 0 Shareholder Equity Common Stock Additional paid in capital  \
# 1               None         None                44277000000
# 2               None         None                42906000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            483000000       44968000000        88762000000
# 2                            760000000       41981000000        84127000000
#
# 0 Total liabilities and equity
# 1                 117006000000
# 2                  97334000000
# All the pages from 10-Q document 0001326801-19-000055 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 1      Q1  2019  11076000000           34167000000          6475000000
# 2      Q4  2018  10019000000           31095000000          7587000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1582000000          53300000000
# 2                                1779000000          50480000000
#
# 0 Property and Equipment Operating lease right of use assets  \
# 1            27345000000                          6747000000
# 2            24683000000                                None
#
# 0 Intangible assets     Goodwill Other assets  Total assets   NaN  \
# 1        1150000000  18333000000   2602000000  109477000000  None
# 2        1294000000  18301000000   2576000000   97334000000  None
#
# 0 Shareholder Equity Current liabilities Accounts payable Partners payable  \
# 1               None                None        604000000        537000000
# 2               None                None        820000000        541000000
#
# 0 Operating lease liabilities Accrued expenses and other current liabilities  \
# 1                   645000000                                     7980000000
# 2                        None                                     5509000000
#
# 0 Deferred Revenue Total current liabilities Operating lease liabilities  \
# 1        142000000                9908000000                  6565000000
# 2        147000000                7017000000                        None
#
# 0 Other liabilities Total liabilities Commitments and contingencies  \
# 1        6488000000       22961000000                          None
# 2        6190000000       13207000000                          None
#
# 0 Shareholder Equity Common Stock Additional paid in capital  \
# 1               None         None                43533000000
# 2               None         None                42906000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            781000000       43764000000        86516000000
# 2                            760000000       41981000000        84127000000
#
# 0 Total liabilities and equity
# 1                 109477000000
# 2                  97334000000
# All the pages from 10-Q document 0001326801-19-000037 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q3  2018  9637000000           31569000000          6058000000
# 2      Q4  2017  8079000000           33632000000          5832000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1883000000          49147000000
# 2                                1020000000          48563000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1            21112000000        1451000000  18304000000   2438000000
# 2            13721000000        1884000000  18221000000   2135000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  92452000000  None               None                None        590000000
# 2  84524000000  None               None                None        380000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        502000000                                     4255000000
# 2        390000000                                     2892000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 1        115000000                5462000000        6648000000
# 2         98000000                3760000000        6417000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1       12110000000                          None               None
# 2       10177000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 1         None                42352000000
# 2         None                40584000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            777000000       38767000000        80342000000
# 2                            227000000       33990000000        74347000000
#
# 0 Total liabilities and equity
# 1                  92452000000
# 2                  84524000000
# All the pages from 10-Q document 0001326801-18-000067 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 1      Q2  2018  11552000000           30757000000          5590000000
# 2      Q4  2017   8079000000           33632000000          5832000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1934000000          49833000000
# 2                                1020000000          48563000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1            18357000000        1573000000  18263000000   2265000000
# 2            13721000000        1884000000  18221000000   2135000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  90291000000  None               None                None        419000000
# 2  84524000000  None               None                None        380000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        440000000                                     3720000000
# 2        390000000                                     2892000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 1         91000000                4670000000        6239000000
# 2         98000000                3760000000        6417000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1       10909000000                          None               None
# 2       10177000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 1         None                41832000000
# 2         None                40584000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            687000000       38237000000        79382000000
# 2                            227000000       33990000000        74347000000
#
# 0 Total liabilities and equity
# 1                  90291000000
# 2                  84524000000
# All the pages from 10-Q document 0001326801-18-000057 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 1      Q1  2018  12082000000           31874000000          5115000000
# 2      Q4  2017   8079000000           33632000000          5832000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1341000000          50412000000
# 2                                1020000000          48563000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1            16211000000        1735000000  18268000000   2319000000
# 2            13721000000        1884000000  18221000000   2135000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  88945000000  None               None                None        593000000
# 2  84524000000  None               None                None        380000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        396000000                                     4003000000
# 2        390000000                                     2892000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 1         94000000                5086000000        6239000000
# 2         98000000                3760000000        6417000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 1       11325000000               None         None
# 2       10177000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 1                41134000000                            294000000
# 2                40584000000                            227000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1       36780000000        77620000000                  88945000000
# 2       33990000000        74347000000                  84524000000
# All the pages from 10-Q document 0001326801-18-000032 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q3  2017  7201000000           31088000000          4424000000
# 2      Q4  2016  8903000000           20546000000          3993000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1490000000          44203000000
# 2                                 959000000          34401000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1            12158000000        2050000000  18213000000   2374000000
# 2             8591000000        2535000000  18122000000   1312000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  78998000000  None               None                None        383000000
# 2  64961000000  None               None                None        302000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        314000000                                     2503000000
# 2        280000000                                     2203000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 1        105000000                3305000000        4485000000
# 2         90000000                2875000000        2892000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 1        7790000000               None         None
# 2        5767000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 1                40199000000                            200000000
# 2                38227000000                            703000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1       31209000000        71208000000                  78998000000
# 2       21670000000        59194000000                  64961000000
# All the pages from 10-Q document 0001326801-17-000053 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q2  2017  6252000000           29200000000          3897000000
# 2      Q4  2016  8903000000           20546000000          3993000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1455000000          40804000000
# 2                                 959000000          34401000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1            10628000000        2186000000  18129000000   2096000000
# 2             8591000000        2535000000  18122000000   1312000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  73843000000  None               None                None        323000000
# 2  64961000000  None               None                None        302000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        278000000                                     2626000000
# 2        280000000                                     2203000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 1         88000000                3315000000        4047000000
# 2         90000000                2875000000        2892000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 1        7362000000               None         None
# 2        5767000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 1                39291000000                            370000000
# 2                38227000000                            703000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1       27560000000        66481000000                  73843000000
# 2       21670000000        59194000000                  64961000000
# All the pages from 10-Q document 0001326801-17-000038 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q1  2017  7104000000           25202000000          3415000000
# 2      Q4  2016  8903000000           20546000000          3993000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1209000000          36930000000
# 2                                 959000000          34401000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             9462000000        2360000000  18126000000   1836000000
# 2             8591000000        2535000000  18122000000   1312000000
#
# 0 Total assets Shareholder Equity Current liabilities Accounts payable  \
# 1  68714000000               None                None        170000000
# 2  64961000000               None                None        302000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        278000000                                     2400000000
# 2        280000000                                     2203000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 1         80000000                2928000000        3598000000
# 2         90000000                2875000000        2892000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 1        6526000000               None         None
# 2        5767000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 1                38639000000                            626000000
# 2                38227000000                            703000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1       24175000000        62188000000                  68714000000
# 2       21670000000        59194000000                  64961000000
# All the pages from 10-Q document 0001326801-17-000024 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q3  2016  6038000000           20102000000          3070000000
# 2      Q4  2015  4907000000           13527000000          2559000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1118000000          30328000000
# 2                                 659000000          21652000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             7899000000        2702000000  18085000000    660000000
# 2             5687000000        3246000000  18026000000    796000000
#
# 0 Total assets Shareholder Equity Current liabilities Accounts payable  \
# 1  59674000000               None                None        260000000
# 2  49407000000               None                None        196000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        239000000                                     2018000000
# 2        217000000                                     1449000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         78000000                                      7000000
# 2         56000000                                         None
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                2595000000                 107000000        2964000000
# 2                1925000000                      None        3157000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 1        5559000000               None         None
# 2        5189000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 1                38756000000                            372000000
# 2                34886000000                            455000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1       15731000000        54115000000                  59674000000
# 2        9787000000        44218000000                  49407000000
# All the pages from 10-Q document 0001326801-16-000087 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q2  2016  5108000000           18185000000          2801000000
# 2      Q4  2015  4907000000           13527000000          2559000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                 916000000          27010000000
# 2                                 659000000          21652000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             7104000000        2879000000  18043000000    703000000
# 2             5687000000        3246000000  18026000000    796000000
#
# 0 Total assets Shareholder Equity Current liabilities Accounts payable  \
# 1  55739000000               None                None        130000000
# 2  49407000000               None                None        196000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        232000000                                     1770000000
# 2        217000000                                     1449000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         79000000                                      7000000
# 2         56000000                                         None
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                2211000000                 107000000        3145000000
# 2                1925000000                      None        3157000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 1        5356000000               None         None
# 2        5189000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 1                37405000000                            374000000
# 2                34886000000                            455000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1       13352000000        50383000000                  55739000000
# 2        9787000000        44218000000                  49407000000
# All the pages from 10-Q document 0001326801-16-000082 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q1  2016  6456000000           14165000000          2348000000
# 2      Q4  2015  4907000000           13527000000          2559000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                 843000000          23812000000
# 2                                 659000000          21652000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             6467000000        3067000000  18029000000    700000000
# 2             5687000000        3246000000  18026000000    796000000
#
# 0 Total assets Shareholder Equity Current liabilities Accounts payable  \
# 1  52075000000               None                None        149000000
# 2  49407000000               None                None        196000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        216000000                                     1389000000
# 2        217000000                                     1449000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         55000000                                      7000000
# 2         56000000                                         None
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                1809000000                 107000000        3116000000
# 2                1925000000                      None        3157000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 1        4925000000               None         None
# 2        5189000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 1                36129000000                            276000000
# 2                34886000000                            455000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1       11297000000        47150000000                  52075000000
# 2        9787000000        44218000000                  49407000000
# All the pages from 10-Q document 0001326801-16-000067 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q3  2015  4308000000           11526000000          2010000000
# 2      Q4  2014  4315000000            6884000000          1678000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1295000000          19139000000
# 2                                 793000000          13670000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             5335000000        3437000000  18024000000    534000000
# 2             3967000000        3929000000  17981000000    637000000
#
# 0 Total assets Shareholder Equity Current liabilities Accounts payable  \
# 1  46469000000               None                None        149000000
# 2  40184000000               None                None        176000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        241000000                                     1338000000
# 2        202000000                                      866000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         47000000                                     17000000
# 2         66000000                                    114000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                1792000000                 109000000        3148000000
# 2                1424000000                 119000000        2545000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 1        5049000000               None         None
# 2        4088000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 1                33574000000                            380000000
# 2                30225000000                            228000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1        8226000000        41420000000                  46469000000
# 2        6099000000        36096000000                  40184000000
# All the pages from 10-Q document 0001326801-15-000032 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q2  2015  5123000000            9002000000          1815000000
# 2      Q4  2014  4315000000            6884000000          1678000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1011000000          16951000000
# 2                                 793000000          13670000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             4955000000        3605000000  18025000000    594000000
# 2             3967000000        3929000000  17981000000    637000000
#
# 0 Total assets Shareholder Equity Current liabilities Accounts payable  \
# 1  44130000000               None                None        139000000
# 2  40184000000               None                None        176000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        182000000                                     1472000000
# 2        202000000                                      866000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         49000000                                     39000000
# 2         66000000                                    114000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                1881000000                 110000000        2687000000
# 2                1424000000                 119000000        2545000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 1        4678000000               None         None
# 2        4088000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 1                32479000000                            357000000
# 2                30225000000                            228000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1        7330000000        39452000000                  44130000000
# 2        6099000000        36096000000                  40184000000
# All the pages from 10-Q document 0001326801-15-000028 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q1  2015  3419000000            8994000000          1508000000
# 2      Q4  2014  4315000000            6884000000          1678000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1083000000          15004000000
# 2                                 793000000          13670000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             4619000000        3774000000  18005000000    605000000
# 2             3967000000        3929000000  17981000000    637000000
#
# 0 Total assets Shareholder Equity Current liabilities Accounts payable  \
# 1  42007000000               None                None        129000000
# 2  40184000000               None                None        176000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        189000000                                     1300000000
# 2        202000000                                      866000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         55000000                                     73000000
# 2         66000000                                    114000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                1746000000                 113000000        2647000000
# 2                1424000000                 119000000        2545000000
#
# 0 Total liabilities Shareholder Equity Common Stock  \
# 1        4506000000               None         None
# 2        4088000000               None         None
#
# 0 Additional paid in capital Accumulated other comprehensive loss  \
# 1                31337000000                            447000000
# 2                30225000000                            228000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1        6611000000        37501000000                  42007000000
# 2        6099000000        36096000000                  40184000000
# All the pages from 10-Q document 0001326801-15-000015 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 1      Q4  2019  19079000000           35776000000          9518000000
# 2    None  2018  10019000000           31095000000          7587000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1852000000          66225000000
# 2                                1779000000          50480000000
#
# 0 Property and Equipment Operating lease right of use assets  \
# 1            35323000000                          9460000000
# 2            24683000000                                None
#
# 0 Intangible assets     Goodwill Other assets  Total assets   NaN  \
# 1         894000000  18715000000   2759000000  133376000000  None
# 2        1294000000  18301000000   2576000000   97334000000  None
#
# 0 Shareholder Equity Current liabilities Accounts payable Partners payable  \
# 1               None                None       1363000000        886000000
# 2               None                None        820000000        541000000
#
# 0 Operating lease liabilities Accrued expenses and other current liabilities  \
# 1                   800000000                                    11735000000
# 2                        None                                     5509000000
#
# 0 Deferred Revenue Total current liabilities Operating lease liabilities  \
# 1        269000000               15053000000                  9524000000
# 2        147000000                7017000000                        None
#
# 0 Other liabilities Total liabilities Commitments and contingencies  \
# 1        7745000000       32322000000                          None
# 2        6190000000       13207000000                          None
#
# 0 Shareholder Equity Common Stock Additional paid in capital  \
# 1               None         None                45851000000
# 2               None         None                42906000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            489000000       55692000000       101054000000
# 2                            760000000       41981000000        84127000000
#
# 0 Total liabilities and equity
# 1                 133376000000
# 2                  97334000000
# All the pages from 10-K document 0001326801-20-000013 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year         Cash Marketable securities Accounts Receivable  \
# 1      Q4  2018  10019000000           31095000000          7587000000
# 2    None  2017   8079000000           33632000000          5832000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1779000000          50480000000
# 2                                1020000000          48563000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1            24683000000        1294000000  18301000000   2576000000
# 2            13721000000        1884000000  18221000000   2135000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  97334000000  None               None                None        820000000
# 2  84524000000  None               None                None        380000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        541000000                                     5509000000
# 2        390000000                                     2892000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 1        147000000                7017000000        6190000000
# 2         98000000                3760000000        6417000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1       13207000000                          None               None
# 2       10177000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 1         None                42906000000
# 2         None                40584000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            760000000       41981000000        84127000000
# 2                            227000000       33990000000        74347000000
#
# 0 Total liabilities and equity
# 1                  97334000000
# 2                  84524000000
# All the pages from 10-K document 0001326801-19-000009 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q4  2017  8079000000           33632000000          5832000000
# 2    None  2016  8903000000           20546000000          3993000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                1020000000          48563000000
# 2                                 959000000          34401000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1            13721000000        1884000000  18221000000   2135000000
# 2             8591000000        2535000000  18122000000   1312000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  84524000000  None               None                None        380000000
# 2  64961000000  None               None                None        302000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        390000000                                     2892000000
# 2        280000000                                     2203000000
#
# 0 Deferred Revenue Total current liabilities Other liabilities  \
# 1         98000000                3760000000        6417000000
# 2         90000000                2875000000        2892000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1       10177000000                          None               None
# 2        5767000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 1         None                40584000000
# 2         None                38227000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            227000000       33990000000        74347000000
# 2                            703000000       21670000000        59194000000
#
# 0 Total liabilities and equity
# 1                  84524000000
# 2                  64961000000
# All the pages from 10-K document 0001326801-18-000009 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q4  2016  8903000000           20546000000          3993000000
# 2    None  2015  4907000000           13527000000          2559000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                 959000000          34401000000
# 2                                 659000000          21652000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             8591000000        2535000000  18122000000   1312000000
# 2             5687000000        3246000000  18026000000    796000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  64961000000  None               None                None        302000000
# 2  49407000000  None               None                None        196000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        280000000                                     2203000000
# 2        217000000                                     1449000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         90000000                                      7000000
# 2         56000000                                         None
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                2875000000                 107000000        2892000000
# 2                1925000000                      None        3157000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1        5767000000                          None               None
# 2        5189000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 1         None                38227000000
# 2         None                34886000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            703000000       21670000000        59194000000
# 2                            455000000        9787000000        44218000000
#
# 0 Total liabilities and equity
# 1                  64961000000
# 2                  49407000000
# All the pages from 10-K document 0001326801-17-000007 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q4  2015  4907000000           13527000000          2559000000
# 2    None  2014  4315000000            6884000000          1678000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                 659000000          21652000000
# 2                                 513000000          13390000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             5687000000        3246000000  18026000000    796000000
# 2             3967000000        3929000000  17981000000    699000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  49407000000  None               None                None        196000000
# 2  39966000000  None               None                None        176000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        217000000                                     1449000000
# 2        202000000                                      866000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         56000000                                      7000000
# 2         66000000                                    114000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                1925000000                 107000000        3157000000
# 2                1424000000                 119000000        2327000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1        5189000000                          None               None
# 2        3870000000                          None               None
#
# 0 Common Stock Additional paid in capital  \
# 1         None                34886000000
# 2         None                30225000000
#
# 0 Accumulated other comprehensive loss Retained Earnings Shareholder Equity  \
# 1                            455000000        9787000000        44218000000
# 2                            228000000        6099000000        36096000000
#
# 0 Total liabilities and equity
# 1                  49407000000
# 2                  39966000000
# All the pages from 10-K document 0001326801-16-000043 have been tableized and saved.
# --------------------------------------------------------------------------------
# 0 Quarter  Year        Cash Marketable securities Accounts Receivable  \
# 1      Q4  2014  4315000000            6884000000          1678000000
# 2    None  2013  3323000000            8126000000          1109000000
#
# 0 Prepaid expenses and other current assets Total current assets  \
# 1                                 793000000          13670000000
# 2                                 512000000          13070000000
#
# 0 Property and Equipment Intangible assets     Goodwill Other assets  \
# 1             3967000000        3929000000  17981000000    637000000
# 2             2882000000         883000000    839000000    221000000
#
# 0 Total assets   NaN Shareholder Equity Current liabilities Accounts payable  \
# 1  40184000000  None               None                None        176000000
# 2  17895000000  None               None                None         87000000
#
# 0 Partners payable Accrued expenses and other current liabilities  \
# 1        202000000                                      866000000
# 2        181000000                                      555000000
#
# 0 Deferred Revenue Current portion of capital lease obligations  \
# 1         66000000                                    114000000
# 2         38000000                                    239000000
#
# 0 Total current liabilities Capital lease obligations Other liabilities  \
# 1                1424000000                 119000000        2545000000
# 2                1100000000                 237000000        1088000000
#
# 0 Total liabilities Commitments and contingencies Shareholder Equity  \
# 1        4088000000                          None               None
# 2        2425000000                          None               None
#
# 0 Common Stock Additional paid in capital Accumulated other comprehensive   \
# 1         None                30225000000                        228000000
# 2         None                12297000000                         14000000
#
# 0 Retained Earnings Shareholder Equity Total liabilities and equity
# 1        6099000000        36096000000                  40184000000
# 2        3159000000        15470000000                  17895000000
# All the pages from 10-K document 0001326801-15-000006 have been tableized and saved.
# --------------------------------------------------------------------------------

# %% [markdown]
# # Comparing the Old and the New.

# %%
# Sample: Older filing style. 
import pickle
pd.set_option('display.max_columns', 100)
with open("0001564590-19-038256-10-Q.csv", "rb") as fp:
    file = pickle.load(fp)
df01 = file[0]

# df01['CSN_SUM'] = df01['Convertible Senior Notes'].values.sum()
# del df01['Convertible Senior Notes']

# df01['DeferredRevenue'] = df01['Deferred Revenue'].values.sum()
# del df01['Deferred Revenue']

# df01['NoncontrollingInterests'] = df01['Noncontrolling interests in subsidiaries'].values.sum()
# del df01['Noncontrolling interests in subsidiaries']

print(df01.shape)
df01

# %%
duplicate_columns( df01 )

# %% [markdown]
# ### Newer Filing

# %%
# Sample: Newer filing style. 
import pickle 
import pandas as pd
pd.set_option('display.max_columns', 100)
with open("0001564590-20-019931-10-Q.csv", "rb") as fp:
    file = pickle.load(fp)
df02 = file[0]
print(df02.shape) 
df02

# %%
checking_duplicate_columns( df02 )

# %%
print('Using the Function')

duplicate_columns( df02 )

# %%
# Slamming the Raw DataFrame into the dissected column cleanser. 
print('Not Using the Function')
duplicates = [k for (k,v) in Counter(df02.columns).items() if v > 1] 

for dupli in duplicates: 
    res = df02[dupli].values.sum()
    df02['Total {}'.format(dupli)] = res
    df02.drop(dupli, axis=1, inplace=True)
    
df02

# %%
df02.columns

# %%
checking_duplicate_columns( df2 )

# %% [markdown]
# # Concating dfs

# %% [markdown]
# ### Example code:

# %%
c_ = pd.concat([df2, df01], axis=0, sort=False)

print(c_.shape)
c_

# %%
# Serious Stuff. 
def duplicate_columns( DataF ):
    
    duplicates = [k for (k,v) in Counter(DataF.columns).items() if v > 1] 

    for dupli in duplicates: 
        
        res = DataF[dupli].values.sum()
        
        DataF['Serious {}'.format(dupli)] = res
        
        DataF.drop(dupli, axis=1, inplace=True)

    return DataF

# %%
# Just for checking.
def checking_duplicate_columns( DataF ):
    
    duplicates = [k for (k,v) in Counter(DataF.columns).items() if v > 1] 

    
    print('Shape of df: ', DataF.shape )
    return duplicates
